# %%
# !pip install seqeval
# Out:
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.4.0)

# %%
import pandas as pd
import numpy as np

import os

import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# verify GPU
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ## Convert to DataFrame for EDA

# %%
def convert_data(filepath):

  # Read the data from the text file
  with open(filepath, "r") as file:
      lines = file.readlines()

  # Define an empty list to store the data
  data = []

  # Iterate over each line in the file
  for line in lines:
      # Split the line by spaces
      parts = line.strip().split()

      # Check if the line has the expected number of elements
      if len(parts) == 9:
          # Extract the values from the line
          text_file_name = parts[0]
          sentence_line_number = int(parts[1])
          sentence_word_index = int(parts[2])
          sentence_seq = parts[3]
          start_token = int(parts[4])
          end_token = int(parts[5])
          original_word = parts[6]
          word = parts[7]
          label = parts[8]

          # Append the values as a tuple to the data list
          data.append((text_file_name, sentence_line_number, sentence_word_index, sentence_seq,
                      start_token, end_token, original_word, word, label))

  # Create a DataFrame from the data list with appropriate column names
  df = pd.DataFrame(data, columns=['text_file_name', 'sentence_line_number', 'sentence_word_index',
                                  'sentence_seq', 'start_token', 'end_token', 'original_word',
                                  'word', 'label'])

  return df

# %%
train_data_path = "/content/drive/MyDrive/266_final/data/Original_text/dataset1_train.txt"
test_data_path = "/content/drive/MyDrive/266_final/data/Original_text/dataset1_test.txt"

train = convert_data(train_data_path)
test = convert_data(test_data_path)

print(f"Length of train: {len(train)}")
print(f"Length of test: {len(test)}")
# Out:
# Length of train: 895141
# Length of test: 585761

# %%
df = train.copy()
df['sentence_line_number'].nunique()
# Out:
# 1053

# %%
df['label'].value_counts().sort_values()
# Out:
# label
# I-Route           397
# B-Duration        592
# I-ADE             776
# B-ADE             956
# I-Duration       1034
# I-Reason         3125
# B-Reason         3791
# I-Form           4173
# B-Dosage         4221
# I-Drug           4298
# B-Route          5475
# B-Frequency      6279
# I-Strength       6617
# B-Form           6647
# B-Strength       6691
# I-Dosage         8779
# I-Frequency     13023
# B-Drug          16222
# O              802045
# Name: count, dtype: int64

# %%
df[(df['word'] == 'ORDINAL') & (df['label'] == 'B-Dosage')]
# Out:
#                            text_file_name  sentence_line_number  \
# 2580    data/training_20180910/110727.txt                   277
# 3038    data/training_20180910/110727.txt                   331
# 3070    data/training_20180910/110727.txt                   335
# 3143    data/training_20180910/110727.txt                   347
# 3166    data/training_20180910/110727.txt                   349
# ...                                   ...                   ...
# 894405  data/training_20180910/100883.txt                   125
# 894903  data/training_20180910/100883.txt                   188
# 894959  data/training_20180910/100883.txt                   194
# 894968  data/training_20180910/100883.txt                   195
# 894988  data/training_20180910/100883.txt                   197
#
#         sentence_word_index sentence_seq  start_token  end_token  \
# 2580                      9         T396        12227      12228
# 3038                      2         T167        14315      14316
# 3070                      2          T87        14463      14464
# 3143                     12         T264        14825      14828
# 3166                      8         T269        14897      14902
# ...                     ...          ...          ...        ...
# 894405                    0          T38         5767       5770
# 894903                    3          T72         8349       8350
# 894959                    3          T90         8571       8572
# 894968                    3          T94         8607       8608
# 894988                    4          T97         8712       8713
#
#        original_word     word     label
# 2580               3  ORDINAL  B-Dosage
# 3038               1  ORDINAL  B-Dosage
# 3070               1  ORDINAL  B-Dosage
# 3143             One  ORDINAL  B-Dosage
# 3166           Three  ORDINAL  B-Dosage
# ...              ...      ...       ...
# 894405           one  ORDINAL  B-Dosage
# 894903             1  ORDINAL  B-Dosage
# 894959             2  ORDINAL  B-Dosage
# 894968             2  ORDINAL  B-Dosage
# 894988             2  ORDINAL  B-Dosage
#
# [3599 rows x 9 columns]

# %% [markdown]
# ### Label labels

# %%
# Split labels based on whitespace and turn them into a list
labels = [i.split() for i in df['label'].values.tolist()]

# Check how many labels are there in the dataset
unique_labels = set()

for lb in labels:
  [unique_labels.add(i) for i in lb if i not in unique_labels]

print(unique_labels)
# Out:
# {'B-Form', 'I-Dosage', 'B-Reason', 'O', 'B-Duration', 'B-Drug', 'B-Frequency', 'B-Route', 'I-ADE', 'I-Frequency', 'B-Strength', 'I-Strength', 'I-Drug', 'I-Form', 'I-Reason', 'B-ADE', 'B-Dosage', 'I-Duration', 'I-Route'}

# %%
# Map each label into its id representation and vice versa
labels_to_ids = {k: v for v, k in enumerate(sorted(unique_labels))}
ids_to_labels = {v: k for v, k in enumerate(sorted(unique_labels))}
print(labels_to_ids)
# Out:
# {'B-ADE': 0, 'B-Dosage': 1, 'B-Drug': 2, 'B-Duration': 3, 'B-Form': 4, 'B-Frequency': 5, 'B-Reason': 6, 'B-Route': 7, 'B-Strength': 8, 'I-ADE': 9, 'I-Dosage': 10, 'I-Drug': 11, 'I-Duration': 12, 'I-Form': 13, 'I-Frequency': 14, 'I-Reason': 15, 'I-Route': 16, 'I-Strength': 17, 'O': 18}

# %%
df[df['label'] == 'B-ADE']
# Out:
#                            text_file_name  sentence_line_number  \
# 637     data/training_20180910/110727.txt                    68
# 645     data/training_20180910/110727.txt                    69
# 700     data/training_20180910/110727.txt                    74
# 706     data/training_20180910/110727.txt                    75
# 732     data/training_20180910/110727.txt                    78
# ...                                   ...                   ...
# 892895  data/training_20180910/118564.txt                   156
# 892897  data/training_20180910/118564.txt                   157
# 893013  data/training_20180910/118564.txt                   168
# 894424  data/training_20180910/100883.txt                   128
# 894469  data/training_20180910/100883.txt                   132
#
#         sentence_word_index sentence_seq  start_token  end_token  \
# 637                       3         T208         3011       3025
# 645                       0         T377         3062       3070
# 700                       1         T209         3237       3240
# 706                       1         T210         3262       3265
# 732                       1         T378         3365       3370
# ...                     ...          ...          ...        ...
# 892895                    6          T40         8092       8106
# 892897                    1          T41         8111       8120
# 893013                   10          T44         8731       8735
# 894424                    0          T41         5871       5882
# 894469                    0          T46         6119       6131
#
#          original_word            word  label
# 637     polyneuropathy  polyneuropathy  B-ADE
# 645           infusion        infusion  B-ADE
# 700                HTN             HTN  B-ADE
# 706                DM2             DM0  B-ADE
# 732              NAFLD           NAFLD  B-ADE
# ...                ...             ...    ...
# 892895  hallucinations  hallucinations  B-ADE
# 892897       tachypnea       tachypnea  B-ADE
# 893013            rash            rash  B-ADE
# 894424     Hypotension     Hypotension  B-ADE
# 894469    tachycardiac    tachycardiac  B-ADE
#
# [956 rows x 9 columns]

# %% [markdown]
# ## Experimenting with formats for BERT

# %%
train_texts = []
train_labels = []

# Read the text file line by line
with open('/content/drive/MyDrive/266_final/data/Original_text/dataset1_train.txt', 'r', encoding='utf-8') as file:
    current_text = []  # To store tokens of the current text
    current_labels = []  # To store labels of the current text
    for line in file:
        if line.strip() == '':  # Empty line signifies end of text
            train_texts.append(current_text)
            train_labels.append(current_labels)
            current_text = []
            current_labels = []
        else:
            parts = line.strip().split()
            token = parts[-3]  # Token is second-to-last part
            label = parts[-1]   # Label is last part
            current_text.append(token)
            current_labels.append(label)

# Check the first few samples
print(train_texts[:5])
print(train_labels[:5])
# Out:
# [['Admission', 'Date', ':', '[', '*', '*', '2202', '-', '1', '-', '8', '*', '*', ']', 'Discharge', 'Date', ':', '[', '*', '*', '2202', '-', '2', '-', '1', '*', '*', ']'], ['Date', 'of', 'Birth', ':', '[', '*', '*', '2163', '-', '9', '-', '18', '*', '*', ']', 'Sex', ':', 'M'], ['Service', ':', 'MEDICINE'], ['Allergies', ':', 'Keflex', '/', 'Orencia', '/', 'Remicade'], ['Attending', ':', '[', '*', '*', 'First', 'Name3', '(', 'LF', ')', '2751', '*', '*', ']', 'Chief', 'Complaint', ':', 'L', 'leg', 'pain', 'and', 'erythema']]
# [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O'], ['O', 'O', 'B-Drug', 'O', 'B-Drug', 'O', 'B-Drug'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]

# %% [markdown]
# ### Not sure if this is the correct format. Let's look into another way to turn it into a sentence.

# %%
def formatted_df(df):
  df['sentence'] = df[[
      'text_file_name',
      'sentence_line_number',
      'original_word',
      'label']].groupby(
          ['text_file_name', 'sentence_line_number'])['original_word'].transform(lambda x: ' '.join(x))

  df['word_labels'] = df[[
      'text_file_name',
      'sentence_line_number',
      'original_word',
      'label']].groupby(
          ['text_file_name', 'sentence_line_number'])['label'].transform(lambda x: ','.join(x))

  return df

# %%
df = formatted_df(df)
df_test = formatted_df(test)

# %%
def sentence_level_data_fn(df):
  sentence_level_data = df[["text_file_name", "sentence_line_number", "sentence", "word_labels"]].drop_duplicates().reset_index(drop=True)
  return sentence_level_data

sentence_level_train = sentence_level_data_fn(df)
sentence_level_test = sentence_level_data_fn(df_test)

# %%
sentence_level_data = sentence_level_train[["text_file_name", "sentence_line_number", "sentence", "word_labels"]].drop_duplicates().reset_index(drop=True)
sentence_level_test = sentence_level_test[["text_file_name","sentence_line_number",  "sentence", "word_labels"]].drop_duplicates().reset_index(drop=True)

sentence_level_data.head()
# Out:
#                       text_file_name  sentence_line_number  \
# 0  data/training_20180910/110727.txt                     1
# 1  data/training_20180910/110727.txt                     3
# 2  data/training_20180910/110727.txt                     5
# 3  data/training_20180910/110727.txt                     7
# 4  data/training_20180910/110727.txt                     8
#
#                                             sentence  \
# 0  Admission Date : [ * * 2202 - 1 - 8 * * ] Disc...
# 1  Date of Birth : [ * * 2163 - 9 - 18 * * ] Sex : M
# 2                                 Service : MEDICINE
# 3                                        Allergies :
# 4                        Keflex / Orencia / Remicade
#
#                                          word_labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1                O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 2                                              O,O,O
# 3                                                O,O
# 4                           B-Drug,O,B-Drug,O,B-Drug

# %%
len(sentence_level_data)
# Out:
# 83321

# %%
sentence_level_data.iloc[7020].sentence
# Out:
# 'your chemistries .'

# %%
sentence_level_data.iloc[7020].word_labels
# Out:
# 'O,O,O'

# %%
print(sentence_level_data.iloc[21].sentence)
print(sentence_level_data.iloc[21].word_labels)
# Out:
# fx on x - ray . This was thought to be a psoriatic arthritis flare ,
# O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O

# %%
sentence_level_data
# Out:
#                           text_file_name  sentence_line_number  \
# 0      data/training_20180910/110727.txt                     1
# 1      data/training_20180910/110727.txt                     3
# 2      data/training_20180910/110727.txt                     5
# 3      data/training_20180910/110727.txt                     7
# 4      data/training_20180910/110727.txt                     8
# ...                                  ...                   ...
# 83316  data/training_20180910/100883.txt                   219
# 83317  data/training_20180910/100883.txt                   220
# 83318  data/training_20180910/100883.txt                   221
# 83319  data/training_20180910/100883.txt                   222
# 83320  data/training_20180910/100883.txt                   223
#
#                                                 sentence  \
# 0      Admission Date : [ * * 2202 - 1 - 8 * * ] Disc...
# 1      Date of Birth : [ * * 2163 - 9 - 18 * * ] Sex : M
# 2                                     Service : MEDICINE
# 3                                            Allergies :
# 4                            Keflex / Orencia / Remicade
# ...                                                  ...
# 83316  Dictated By : [ * * Last Name ( NamePattern1 )...
# 83317                                         MEDQUIST36
# 83318          D : [ * * 2102 - 6 - 3 * * ] 13 : 37 : 57
# 83319          T : [ * * 2102 - 6 - 3 * * ] 15 : 11 : 44
# 83320               Job # : [ * * Job Number 20174 * * ]
#
#                                              word_labels
# 0      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1                    O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 2                                                  O,O,O
# 3                                                    O,O
# 4                               B-Drug,O,B-Drug,O,B-Drug
# ...                                                  ...
# 83316                      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 83317                                                  O
# 83318                O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 83319                O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 83320                            O,O,O,O,O,O,O,O,O,O,O,O
#
# [83321 rows x 4 columns]

# %% [markdown]
# #### Some sentences are really short. *Try* concatenating sentence to get longer inputs

# %%
# df = sentence_level_data.sort_values(by=['text_file_name', 'sentence_line_number'])
# df_test = sentence_level_test.sort_values(by=['text_file_name', 'sentence_line_number'])

# # Function to concatenate up to 5 consecutive sentences and labels
# def concatenate_sentences(group):
#     """
#     This function takes a group of sentences and labels from a dataframe
#     and concatenates up to 5 consecutive sentences and t
#     heir corresponding labels into a single string.
#     Args:
#         group (Datafram): A group of sentences and labels from a
#         DataFrame grouped by a column (e.g., text_file_name).
#     Returns:
#         pandas.DataFrame: A DataFrame containing the
#         original text_file_name, a list of
#         concatenated sentences, and a
#         list of concatenated labels.
#     """
#     concatenated_sentences = []
#     concatenated_labels = []

#     for i in range(len(group)):
#         # Select up to 5 consecutive sentences starting from the current one
#         sentences_to_concat = group['sentence'].iloc[i:i+5].tolist()
#         labels_to_concat = group['word_labels'].iloc[i:i+5].tolist()

#         # Concatenate selected sentences and labels
#         concatenated_sentence = ' '.join(sentences_to_concat)
#         concatenated_label = ','.join(labels_to_concat)

#         concatenated_sentences.append(concatenated_sentence)
#         concatenated_labels.append(concatenated_label)

#     # Return a DataFrame for the concatenated sentences and labels
#     return pd.DataFrame({
#         'text_file_name': group['text_file_name'].iloc[0],
#         'concatenated_sentence': concatenated_sentences,
#         'concatenated_labels': concatenated_labels
#     })

# # Step 2: Apply the concatenation function to each group and combine the results
# concatenated_df = pd.concat([concatenate_sentences(group) for _, group in df.groupby('text_file_name')])
# concatenated_test = pd.concat([concatenate_sentences(group) for _, group in df_test.groupby('text_file_name')])

# # Reset index of the resulting DataFrame
# concatenated_df = concatenated_df.reset_index(drop=True)

# df = sentence_level_data.sort_values(by=['text_file_name', 'sentence_line_number'])
# df_test = sentence_level_test.sort_values(by=['text_file_name', 'sentence_line_number'])# concatenated_df.head()

# %%
df = sentence_level_data.sort_values(by=['text_file_name', 'sentence_line_number'])
df_test = sentence_level_test.sort_values(by=['text_file_name', 'sentence_line_number'])

def cs(dataframe):
    processed_data_list = []

    # Group by 'text_file_name'
    grouped = dataframe.groupby("text_file_name")

    for name, group in grouped:
        sentences = group['sentence'].tolist()
        # Labels are already strings, so we take them as is
        labels = group['word_labels'].tolist()

        for i in range(0, len(sentences), 5):
            end_index = min(i + 5, len(sentences))
            current_batch = sentences[i:end_index]
            current_labels = labels[i:end_index]

            concatenated_sentence = " ".join(current_batch)
            # Concatenate labels as they are, assuming they're correctly formatted strings
            concatenated_label = ",".join(current_labels)

            processed_data_list.append({
                "text_file_name": name,
                "sentences": concatenated_sentence,
                "labels": concatenated_label
            })

    processed_data = pd.DataFrame(processed_data_list)
    return processed_data


# Correcting the function to properly handle labels
concatenated_df = cs(df)
concatenated_test= cs(df_test)

concatenated_df
# Out:
#                           text_file_name  \
# 0      data/training_20180910/100035.txt
# 1      data/training_20180910/100035.txt
# 2      data/training_20180910/100035.txt
# 3      data/training_20180910/100035.txt
# 4      data/training_20180910/100035.txt
# ...                                  ...
# 16783  data/training_20180910/198406.txt
# 16784  data/training_20180910/198406.txt
# 16785  data/training_20180910/198406.txt
# 16786  data/training_20180910/198406.txt
# 16787  data/training_20180910/198406.txt
#
#                                                sentences  \
# 0      Admission Date : [ * * 2115 - 2 - 22 * * ] Dis...
# 1      Attending : [ * * First Name3 ( LF ) 4891 * * ...
# 2      Removal of chest tubes placed at an outside ho...
# 3      to an OSH with dyspnea now admitted to the MIC...
# 4      and was intubated . He received epinephrine , ...
# ...                                                  ...
# 16783  # Contact : [ * * Name ( NI ) * * ] [ * * Tele...
# 16784  4 . Ergocalciferol 50 , 000 unit weekly 5 . Ri...
# 16785  9 . Acetaminophen 1000 mg PO Q6H 10 . Mirtazap...
# 16786  Expired Discharge Diagnosis : Chief cause of d...
# 16787  Deceased Discharge Instructions : Deceased Fol...
#
#                                                   labels
# 0      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 2      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3      O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4      O,O,O,O,O,O,B-Drug,O,B-Drug,O,B-Drug,O,O,B-Dru...
# ...                                                  ...
# 16783  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 16784  O,O,B-Drug,B-Dosage,I-Dosage,I-Dosage,I-Dosage...
# 16785  O,O,B-Drug,B-Strength,I-Strength,B-Route,B-Fre...
# 16786        O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O
# 16787                                  O,O,O,O,O,O,O,O,O
#
# [16788 rows x 3 columns]

# %%
# concatenated_df['labels']= concatenated_df['labels'].map(lambda x: ','.join(map(str, x)))

# %%
# concatenated_df_with_labels.drop_duplicates(subset=['sentences'], inplace=True)
# concatenated_df_with_labels.drop_duplicates(subset=['sentences'], inplace=True)

# %%
# make sure test is formatted same way
concatenated_df.iloc[301].sentences
# Out:
# "could be due to patient's liver dysfunction/third spacing from CHF . If cholecystitis is of clinical concern , HIDA scan can be performed provided the total bilirubin is not elevated . 3 ) Hyperdense renal cortex in left lower quadrant transplanted kidney . Findings are most likely due to chronic rejection or"

# %%
concatenated_df.iloc[301].labels
# Out:
# 'O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O'

# %%
concatenated_df.iloc[16765].sentences
# Out:
# 'evidence of acute focal pneumonia . Brief Hospital Course : [ * * Age over 90 * * ] year old female with past medical history significant for CAD , critical AS , and radiation proctitis presenting after a fall with a humeral fracture and hypotension following opiates .'

# %%
concatenated_df.iloc[16765].labels
# Out:
# 'O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,B-ADE,I-ADE,O,B-ADE,O,B-Drug,O'

# %%
print(concatenated_df.iloc[21].sentences)
print(concatenated_df.iloc[21].labels)
# Out:
# Recommend clinical correlation . . CTH : My read , no acute bleed .
# O,O,O,O,O,O,O,O,O,O,O,O,O,O

# %%
def contains_ade(labels):
    return any('ADE' in label for label in labels.split(','))

ade_mask = concatenated_df['labels'].apply(contains_ade)

# Use the mask to filter the DataFrame
ade_sentences_df = concatenated_df[ade_mask]

# Display the filtered DataFrame
ade_sentences_df
# Out:
#                           text_file_name  \
# 60     data/training_20180910/100035.txt
# 84     data/training_20180910/100039.txt
# 92     data/training_20180910/100039.txt
# 145    data/training_20180910/100039.txt
# 149    data/training_20180910/100039.txt
# ...                                  ...
# 16647  data/training_20180910/196798.txt
# 16667  data/training_20180910/196798.txt
# 16699  data/training_20180910/197869.txt
# 16765  data/training_20180910/198406.txt
# 16766  data/training_20180910/198406.txt
#
#                                                sentences  \
# 60     being treated for infection . Since no new inf...
# 84     Right heart catheterization IR guided paracent...
# 92     OTHER MEDICAL HISTORY : - Embolic stroke in [ ...
# 145    anthracycline - induced cardiomyopathy ( EF 15...
# 149    She continued to have mild - moderate abdomina...
# ...                                                  ...
# 16647  . 3 ) Anuric renal failure : ATN likely from T...
# 16667  . 11 ) Rash : Patient noted to have morbillifo...
# 16699  flagyl and zosyn ) his WBC continues to rise w...
# 16765  evidence of acute focal pneumonia . Brief Hosp...
# 16766  . # Hypotension : Patient was found to be hypo...
#
#                                                   labels
# 60     O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 84     O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 92     O,O,O,O,O,B-Reason,I-Reason,O,O,O,O,O,O,O,O,O,...
# 145    B-Drug,O,O,B-ADE,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O...
# 149    O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# ...                                                  ...
# 16647  O,O,O,O,O,O,O,B-ADE,O,O,B-Drug,O,B-Drug,O,O,O,...
# 16667  O,O,O,B-ADE,O,O,O,O,O,B-ADE,I-ADE,O,O,O,O,O,O,...
# 16699  B-Drug,O,B-Drug,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 16765  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 16766  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
#
# [727 rows x 3 columns]

# %%
# concatenated_df.to_csv('/content/drive/MyDrive/266_final/data/concatenated_df.csv', index=False)
# concatenated_test.to_csv('/content/drive/MyDrive/266_final/data/concatenated_test.csv', index=False)

# %% [markdown]
# #### Comment this out if you want concatenated dataset.

# %%
# data = sentence_level_data.copy()
# data_test = sentence_level_test.copy()

# %% [markdown]
# #### Comment this out if you want sentence level dataset.

# %%
data = concatenated_df.copy()
data_test = concatenated_test.copy()

data.rename(columns={'concatenated_sentence': 'sentence', 'concatenated_labels': 'word_labels'}, inplace=True)
data_test.rename(columns={'concatenated_sentence': 'sentence', 'concatenated_labels': 'word_labels'}, inplace=True)

# %%
# from collections import Counter
# import pandas as pd

# # Assuming `df` is your DataFrame

# # Step 1: Concatenate all labels into a single list
# all_labels = []
# for labels_str in df['word_labels']:
#     labels_list = labels_str.split(',')
#     all_labels.extend(labels_list)  # Combine lists

# # Step 2: Count unique labels
# label_counts = Counter(all_labels)

# # Display the counts of each unique label
# label_counts

# %% [markdown]
# #### Double check the dataset you want.

# %%
# data = data.head(10000)
# data_test = data_test.head(10000)

# %%
data_test.head()
# Out:
#                     text_file_name  \
# 0  data/test_data_Task2/100130.txt
# 1  data/test_data_Task2/100130.txt
# 2  data/test_data_Task2/100130.txt
# 3  data/test_data_Task2/100130.txt
# 4  data/test_data_Task2/100130.txt
#
#                                            sentences  \
# 0  Admission Date : [ * * 2109 - 7 - 21 * * ] Dis...
# 1  with features of an oligodendroglioma who was ...
# 2  the night before admission which rapidly sprea...
# 3  PAST MEDICAL HISTORY : 1 . Hypercholesterolemi...
# 4  previously on Decadron q.i.d . tapered over on...
#
#                                               labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,B-Drug,O,O,B-Reason,I-Reason...
# 2  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4  O,O,B-Drug,B-Frequency,O,O,O,B-Duration,I-Dura...

# %% [markdown]
# ### It looks reasonable, let's proceed with training

# %%
### LOAD IF NECESSARY

# from transformers import AutoModelForTokenClassification, AutoTokenizer

# # Directory where the model and tokenizer are saved
# directory = "/content/drive/MyDrive/266_final/bert_base_cased_sentence_level"


# tokenizer = AutoTokenizer.from_pretrained(directory)

# model = AutoModelForTokenClassification.from_pretrained(directory)

# print('Model and tokenizer have been loaded.')

# %%
import os
from transformers import AutoTokenizer, AutoModelForTokenClassification

model = "emilyalsentzer/Bio_ClinicalBERT"  # Bio_ClinicalBERT model identifier
tokenizer = AutoTokenizer.from_pretrained(model)
model = AutoModelForTokenClassification.from_pretrained(model, num_labels=len(labels_to_ids))
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForMaskedLM

# tokenizer = AutoTokenizer.from_pretrained("microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext")
# model = AutoModelForMaskedLM.from_pretrained("microsoft/BiomedNLP-BiomedBERT-base-uncased-abstract-fulltext")

# %%
MAX_LEN = 512
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2
TEST_BATCH_SIZE = 32
EPOCHS = 3
LEARNING_RATE = 1e-05
MAX_GRAD_NORM = 10
# tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')

# %%
class dataset(Dataset):
  def __init__(self, dataframe, tokenizer, max_len):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

  def __getitem__(self, index):
        # step 1: get the sentence and word labels
        sentence = self.data.sentences[index].strip().split()
        word_labels = self.data.labels[index].split(",")
        # sentence_id = self.data.iloc[index]['sentence_id']

        # step 2: use tokenizer to encode sentence (includes padding/truncation up to max length)
        # BertTokenizerFast provides a handy "return_offsets_mapping" functionality for individual tokens
        encoding = self.tokenizer(sentence,
                             return_offsets_mapping=True,
                             padding='max_length',
                             is_split_into_words=True,
                             truncation=True,
                             max_length=self.max_len)

        # step 3: create token labels only for first word pieces of each tokenized word
        labels = [labels_to_ids[label] for label in word_labels]
        # code based on https://huggingface.co/transformers/custom_datasets.html#tok-ner
        # create an empty array of -100 of length max_length
        encoded_labels = np.ones(len(encoding["offset_mapping"]), dtype=int) * -100

        # set only labels whose first offset position is 0 and the second is not 0
        i = 0
        for idx, mapping in enumerate(encoding["offset_mapping"]):
          if mapping[0] == 0 and mapping[1] != 0:
            # overwrite label
            encoded_labels[idx] = labels[i]
            i += 1

        # step 4: turn everything into PyTorch tensors
        item = {key: torch.as_tensor(val) for key, val in encoding.items()}
        item['labels'] = torch.as_tensor(encoded_labels)
        # item['sentence_id'] = sentence_id

        return item

  def __len__(self):
        return self.len

# %%
# data[data['text_file_name']=='data/training_20180910/100035.txt']

# %%
# train_dataset.sort_values(by='sentence_id', inplace=True)

# %%
# from collections import Counter
# import pandas as pd

# # Assuming `df` is your DataFrame

# # Step 1: Concatenate all labels into a single list
# all_labels = []
# for labels_str in train_dataset['word_labels']:
#     labels_list = labels_str.split(',')
#     all_labels.extend(labels_list)  # Combine lists

# # Step 2: Count unique labels
# label_counts = Counter(all_labels)

# # Display the counts of each unique label
# label_counts

# %%
# train_dataset.iloc[0]['sentence']

# %%
# train_dataset.iloc[11244]['sentence']

# %%
# train_size = 0.8
# train_dataset = data.sample(frac=train_size,random_state=200, shuffle=True)
# val_dataset = data.drop(train_dataset.index).reset_index(drop=True)
# train_dataset = train_dataset.reset_index(drop=True)


# train_dataset.to_csv('/content/drive/MyDrive/266_final/data/train_dataset.csv', index=False)
# val_dataset.to_csv('/content/drive/MyDrive/266_final/data/val_dataset.csv', index=False)
# data_test.to_csv('/content/drive/MyDrive/266_final/data/test_dataset.csv', index=False)

# %%
# len(data)

# %%
from sklearn.model_selection import train_test_split

train_dataset, val_dataset = train_test_split(data, test_size=0.2, shuffle=False)

# %%
train_dataset.reset_index(drop=True, inplace=True)
val_dataset.reset_index(drop=True, inplace=True)

# %%
train_dataset.head()
# Out:
#                       text_file_name  \
# 0  data/training_20180910/100035.txt
# 1  data/training_20180910/100035.txt
# 2  data/training_20180910/100035.txt
# 3  data/training_20180910/100035.txt
# 4  data/training_20180910/100035.txt
#
#                                            sentences  \
# 0  Admission Date : [ * * 2115 - 2 - 22 * * ] Dis...
# 1  Attending : [ * * First Name3 ( LF ) 4891 * * ...
# 2  Removal of chest tubes placed at an outside ho...
# 3  to an OSH with dyspnea now admitted to the MIC...
# 4  and was intubated . He received epinephrine , ...
#
#                                               labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 2  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4  O,O,O,O,O,O,B-Drug,O,B-Drug,O,B-Drug,O,O,B-Dru...

# %%
print("FULL Dataet: {}".format(data.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("VAL Dataset: {}".format(val_dataset.shape))
print("TEST Dataset: {}".format(data_test.shape))

data_test.reset_index(drop=True, inplace=True)

training_set = dataset(train_dataset, tokenizer, MAX_LEN)
val_set = dataset(val_dataset, tokenizer, MAX_LEN)
test_set = dataset(data_test, tokenizer, MAX_LEN)
# Out:
# FULL Dataet: (16788, 3)
# TRAIN Dataset: (13430, 3)
# VAL Dataset: (3358, 3)
# TEST Dataset: (11146, 3)

# %%
for token, label in zip(tokenizer.convert_ids_to_tokens(training_set[3]["input_ids"]), training_set[3]["labels"]):
  print('{0:10}  {1}'.format(token, label))
# Out:
# [CLS]       -100
# to          18
# an          18
# o           18
# ##sh        -100
# with        18
# d           18
# ##ys        -100
# ##p         -100
# ##nea       -100
# now         18
# admitted    18
# to          18
# the         18
# mi          18
# ##cu        -100
# after       18
# p           18
# ##ea        -100
# arrest      18
# x           18
# ##2         -100
# .           18
# the         18
# patient     18
# initially   18
# presented   18
# to          18
# l           18
# ##gh        -100
# ed          18
# with        18
# h           18
# ##y         -100
# ##pox       -100
# ##em        -100
# ##ic        -100
# respiratory  18
# distress    18
# .           18
# while       18
# at          18
# the         18
# o           18
# ##sh        -100
# ,           18
# he          18
# received    18
# c           2
# ##t         -100
# ##x         -100
# ,           18
# a           2
# ##zi        -100
# ##th        -100
# ##rom       -100
# ##y         -100
# ##cin       -100
# ,           18
# s           7
# ##c         -100
# e           2
# ##pine      -100
# ##ph        -100
# ##rine      -100
# ,           18
# and         18
# so          2
# ##lume      -100
# ##dr        -100
# ##ol        -100
# .           18
# while       18
# at          18
# the         18
# o           18
# ##sh        -100
# ,           18
# he          18
# became      18
# confused    18
# and         18
# subsequently  18
# had         18
# an          18
# episode     18
# of          18
# p           18
# ##ea        -100
# arrest      18
# [SEP]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100
# [PAD]       -100

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

val_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': TEST_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }


training_loader = DataLoader(training_set, **train_params)
val_loader = DataLoader(val_set, **val_params)
test_loader = DataLoader(test_set, **test_params)

# %%
# model = BertForTokenClassification.from_pretrained('bert-base-cased', num_labels=len(labels_to_ids))
model.to(device)
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=19, bias=True)
# )

# %%
inputs = training_set[2]
input_ids = inputs["input_ids"].unsqueeze(0)
attention_mask = inputs["attention_mask"].unsqueeze(0)
labels = inputs["labels"].unsqueeze(0)

input_ids = input_ids.to(device)
attention_mask = attention_mask.to(device)
labels = labels.to(device)

outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
initial_loss = outputs[0]
initial_loss
# Out:
# tensor(3.1042, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
tr_logits = outputs[1]
tr_logits.shape
# Out:
# torch.Size([1, 512, 19])

# %%
# !pip install transformers==3.5.1

import torch.nn.functional as F


def focal_loss(logits, labels, alpha=0.25, gamma=2.0, ignore_index=-100):
    """
    logits: [batch_size, seq_len, num_labels] - model predictions
    labels: [batch_size, seq_len] - ground truth labels
    """
    # Calculate Cross Entropy Loss without reduction
    ce_loss = F.cross_entropy(logits.view(-1, logits.size(-1)), labels.view(-1), reduction='none', ignore_index=ignore_index)

    # Get the predictions
    pred_probs = F.softmax(logits.view(-1, logits.size(-1)), dim=-1)
    pred_class = labels.view(-1)

    # focusing parameter
    gamma = gamma

    # Filter out 'ignore_index' labels
    filtered = labels.view(-1) != ignore_index

    # Calculate focal loss
    ce_loss_filtered = ce_loss[filtered]
    pred_probs_filtered = pred_probs[filtered]
    pred_class_filtered = pred_class[filtered]

    # Construct the loss
    pt = pred_probs_filtered.gather(1, pred_class_filtered.unsqueeze(-1)).squeeze()
    loss = ((1 - pt) ** gamma * ce_loss_filtered).mean()  # mean over the batch

    return loss

# %%
optimizer = torch.optim.AdamW(params=model.parameters(), lr=LEARNING_RATE)

# %%
def train(epoch):
    tr_loss, tr_accuracy = 0, 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []

    model.train()

    for idx, batch in enumerate(training_loader):
        ids = batch['input_ids'].to(device, dtype=torch.long)
        mask = batch['attention_mask'].to(device, dtype=torch.long)
        labels = batch['labels'].to(device, dtype=torch.long)
    #     global_attention_mask = torch.zeros(
    # input_ids.shape, dtype=torch.long, device=input_ids.device

        # Perform a forward pass to get the logits
        outputs = model(input_ids=ids, attention_mask=mask)

        # Calculate the loss using focal_loss function directly
        loss = focal_loss(outputs.logits, labels)  # Use the focal_loss function here directly

        tr_loss += loss.item()
        nb_tr_steps += 1
        nb_tr_examples += labels.size(0)

        if idx % 100 == 0:
            loss_step = tr_loss / nb_tr_steps
            print(f"Training loss per 100 training steps: {loss_step}")

        # Decoding the logits to compute accuracy
        active_logits = outputs.logits.view(-1, model.num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1)

        # Ignoring the predictions of the padding tokens
        active_accuracy = labels.view(-1) != -100
        active_labels = torch.where(active_accuracy, labels.view(-1), torch.tensor(-100).type_as(labels))

        labels = torch.masked_select(active_labels, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_labels.extend(labels.cpu().numpy())
        tr_preds.extend(predictions.cpu().numpy())

        tmp_tr_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy

        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(parameters=model.parameters(), max_norm=MAX_GRAD_NORM)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    print(f"Training loss epoch: {epoch_loss}")
    print(f"Training accuracy epoch: {tr_accuracy}")

# %%
for epoch in range(EPOCHS):
    print(f"Training epoch: {epoch + 1}")
    train(epoch)
# Out:
# Training epoch: 1
# Training loss per 100 training steps: 2.8425018787384033
# Training loss per 100 training steps: 0.6463727346704443
# Training loss per 100 training steps: 0.42277706415735333
# Training loss per 100 training steps: 0.3163785307530462
# Training loss per 100 training steps: 0.26028489972496094
# Training loss per 100 training steps: 0.2249096211679991
# Training loss per 100 training steps: 0.20096153629211144
# Training loss per 100 training steps: 0.18109726229401574
# Training loss per 100 training steps: 0.16469221742797996
# Training loss per 100 training steps: 0.15245983330308413
# Training loss per 100 training steps: 0.14233275261676726
# Training loss per 100 training steps: 0.1341221071177297
# Training loss per 100 training steps: 0.12790781445224514
# Training loss per 100 training steps: 0.12164558449000695
# Training loss per 100 training steps: 0.116221555431198
# Training loss per 100 training steps: 0.11129661202454187
# Training loss per 100 training steps: 0.10676416370509313
# Training loss per 100 training steps: 0.1024523661978055
# Training loss per 100 training steps: 0.09875012937256061
# Training loss per 100 training steps: 0.09587885910691944
# Training loss per 100 training steps: 0.09256921630567821
# Training loss per 100 training steps: 0.08975961190619466
# Training loss per 100 training steps: 0.08734621485729398
# Training loss per 100 training steps: 0.08510666295982622
# Training loss per 100 training steps: 0.08282846373766976
# Training loss per 100 training steps: 0.08067691613585612
# Training loss per 100 training steps: 0.07859349262056785
# Training loss per 100 training steps: 0.07673964053628711
# Training loss per 100 training steps: 0.07497717021332674
# Training loss per 100 training steps: 0.0732197047639024
# Training loss per 100 training steps: 0.07190144716465043
# Training loss per 100 training steps: 0.07062937551043308
# Training loss per 100 training steps: 0.06938560580411095
# Training loss per 100 training steps: 0.06817704934836993
# Training loss epoch: 0.06752690267907932
# Training accuracy epoch: 0.9716989904722171
# Training epoch: 2
# Training loss per 100 training steps: 0.08943044394254684
# Training loss per 100 training steps: 0.026149480098064316
# Training loss per 100 training steps: 0.02530346821796813
# Training loss per 100 training steps: 0.02512015306179529
# Training loss per 100 training steps: 0.024834960846392345
# Training loss per 100 training steps: 0.02383361891187707
# Training loss per 100 training steps: 0.022852371489782742
# Training loss per 100 training steps: 0.02262738708022374
# Training loss per 100 training steps: 0.022501241786107785
# Training loss per 100 training steps: 0.022476636959404796
# Training loss per 100 training steps: 0.022955543981595213
# Training loss per 100 training steps: 0.022899302538601285
# Training loss per 100 training steps: 0.02288137683717423
# Training loss per 100 training steps: 0.022613939277121402
# Training loss per 100 training steps: 0.02268246650715663
# Training loss per 100 training steps: 0.022956212220632686
# Training loss per 100 training steps: 0.022964190050378277
# Training loss per 100 training steps: 0.0230042216415817
# Training loss per 100 training steps: 0.0231264456349821
# Training loss per 100 training steps: 0.02349325572013396
# Training loss per 100 training steps: 0.023379783314451688
# Training loss per 100 training steps: 0.023286463796117367
# Training loss per 100 training steps: 0.023145066154702472
# Training loss per 100 training steps: 0.023112430352733932
# Training loss per 100 training steps: 0.02301186138489339
# Training loss per 100 training steps: 0.022825423930308793
# Training loss per 100 training steps: 0.022642563620826194
# Training loss per 100 training steps: 0.02237657259046989
# Training loss per 100 training steps: 0.022363655905532655
# Training loss per 100 training steps: 0.022252475267818584
# Training loss per 100 training steps: 0.02231435298533107
# Training loss per 100 training steps: 0.022258146635799586
# Training loss per 100 training steps: 0.02223482990220046
# Training loss per 100 training steps: 0.022095361458836095
# Training loss epoch: 0.022133666843479415
# Training accuracy epoch: 0.9838482843245882
# Training epoch: 3
# Training loss per 100 training steps: 0.003339467803016305
# Training loss per 100 training steps: 0.015441168343836626
# Training loss per 100 training steps: 0.015095778407922622
# Training loss per 100 training steps: 0.014258658769318101
# Training loss per 100 training steps: 0.013621801757023815
# Training loss per 100 training steps: 0.013842814629122825
# Training loss per 100 training steps: 0.014019887626458808
# Training loss per 100 training steps: 0.014280999869244752
# Training loss per 100 training steps: 0.014683172358426498
# Training loss per 100 training steps: 0.01462114766491847
# Training loss per 100 training steps: 0.014612850887540111
# Training loss per 100 training steps: 0.014546636699819015
# Training loss per 100 training steps: 0.014599033319563621
# Training loss per 100 training steps: 0.014524457054329616
# Training loss per 100 training steps: 0.014523205758865933
# Training loss per 100 training steps: 0.014670594936520747
# Training loss per 100 training steps: 0.014780535933958476
# Training loss per 100 training steps: 0.01501383652376775
# Training loss per 100 training steps: 0.015148180402983887
# Training loss per 100 training steps: 0.015207579354874049
# Training loss per 100 training steps: 0.01519268559905581
# Training loss per 100 training steps: 0.015367779001808845
# Training loss per 100 training steps: 0.015291140042084895
# Training loss per 100 training steps: 0.015290780942601105
# Training loss per 100 training steps: 0.015290888800605635
# Training loss per 100 training steps: 0.015216393761261016
# Training loss per 100 training steps: 0.015225186846754881
# Training loss per 100 training steps: 0.015166480316115496
# Training loss per 100 training steps: 0.0152145512175473
# Training loss per 100 training steps: 0.015168607767351275
# Training loss per 100 training steps: 0.015226092666200784
# Training loss per 100 training steps: 0.015165885006618916
# Training loss per 100 training steps: 0.01511873756463285
# Training loss per 100 training steps: 0.015154651570798131
# Training loss epoch: 0.015152914781624258
# Training accuracy epoch: 0.9871542617517303

# %%
def valid(model, testing_loader):
    model.eval()
    eval_loss, eval_accuracy = 0, 0

    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []

    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):
            ids = batch['input_ids'].to(device, dtype=torch.long)
            mask = batch['attention_mask'].to(device, dtype=torch.long)
            labels = batch['labels'].to(device, dtype=torch.long)
            # sentence_ids = batch['sentence_id']

            outputs = model(input_ids=ids, attention_mask=mask)
            loss = focal_loss(outputs.logits, labels)  # Use the same focal_loss function

            eval_loss += loss.item()
            nb_eval_steps += 1
            nb_eval_examples += labels.size(0)

            if idx % 100 == 0:
                loss_step = eval_loss / nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")

            # Decoding the logits to compute accuracy
            active_logits = outputs.logits.view(-1, model.num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1)

            # Ignoring the predictions of the padding tokens
            active_accuracy = labels.view(-1) != -100
            active_labels = torch.where(active_accuracy, labels.view(-1), torch.tensor(-100).type_as(labels))

            labels = torch.masked_select(active_labels, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)

            eval_labels.extend(labels.cpu().numpy())
            eval_preds.extend(predictions.cpu().numpy())

            tmp_eval_accuracy = accuracy_score(labels.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy

            # sentence_ids_list.extend(sentence_ids)



    labels = [ids_to_labels[id.item()] for id in eval_labels]
    predictions = [ids_to_labels[id.item()] for id in eval_preds]

    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    print(f"Validation Loss: {eval_loss}")
    print(f"Validation Accuracy: {eval_accuracy}")

    return labels, predictions

# %%
labels, predictions = valid(model, val_loader)
# Out:
# Validation loss per 100 evaluation steps: 0.005812683142721653
# Validation loss per 100 evaluation steps: 0.029902314047198574
# Validation loss per 100 evaluation steps: 0.029637827443586992
# Validation loss per 100 evaluation steps: 0.030716734786596138
# Validation loss per 100 evaluation steps: 0.03146203292717865
# Validation loss per 100 evaluation steps: 0.02985226105792214
# Validation loss per 100 evaluation steps: 0.02920594221620661
# Validation loss per 100 evaluation steps: 0.028510840986541067
# Validation loss per 100 evaluation steps: 0.029072611333780227
# Validation loss per 100 evaluation steps: 0.030129624426010856
# Validation loss per 100 evaluation steps: 0.030498732567249026
# Validation loss per 100 evaluation steps: 0.031316674119287215
# Validation loss per 100 evaluation steps: 0.031505375459210276
# Validation loss per 100 evaluation steps: 0.0317758949351076
# Validation loss per 100 evaluation steps: 0.03205072348063346
# Validation loss per 100 evaluation steps: 0.03214698020615042
# Validation loss per 100 evaluation steps: 0.03284987005888358
# Validation Loss: 0.03256771052262163
# Validation Accuracy: 0.9783181811439102

# %%
from seqeval.metrics import classification_report

print(classification_report([labels], [predictions]))
# Out:
#               precision    recall  f1-score   support
#
#          ADE       0.32      0.45      0.37       165
#       Dosage       0.85      0.91      0.88       782
#         Drug       0.88      0.93      0.91      3216
#     Duration       0.66      0.79      0.72       120
#         Form       0.87      0.88      0.88      1269
#    Frequency       0.79      0.83      0.81      1270
#       Reason       0.56      0.68      0.61       698
#        Route       0.90      0.93      0.92      1143
#     Strength       0.93      0.93      0.93      1341
#
#    micro avg       0.83      0.88      0.86     10004
#    macro avg       0.75      0.81      0.78     10004
# weighted avg       0.84      0.88      0.86     10004

# %% [markdown]
# ## Evaluation
#
#  - convert val set back to word level

# %%
# split the sentence by space and expand into separate columns
split_df_label = val_dataset['labels'].str.split(',', expand=True)

# Stack the split words into a single column, dropping NaN values automatically
val_labels = split_df_label.stack().reset_index(level=1, drop=True).reset_index()

# Rename the columns
val_labels.columns = ['original_row_index', 'label']

val_labels.head()
# Out:
#    original_row_index label
# 0                   0     O
# 1                   0     O
# 2                   0     O
# 3                   0     O
# 4                   0     O

# %%
len(val_dataset)
# Out:
# 3358

# %%
# split the sentence by space and expand into separate columns
split_dfl = val_dataset['sentences'].str.split(',', expand=True)

# Stack the split words into a single column, dropping NaN values automatically
val_sent = split_df.stack().reset_index(level=1, drop=True).reset_index()

# Rename the columns
val_sent.columns = ['original_row_index', 'word']

val_sent.head()
# Out:
#    original_row_index       word
# 0                   0  Admission
# 1                   0       Date
# 2                   0          :
# 3                   0          [
# 4                   0          *

# %%
val_sent['preds'] = predictions
val_sent['labels_pp'] = labels
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-f4ccd13f9175> in <cell line: 1>()
# ----> 1 val_sent['preds'] = predictions
#       2 val_sent['labels_pp'] = labels
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4141         ensure homogeneity.
#    4142         """
# -> 4143         value = self._sanitize_column(value)
#    4144
#    4145         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4868
#    4869         if is_list_like(value):
# -> 4870             com.require_length_match(value, self.index)
#    4871         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4872
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     574     """
#     575     if len(data) != len(index):
# --> 576         raise ValueError(
#     577             "Length of values "
#     578             f"({len(data)}) "
#
# ValueError: Length of values (176679) does not match length of index (585761)

# %%
# merged = pd.concat([val_words, val_labels], axis=1)
# Out:
#    original_row_index       word  original_row_index label
# 0                   0  Admission                   0     O
# 1                   0       Date                   0     O
# 2                   0          :                   0     O
# 3                   0          [                   0     O
# 4                   0          *                   0     O

# %%
# merged['preds'] = test_predictions
# merged['labels_pp'] = test_labels

# %%
# merged[merged['preds'] == 'B-Drug']

# %%
# test['sentence'].iloc[0]

# %%
test_labels, test_predictions = valid(model, test_loader)
# Out:
# Validation loss per 100 evaluation steps: 0.010770902968943119
# Validation loss per 100 evaluation steps: 0.02729300238505596
# Validation loss per 100 evaluation steps: 0.02737924360336541
# Validation loss per 100 evaluation steps: 0.026840517346119117
# Validation Loss: 0.026870437326005803
# Validation Accuracy: 0.9811775172745457

# %%
from seqeval.metrics import classification_report

print(classification_report([test_labels], [test_predictions]))
# Out:
#               precision    recall  f1-score   support
#
#          ADE       0.42      0.50      0.46       634
#       Dosage       0.89      0.93      0.91      2703
#         Drug       0.91      0.94      0.93     10594
#     Duration       0.64      0.73      0.69       385
#         Form       0.91      0.92      0.91      4373
#    Frequency       0.83      0.86      0.84      4155
#       Reason       0.54      0.60      0.57      2561
#        Route       0.91      0.95      0.93      3513
#     Strength       0.95      0.95      0.95      4237
#
#    micro avg       0.86      0.89      0.88     33155
#    macro avg       0.78      0.82      0.80     33155
# weighted avg       0.86      0.89      0.88     33155

# %%
sentence_predictions = []


start_idx = 0
for index, row in data_test.iterrows():
    # Number of labels in the sentence
    num_labels = len(row['word_labels'].split(','))
    # Segment predictions corresponding to the current sentence
    sentence_pred = predictions[start_idx:start_idx + num_labels]
    # Append to our list
    sentence_predictions.append(','.join(sentence_pred))
    # Update start index for next iteration
    start_idx += num_labels

# Assigning segmented predictions back to DataFrame
data_test['predicted_labels'] = sentence_predictions

data_test.head()
# Out:
#   sentence_id                   text_file_name  \
# 0      sent_0  data/test_data_Task2/100130.txt
# 1      sent_1  data/test_data_Task2/100130.txt
# 2      sent_2  data/test_data_Task2/100130.txt
# 3      sent_3  data/test_data_Task2/100130.txt
# 4      sent_4  data/test_data_Task2/100130.txt
#
#                                             sentence  \
# 0  Admission Date : [ * * 2109 - 7 - 21 * * ] Dis...
# 1  with features of an oligodendroglioma who was ...
# 2  the night before admission which rapidly sprea...
# 3  PAST MEDICAL HISTORY : 1 . Hypercholesterolemi...
# 4  previously on Decadron q.i.d . tapered over on...
#
#                                          word_labels  \
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,B-Drug,O,O,B-Reason,I-Reason...
# 2  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4  O,O,B-Drug,B-Frequency,O,O,O,B-Duration,I-Dura...
#
#                                     predicted_labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,B-Re...
# 2  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,B-Do...
# 4  O,O,B-Drug,O,B-Drug,O,O,O,O,O,O,O,O,O,O,O,O,O,...

# %%
from collections import defaultdict

# Adjust the dictionary to hold tuples of (word, sentence_id)
misclassified_words_with_ids = defaultdict(list)

for _, row in data_test.iterrows():
    true_labels = row['word_labels'].split(',')
    pred_labels = row['predicted_labels'].split(',')
    words = row['sentence'].split()  # Assuming words are space-separated
    sentence_id = row['sentence_id']  # Capture the sentence ID

    # Ensure the lists are of the same length; this might need adjusting depending on your data's preprocessing
    assert len(true_labels) == len(pred_labels) == len(words), "Length mismatch between words and labels"

    for true_label, pred_label, word in zip(true_labels, pred_labels, words):
        if true_label != pred_label:  # Word is misclassified
            key = (true_label, pred_label)
            # Now append a tuple of (word, sentence_id)
            misclassified_words_with_ids[key].append((word, sentence_id))

# At this point, `misclassified_words_with_ids` contains information about misclassified words along with their sentence IDs

# %%
# Example: Print misclassified words for each label pair, along with sentence IDs
for label_pair, word_id_pairs in misclassified_words_with_ids.items():
    print(f"True label: {label_pair[0]}, Predicted label: {label_pair[1]}")
    for word, sentence_id in word_id_pairs:
        print(f"  Word: '{word}' in Sentence ID: {sentence_id}")
    print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#   Word: '20' in Sentence ID: sent_10853
#
#
# True label: B-Reason, Predicted label: I-Frequency
#   Word: 'SCC' in Sentence ID: sent_249
#   Word: 'diuresing' in Sentence ID: sent_311
#   Word: 'edematous' in Sentence ID: sent_376
#   Word: 'solid' in Sentence ID: sent_379
#   Word: 'Clostridium' in Sentence ID: sent_380
#   Word: 'pain.' in Sentence ID: sent_385
#   Word: 'bloody' in Sentence ID: sent_910
#   Word: 'constipation.' in Sentence ID: sent_1291
#   Word: 'line' in Sentence ID: sent_2664
#   Word: 'hypertension' in Sentence ID: sent_3205
#   Word: 'constipation' in Sentence ID: sent_3396
#   Word: 'Steroid' in Sentence ID: sent_3536
#   Word: 'anxiety' in Sentence ID: sent_3550
#   Word: 'wheezing' in Sentence ID: sent_3669
#   Word: 'COPD' in Sentence ID: sent_4056
#   Word: 'Fibromyalgia' in Sentence ID: sent_4062
#   Word: 'atrial' in Sentence ID: sent_4627
#   Word: 'dyspnea' in Sentence ID: sent_4871
#   Word: 'aspiration' in Sentence ID: sent_5078
#   Word: 'Pseudomonas' in Sentence ID: sent_5205
#   Word: 'multifocal' in Sentence ID: sent_5439
#   Word: 'anxiety' in Sentence ID: sent_5737
#   Word: 'h/o' in Sentence ID: sent_5824
#   Word: 'slow' in Sentence ID: sent_5940
#   Word: 'sleep' in Sentence ID: sent_6297
#   Word: 'hypotensive' in Sentence ID: sent_6768
#   Word: 'hyperkalemia' in Sentence ID: sent_6955
#   Word: 'hypotensive' in Sentence ID: sent_7266
#   Word: 'Right' in Sentence ID: sent_7629
#   Word: 'blood' in Sentence ID: sent_7758
#   Word: 'her' in Sentence ID: sent_8050
#   Word: 'HTN' in Sentence ID: sent_8750
#   Word: 'somnolence' in Sentence ID: sent_8908
#   Word: 'COPD' in Sentence ID: sent_9052
#   Word: 'PVD' in Sentence ID: sent_9151
#   Word: 'stent' in Sentence ID: sent_9151
#   Word: 'Cystitis' in Sentence ID: sent_9263
#   Word: 'pain' in Sentence ID: sent_9366
#   Word: 'cough' in Sentence ID: sent_9453
#   Word: 'mildly' in Sentence ID: sent_9698
#   Word: 'mechanical' in Sentence ID: sent_9803
#
#
# True label: I-Reason, Predicted label: I-Frequency
#   Word: 'of' in Sentence ID: sent_249
#   Word: 'lung' in Sentence ID: sent_249
#   Word: 'tumors' in Sentence ID: sent_379
#   Word: 'difficile' in Sentence ID: sent_380
#   Word: 'Colitis' in Sentence ID: sent_380
#   Word: 'your' in Sentence ID: sent_726
#   Word: 'heart' in Sentence ID: sent_726
#   Word: 'pump' in Sentence ID: sent_726
#   Word: 'better.' in Sentence ID: sent_726
#   Word: 'stool' in Sentence ID: sent_910
#   Word: 'pericarditis' in Sentence ID: sent_1865
#   Word: 'stroke' in Sentence ID: sent_2526
#   Word: 'at' in Sentence ID: sent_2586
#   Word: 'triage' in Sentence ID: sent_2586
#   Word: 'induced' in Sentence ID: sent_3536
#   Word: 'control' in Sentence ID: sent_4646
#   Word: 'pneumonia' in Sentence ID: sent_5078
#   Word: 'pneumonia' in Sentence ID: sent_5205
#   Word: 'pneumonia' in Sentence ID: sent_5439
#   Word: 'DVT' in Sentence ID: sent_5824
#   Word: 'infarct' in Sentence ID: sent_6768
#   Word: 'Lower' in Sentence ID: sent_7629
#   Word: 'Extremity' in Sentence ID: sent_7629
#   Word: 'DVT' in Sentence ID: sent_7629
#   Word: 'pressure' in Sentence ID: sent_7758
#   Word: 'DVT' in Sentence ID: sent_8050
#   Word: 'placement' in Sentence ID: sent_9151
#   Word: 'fibrillation' in Sentence ID: sent_9407
#   Word: 'with' in Sentence ID: sent_9407
#   Word: 'RVR' in Sentence ID: sent_9407
#   Word: 'aortic' in Sentence ID: sent_9803
#   Word: 'valve' in Sentence ID: sent_9803
#   Word: 'Difficile' in Sentence ID: sent_10041
#   Word: 'Colitis' in Sentence ID: sent_10041
#
#
# True label: I-Frequency, Predicted label: B-Dosage
#   Word: '24' in Sentence ID: sent_279
#   Word: ')' in Sentence ID: sent_716
#   Word: 'as' in Sentence ID: sent_967
#   Word: 'needed' in Sentence ID: sent_1123
#   Word: 'as.' in Sentence ID: sent_1356
#   Word: 'Daily' in Sentence ID: sent_1874
#   Word: 'hours' in Sentence ID: sent_1939
#   Word: 'a' in Sentence ID: sent_2235
#   Word: ')' in Sentence ID: sent_2283
#   Word: 'as' in Sentence ID: sent_2352
#   Word: 'Daily' in Sentence ID: sent_2407
#   Word: '-' in Sentence ID: sent_2764
#   Word: '6' in Sentence ID: sent_2766
#   Word: 'day' in Sentence ID: sent_2831
#   Word: 'Hours' in Sentence ID: sent_3278
#   Word: '(' in Sentence ID: sent_3331
#   Word: 'DAY.' in Sentence ID: sent_3332
#   Word: 'hours' in Sentence ID: sent_3336
#   Word: '(' in Sentence ID: sent_3476
#   Word: ')' in Sentence ID: sent_3669
#   Word: '16' in Sentence ID: sent_3669
#   Word: 'day' in Sentence ID: sent_4194
#   Word: '6' in Sentence ID: sent_4261
#   Word: 'a' in Sentence ID: sent_4262
#   Word: 'a.' in Sentence ID: sent_4262
#   Word: ')' in Sentence ID: sent_4737
#   Word: 'a' in Sentence ID: sent_5102
#   Word: 'as' in Sentence ID: sent_5180
#   Word: 'Daily' in Sentence ID: sent_6195
#   Word: 'day' in Sentence ID: sent_6202
#   Word: '(' in Sentence ID: sent_6297
#   Word: 'a' in Sentence ID: sent_6492
#   Word: '(' in Sentence ID: sent_6686
#   Word: '6' in Sentence ID: sent_6805
#   Word: 'day' in Sentence ID: sent_6805
#   Word: '(' in Sentence ID: sent_7588
#   Word: 'Daily' in Sentence ID: sent_7885
#   Word: ')' in Sentence ID: sent_8103
#   Word: 'day' in Sentence ID: sent_8450
#   Word: 'hours' in Sentence ID: sent_9202
#   Word: 'four' in Sentence ID: sent_9366
#   Word: '(' in Sentence ID: sent_9453
#   Word: 'needed' in Sentence ID: sent_9499
#   Word: 'Daily' in Sentence ID: sent_10183
#   Word: '..' in Sentence ID: sent_10429
#   Word: 'as.' in Sentence ID: sent_10432
#   Word: '6' in Sentence ID: sent_10855
#
#
# True label: I-Frequency, Predicted label: I-Dosage
#   Word: 'hours' in Sentence ID: sent_279
#   Word: 'a' in Sentence ID: sent_284
#   Word: 'times' in Sentence ID: sent_323
#   Word: 'a' in Sentence ID: sent_323
#   Word: 'day' in Sentence ID: sent_323
#   Word: '-' in Sentence ID: sent_766
#   Word: '6H' in Sentence ID: sent_766
#   Word: '(' in Sentence ID: sent_766
#   Word: '(' in Sentence ID: sent_972
#   Word: '2.' in Sentence ID: sent_972
#   Word: 'times' in Sentence ID: sent_972
#   Word: ':' in Sentence ID: sent_1037
#   Word: 'PRN' in Sentence ID: sent_1037
#   Word: 'morning' in Sentence ID: sent_1233
#   Word: 'needed' in Sentence ID: sent_1356
#   Word: '.' in Sentence ID: sent_1801
#   Word: ')' in Sentence ID: sent_1874
#   Word: ')' in Sentence ID: sent_1939
#   Word: 'as' in Sentence ID: sent_1939
#   Word: 'needed' in Sentence ID: sent_1939
#   Word: 'needed' in Sentence ID: sent_2352
#   Word: '8' in Sentence ID: sent_2764
#   Word: 'prn.' in Sentence ID: sent_2764
#   Word: 'or' in Sentence ID: sent_2831
#   Word: 'as' in Sentence ID: sent_2831
#   Word: 'directed.' in Sentence ID: sent_2831
#   Word: ')' in Sentence ID: sent_3278
#   Word: '-' in Sentence ID: sent_3330
#   Word: '2.' in Sentence ID: sent_3331
#   Word: 'times' in Sentence ID: sent_3331
#   Word: 'a' in Sentence ID: sent_3331
#   Word: '(' in Sentence ID: sent_3332
#   Word: 'Every' in Sentence ID: sent_3332
#   Word: 'Other' in Sentence ID: sent_3332
#   Word: 'as' in Sentence ID: sent_3336
#   Word: 'needed' in Sentence ID: sent_3336
#   Word: '(' in Sentence ID: sent_3398
#   Word: 'Daily' in Sentence ID: sent_3398
#   Word: ')' in Sentence ID: sent_3398
#   Word: 'Daily' in Sentence ID: sent_3476
#   Word: ':' in Sentence ID: sent_3669
#   Word: 'needed' in Sentence ID: sent_4124
#   Word: 'hours' in Sentence ID: sent_4261
#   Word: ')' in Sentence ID: sent_4261
#   Word: 'as' in Sentence ID: sent_4261
#   Word: 'day' in Sentence ID: sent_4262
#   Word: ')' in Sentence ID: sent_4262
#   Word: 'day' in Sentence ID: sent_4262
#   Word: '(' in Sentence ID: sent_4819
#   Word: '(' in Sentence ID: sent_4957
#   Word: 'day' in Sentence ID: sent_5102
#   Word: '..' in Sentence ID: sent_5213
#   Word: '(' in Sentence ID: sent_5287
#   Word: '(' in Sentence ID: sent_6152
#   Word: 'at' in Sentence ID: sent_6152
#   Word: 'bedtime' in Sentence ID: sent_6152
#   Word: '(' in Sentence ID: sent_6152
#   Word: ')' in Sentence ID: sent_6195
#   Word: 'prn.' in Sentence ID: sent_6255
#   Word: '(' in Sentence ID: sent_6297
#   Word: '2.' in Sentence ID: sent_6297
#   Word: 'every' in Sentence ID: sent_6297
#   Word: '4' in Sentence ID: sent_6297
#   Word: 'hours' in Sentence ID: sent_6297
#   Word: 'day' in Sentence ID: sent_6492
#   Word: 'a' in Sentence ID: sent_6493
#   Word: 'day' in Sentence ID: sent_6493
#   Word: '2.' in Sentence ID: sent_6686
#   Word: 'times' in Sentence ID: sent_6687
#   Word: 'a' in Sentence ID: sent_6687
#   Word: 'hours' in Sentence ID: sent_6805
#   Word: ')' in Sentence ID: sent_6805
#   Word: ')' in Sentence ID: sent_6805
#   Word: '(' in Sentence ID: sent_7022
#   Word: '2.' in Sentence ID: sent_7022
#   Word: '(' in Sentence ID: sent_7024
#   Word: 'at' in Sentence ID: sent_7588
#   Word: 'bedtime' in Sentence ID: sent_7588
#   Word: ')' in Sentence ID: sent_7588
#   Word: ')' in Sentence ID: sent_7885
#   Word: 'a' in Sentence ID: sent_7890
#   Word: '.' in Sentence ID: sent_9003
#   Word: ')' in Sentence ID: sent_9202
#   Word: 'as' in Sentence ID: sent_9202
#   Word: 'needed' in Sentence ID: sent_9202
#   Word: '(' in Sentence ID: sent_9366
#   Word: '4' in Sentence ID: sent_9366
#   Word: ')' in Sentence ID: sent_9366
#   Word: 'every' in Sentence ID: sent_9453
#   Word: '6' in Sentence ID: sent_9453
#   Word: 'hours' in Sentence ID: sent_9453
#   Word: '(' in Sentence ID: sent_9454
#   Word: 'as' in Sentence ID: sent_9454
#   Word: 'needed' in Sentence ID: sent_9454
#   Word: '(' in Sentence ID: sent_10089
#   Word: '3' in Sentence ID: sent_10089
#   Word: ')' in Sentence ID: sent_10183
#   Word: 'hours' in Sentence ID: sent_10855
#   Word: ')' in Sentence ID: sent_10855
#   Word: 'as.' in Sentence ID: sent_10855
#
#
# True label: B-Dosage, Predicted label: B-Drug
#   Word: 'One' in Sentence ID: sent_281
#   Word: '500cc' in Sentence ID: sent_506
#   Word: 'One' in Sentence ID: sent_568
#   Word: 'Two' in Sentence ID: sent_620
#   Word: '1U' in Sentence ID: sent_630
#   Word: 'One' in Sentence ID: sent_765
#   Word: 'One' in Sentence ID: sent_766
#   Word: 'One' in Sentence ID: sent_837
#   Word: 'taper' in Sentence ID: sent_957
#   Word: 'Two' in Sentence ID: sent_972
#   Word: 'One' in Sentence ID: sent_1292
#   Word: 'One' in Sentence ID: sent_1356
#   Word: '1' in Sentence ID: sent_1720
#   Word: 'One' in Sentence ID: sent_2094
#   Word: 'Two' in Sentence ID: sent_2212
#   Word: 'One' in Sentence ID: sent_2352
#   Word: 'One' in Sentence ID: sent_2467
#   Word: '12' in Sentence ID: sent_2825
#   Word: 'One' in Sentence ID: sent_3010
#   Word: 'liter.' in Sentence ID: sent_3164
#   Word: 'One' in Sentence ID: sent_3276
#   Word: 'One' in Sentence ID: sent_3332
#   Word: '1' in Sentence ID: sent_3654
#   Word: 'One' in Sentence ID: sent_3807
#   Word: '4' in Sentence ID: sent_4075
#   Word: 'tapered' in Sentence ID: sent_4177
#   Word: '0.5' in Sentence ID: sent_4886
#   Word: '4L' in Sentence ID: sent_4907
#   Word: 'One' in Sentence ID: sent_5500
#   Word: '0.5' in Sentence ID: sent_5834
#   Word: '2' in Sentence ID: sent_6014
#   Word: 'One' in Sentence ID: sent_6037
#   Word: 'One' in Sentence ID: sent_6152
#   Word: '1' in Sentence ID: sent_6194
#   Word: 'Nine' in Sentence ID: sent_6194
#   Word: 'One' in Sentence ID: sent_6259
#   Word: 'Three' in Sentence ID: sent_6358
#   Word: 'One' in Sentence ID: sent_6490
#   Word: '15' in Sentence ID: sent_6936
#   Word: 'Two' in Sentence ID: sent_7021
#   Word: 'Two' in Sentence ID: sent_7967
#   Word: '2' in Sentence ID: sent_8388
#   Word: '1.5' in Sentence ID: sent_8391
#   Word: '1.5' in Sentence ID: sent_8670
#   Word: 'One' in Sentence ID: sent_9201
#   Word: 'One' in Sentence ID: sent_9204
#   Word: 'One' in Sentence ID: sent_9452
#   Word: '1' in Sentence ID: sent_9613
#   Word: 'Two' in Sentence ID: sent_9832
#   Word: 'sliding' in Sentence ID: sent_10089
#   Word: '0.5' in Sentence ID: sent_10364
#   Word: 'One' in Sentence ID: sent_10425
#   Word: 'One' in Sentence ID: sent_10639
#   Word: 'One' in Sentence ID: sent_10640
#   Word: 'Two' in Sentence ID: sent_10854
#
#
# True label: B-Form, Predicted label: B-ADE
#   Word: 'Tablet' in Sentence ID: sent_281
#   Word: 'Tablet' in Sentence ID: sent_1489
#   Word: 'Tablet' in Sentence ID: sent_2235
#   Word: 'sprays' in Sentence ID: sent_7019
#   Word: 'Mouthwash' in Sentence ID: sent_7589
#   Word: 'Tablet' in Sentence ID: sent_8865
#   Word: 'drop' in Sentence ID: sent_8920
#   Word: 'Tablet' in Sentence ID: sent_8985
#   Word: 'Tablet' in Sentence ID: sent_10274
#
#
# True label: B-Route, Predicted label: B-Drug
#   Word: 'PO' in Sentence ID: sent_281
#   Word: 'IV' in Sentence ID: sent_384
#   Word: 'Subcutaneous.' in Sentence ID: sent_567
#   Word: 'IV.' in Sentence ID: sent_735
#   Word: 'nasal' in Sentence ID: sent_953
#   Word: 'PO' in Sentence ID: sent_969
#   Word: 'PO' in Sentence ID: sent_969
#   Word: 'IV' in Sentence ID: sent_1221
#   Word: 'PO' in Sentence ID: sent_1356
#   Word: 'PO' in Sentence ID: sent_1551
#   Word: 'PO' in Sentence ID: sent_1646
#   Word: 'PO' in Sentence ID: sent_1648
#   Word: 'IV' in Sentence ID: sent_1891
#   Word: 'PO' in Sentence ID: sent_1940
#   Word: 'PO' in Sentence ID: sent_1941
#   Word: 'PO' in Sentence ID: sent_2211
#   Word: 'PO' in Sentence ID: sent_2832
#   Word: 'PO' in Sentence ID: sent_2833
#   Word: 'Subcutaneous' in Sentence ID: sent_2838
#   Word: 'PO' in Sentence ID: sent_3014
#   Word: 'PO' in Sentence ID: sent_3088
#   Word: 'po' in Sentence ID: sent_3788
#   Word: 'IV' in Sentence ID: sent_4003
#   Word: 'PO' in Sentence ID: sent_4070
#   Word: 'Topical' in Sentence ID: sent_4257
#   Word: 'PO' in Sentence ID: sent_4291
#   Word: 'IV' in Sentence ID: sent_4438
#   Word: 'Injection' in Sentence ID: sent_4737
#   Word: 'PO' in Sentence ID: sent_4809
#   Word: 'PO' in Sentence ID: sent_4819
#   Word: 'nasal' in Sentence ID: sent_4899
#   Word: 'IV' in Sentence ID: sent_5089
#   Word: 'PO' in Sentence ID: sent_5449
#   Word: 'PO' in Sentence ID: sent_5622
#   Word: 'SC' in Sentence ID: sent_5825
#   Word: 'PO' in Sentence ID: sent_5834
#   Word: 'subcutaneously' in Sentence ID: sent_5836
#   Word: 'NC' in Sentence ID: sent_6014
#   Word: 'PO' in Sentence ID: sent_6043
#   Word: 'PO' in Sentence ID: sent_6149
#   Word: 'PO' in Sentence ID: sent_6149
#   Word: 'PO' in Sentence ID: sent_6194
#   Word: 'PO' in Sentence ID: sent_6296
#   Word: 'lip.' in Sentence ID: sent_6540
#   Word: 'PO' in Sentence ID: sent_6686
#   Word: 'drip' in Sentence ID: sent_6730
#   Word: 'PO' in Sentence ID: sent_6803
#   Word: 'PO' in Sentence ID: sent_7021
#   Word: 'PO' in Sentence ID: sent_7457
#   Word: 'PO' in Sentence ID: sent_7458
#   Word: 'Mucous' in Sentence ID: sent_7589
#   Word: 'drip' in Sentence ID: sent_7755
#   Word: 'PO.' in Sentence ID: sent_7889
#   Word: 'PO' in Sentence ID: sent_7966
#   Word: 'PO.' in Sentence ID: sent_8201
#   Word: 'drips' in Sentence ID: sent_8483
#   Word: 'PO' in Sentence ID: sent_8671
#   Word: 'PO' in Sentence ID: sent_8730
#   Word: 'gtt' in Sentence ID: sent_8740
#   Word: 'PO' in Sentence ID: sent_8818
#   Word: 'PO' in Sentence ID: sent_8975
#   Word: 'PO' in Sentence ID: sent_9128
#   Word: 'Topical' in Sentence ID: sent_9201
#   Word: 'Ophthalmic' in Sentence ID: sent_9452
#   Word: 'PO' in Sentence ID: sent_9619
#   Word: 'by' in Sentence ID: sent_9754
#   Word: 'Subcutaneous' in Sentence ID: sent_9832
#   Word: 'by' in Sentence ID: sent_9868
#   Word: 'PO' in Sentence ID: sent_10076
#   Word: 'PO' in Sentence ID: sent_10079
#   Word: 'PO' in Sentence ID: sent_10081
#   Word: 'PO' in Sentence ID: sent_10264
#   Word: 'PO' in Sentence ID: sent_10364
#   Word: 'by.' in Sentence ID: sent_10423
#   Word: 'PO' in Sentence ID: sent_10431
#   Word: 'Buccal' in Sentence ID: sent_10433
#   Word: 'SQ' in Sentence ID: sent_10763
#   Word: 'by' in Sentence ID: sent_10895
#
#
# True label: B-Form, Predicted label: B-Drug
#   Word: 'Tablet' in Sentence ID: sent_284
#   Word: 'Tablet' in Sentence ID: sent_716
#   Word: 'Tablet' in Sentence ID: sent_1158
#   Word: 'HFA' in Sentence ID: sent_1544
#   Word: 'Tablet' in Sentence ID: sent_1545
#   Word: 'Tablet' in Sentence ID: sent_2212
#   Word: 'Tablet' in Sentence ID: sent_2234
#   Word: 'Tablet' in Sentence ID: sent_2469
#   Word: 'Tablet' in Sentence ID: sent_2765
#   Word: 'Tablet' in Sentence ID: sent_2765
#   Word: 'Tablet' in Sentence ID: sent_3088
#   Word: 'Tablet' in Sentence ID: sent_3088
#   Word: 'Tablet' in Sentence ID: sent_3273
#   Word: 'Tablet' in Sentence ID: sent_3329
#   Word: 'Capsule' in Sentence ID: sent_3331
#   Word: 'Tablet' in Sentence ID: sent_3333
#   Word: 'Tablet' in Sentence ID: sent_3468
#   Word: 'Capsule' in Sentence ID: sent_3470
#   Word: 'Tablet' in Sentence ID: sent_3474
#   Word: 'Tablet' in Sentence ID: sent_3477
#   Word: 'neb.' in Sentence ID: sent_3668
#   Word: 'Tablet' in Sentence ID: sent_3866
#   Word: 'Tablet' in Sentence ID: sent_3907
#   Word: 'Tablet' in Sentence ID: sent_3951
#   Word: 'pills' in Sentence ID: sent_4075
#   Word: 'Capsule' in Sentence ID: sent_4129
#   Word: 'Capsule' in Sentence ID: sent_4194
#   Word: 'Capsule' in Sentence ID: sent_4261
#   Word: 'Tablet' in Sentence ID: sent_4608
#   Word: 'gtt' in Sentence ID: sent_4870
#   Word: 'Appl' in Sentence ID: sent_5090
#   Word: 'Capsules' in Sentence ID: sent_5095
#   Word: 'Powder' in Sentence ID: sent_5103
#   Word: 'Patch' in Sentence ID: sent_5638
#   Word: 'Ointment' in Sentence ID: sent_6040
#   Word: 'Tablet' in Sentence ID: sent_6257
#   Word: 'Tablet' in Sentence ID: sent_6259
#   Word: 'Tablet' in Sentence ID: sent_6354
#   Word: 'Tablet' in Sentence ID: sent_6358
#   Word: 'Tablet' in Sentence ID: sent_6490
#   Word: 'puffs.' in Sentence ID: sent_6493
#   Word: 'tablet' in Sentence ID: sent_6803
#   Word: 'Tablet' in Sentence ID: sent_6806
#   Word: 'Tablet' in Sentence ID: sent_7830
#   Word: 'Tablet' in Sentence ID: sent_7834
#   Word: 'Piggyback' in Sentence ID: sent_8043
#   Word: 'Solution' in Sentence ID: sent_8102
#   Word: 'Solution' in Sentence ID: sent_8103
#   Word: 'Capsule' in Sentence ID: sent_8157
#   Word: 'nebs.' in Sentence ID: sent_8272
#   Word: 'patch' in Sentence ID: sent_8327
#   Word: 'Tablet.' in Sentence ID: sent_8329
#   Word: 'Tablet' in Sentence ID: sent_8670
#   Word: 'Tablet' in Sentence ID: sent_8671
#   Word: 'Tablet' in Sentence ID: sent_8729
#   Word: 'drop' in Sentence ID: sent_8920
#   Word: 'Tablet' in Sentence ID: sent_9128
#   Word: 'Tablet' in Sentence ID: sent_9200
#   Word: 'Tablet' in Sentence ID: sent_9202
#   Word: 'Tablet' in Sentence ID: sent_9358
#   Word: 'Drops' in Sentence ID: sent_9452
#   Word: 'Tablet' in Sentence ID: sent_9618
#   Word: 'Tablet' in Sentence ID: sent_10085
#   Word: 'Solution' in Sentence ID: sent_10183
#   Word: 'Tablet' in Sentence ID: sent_10269
#   Word: 'Tablet' in Sentence ID: sent_10326
#   Word: 'Solution' in Sentence ID: sent_10418
#   Word: 'Tablet' in Sentence ID: sent_10421
#   Word: 'Liquid' in Sentence ID: sent_10423
#   Word: 'Tablet' in Sentence ID: sent_10429
#   Word: 'Aerosol' in Sentence ID: sent_10474
#   Word: 'Tablet' in Sentence ID: sent_10631
#   Word: 'Tablet' in Sentence ID: sent_10755
#   Word: 'Tablet' in Sentence ID: sent_10854
#   Word: 'Tablet' in Sentence ID: sent_10854
#   Word: 'Tablet' in Sentence ID: sent_10855
#   Word: 'Tablet' in Sentence ID: sent_10901
#   Word: 'Tablet' in Sentence ID: sent_10901
#   Word: 'Capsule' in Sentence ID: sent_10902
#   Word: 'Tablet' in Sentence ID: sent_10902
#
#
# True label: B-Dosage, Predicted label: B-Form
#   Word: 'One' in Sentence ID: sent_284
#   Word: 'One' in Sentence ID: sent_324
#   Word: '2' in Sentence ID: sent_640
#   Word: '1' in Sentence ID: sent_714
#   Word: '2' in Sentence ID: sent_824
#   Word: 'bolused' in Sentence ID: sent_1468
#   Word: 'One' in Sentence ID: sent_1551
#   Word: 'One' in Sentence ID: sent_2235
#   Word: 'One' in Sentence ID: sent_3088
#   Word: 'One' in Sentence ID: sent_3572
#   Word: 'One' in Sentence ID: sent_3907
#   Word: 'One' in Sentence ID: sent_4819
#   Word: 'One' in Sentence ID: sent_4958
#   Word: 'One' in Sentence ID: sent_5096
#   Word: 'One' in Sentence ID: sent_6194
#   Word: 'One' in Sentence ID: sent_7832
#   Word: 'One' in Sentence ID: sent_8329
#   Word: 'One' in Sentence ID: sent_8450
#   Word: 'One' in Sentence ID: sent_9620
#   Word: 'One' in Sentence ID: sent_10368
#   Word: 'taper' in Sentence ID: sent_10411
#   Word: 'sliding' in Sentence ID: sent_10631
#   Word: '1' in Sentence ID: sent_10745
#
#
# True label: I-Dosage, Predicted label: I-Form
#   Word: '(' in Sentence ID: sent_284
#   Word: '(' in Sentence ID: sent_716
#   Word: '1' in Sentence ID: sent_716
#   Word: ')' in Sentence ID: sent_716
#   Word: '(' in Sentence ID: sent_3474
#   Word: '1' in Sentence ID: sent_3474
#   Word: '(' in Sentence ID: sent_3572
#   Word: '1' in Sentence ID: sent_3572
#   Word: ').' in Sentence ID: sent_3572
#   Word: '(' in Sentence ID: sent_5287
#   Word: '1' in Sentence ID: sent_7885
#   Word: ')' in Sentence ID: sent_7885
#   Word: '(' in Sentence ID: sent_8329
#   Word: '1' in Sentence ID: sent_8329
#   Word: ')' in Sentence ID: sent_8329
#   Word: '(' in Sentence ID: sent_9454
#   Word: '1' in Sentence ID: sent_9454
#   Word: ')' in Sentence ID: sent_9454
#   Word: 'units' in Sentence ID: sent_10037
#   Word: '(' in Sentence ID: sent_10184
#   Word: '1' in Sentence ID: sent_10184
#   Word: ')' in Sentence ID: sent_10184
#
#
# True label: B-Form, Predicted label: B-Dosage
#   Word: 'Tablet' in Sentence ID: sent_284
#   Word: 'Cream' in Sentence ID: sent_968
#   Word: 'liquid' in Sentence ID: sent_1025
#   Word: 'Solution' in Sentence ID: sent_1292
#   Word: 'HFA' in Sentence ID: sent_1773
#   Word: 'neb.' in Sentence ID: sent_2660
#   Word: 'Tablet' in Sentence ID: sent_4262
#   Word: 'Tablet' in Sentence ID: sent_4608
#   Word: 'Tablet' in Sentence ID: sent_4819
#   Word: 'Tablet' in Sentence ID: sent_4957
#   Word: 'Tablet' in Sentence ID: sent_5287
#   Word: 'Tablet' in Sentence ID: sent_5500
#   Word: 'Capsule' in Sentence ID: sent_6152
#   Word: 'Capsule' in Sentence ID: sent_6297
#   Word: 'Tablet' in Sentence ID: sent_7831
#   Word: 'Tablet' in Sentence ID: sent_7831
#   Word: 'Tablet' in Sentence ID: sent_8328
#   Word: 'Tablet' in Sentence ID: sent_9125
#   Word: 'Tablet' in Sentence ID: sent_9129
#   Word: 'Solution' in Sentence ID: sent_9366
#   Word: 'Tablet' in Sentence ID: sent_9447
#   Word: 'Tablet' in Sentence ID: sent_9619
#   Word: 'Puff' in Sentence ID: sent_10474
#
#
# True label: B-Route, Predicted label: I-Dosage
#   Word: 'PO' in Sentence ID: sent_284
#   Word: 'gtt' in Sentence ID: sent_1379
#   Word: 'gtt' in Sentence ID: sent_1420
#   Word: 'PO' in Sentence ID: sent_1704
#   Word: 'PO' in Sentence ID: sent_3085
#   Word: 'SC' in Sentence ID: sent_3088
#   Word: 'PO' in Sentence ID: sent_3330
#   Word: 'PO' in Sentence ID: sent_3331
#   Word: 'PO' in Sentence ID: sent_3335
#   Word: 'PO' in Sentence ID: sent_3907
#   Word: 'PO' in Sentence ID: sent_3907
#   Word: 'PO' in Sentence ID: sent_3907
#   Word: 'inhalation.' in Sentence ID: sent_3908
#   Word: 'IV' in Sentence ID: sent_4117
#   Word: 'Rectal.' in Sentence ID: sent_4361
#   Word: 'IV' in Sentence ID: sent_4493
#   Word: 'PO' in Sentence ID: sent_4819
#   Word: 'PO' in Sentence ID: sent_5088
#   Word: 'Mucous' in Sentence ID: sent_5097
#   Word: 'PO' in Sentence ID: sent_5287
#   Word: 'PO' in Sentence ID: sent_6152
#   Word: 'PO' in Sentence ID: sent_6297
#   Word: 'oral' in Sentence ID: sent_7652
#   Word: 'PO' in Sentence ID: sent_7888
#   Word: 'PO' in Sentence ID: sent_7890
#   Word: 'PO' in Sentence ID: sent_8245
#   Word: 'PO' in Sentence ID: sent_8328
#   Word: 'Intravenous.' in Sentence ID: sent_9206
#   Word: 'po' in Sentence ID: sent_10362
#   Word: 'Inhalation.' in Sentence ID: sent_10473
#   Word: 'Inhalation' in Sentence ID: sent_10474
#   Word: 'inhalation' in Sentence ID: sent_10534
#   Word: 'PO' in Sentence ID: sent_10640
#   Word: 'po' in Sentence ID: sent_10674
#   Word: 'PO' in Sentence ID: sent_10750
#
#
# True label: B-Frequency, Predicted label: I-Dosage
#   Word: 'once' in Sentence ID: sent_284
#   Word: 'Q6H' in Sentence ID: sent_1037
#   Word: 'Daily.' in Sentence ID: sent_1119
#   Word: 'every' in Sentence ID: sent_1233
#   Word: 'q.h.s' in Sentence ID: sent_1801
#   Word: 'daily.' in Sentence ID: sent_2676
#   Word: 'Q4' in Sentence ID: sent_3330
#   Word: 'DAILY.' in Sentence ID: sent_3665
#   Word: 'once' in Sentence ID: sent_3907
#   Word: '(' in Sentence ID: sent_4262
#   Word: 'PRN' in Sentence ID: sent_4646
#   Word: 'daily.' in Sentence ID: sent_4653
#   Word: 'DAILY' in Sentence ID: sent_4819
#   Word: 'q.d' in Sentence ID: sent_5213
#   Word: 'HS' in Sentence ID: sent_5287
#   Word: 'BID' in Sentence ID: sent_6152
#   Word: 'QAM' in Sentence ID: sent_6254
#   Word: 'Q6H' in Sentence ID: sent_6255
#   Word: 'BID' in Sentence ID: sent_6297
#   Word: 'once' in Sentence ID: sent_6493
#   Word: 'BID' in Sentence ID: sent_7022
#   Word: 'Q6H' in Sentence ID: sent_7024
#   Word: 'qd.' in Sentence ID: sent_7587
#   Word: 'once' in Sentence ID: sent_7890
#   Word: 'DAILY' in Sentence ID: sent_8245
#   Word: 'DAILY' in Sentence ID: sent_8328
#   Word: 'twice' in Sentence ID: sent_8462
#   Word: 'daily.' in Sentence ID: sent_9122
#   Word: 'Q12h' in Sentence ID: sent_9344
#   Word: 'qday' in Sentence ID: sent_9408
#   Word: 'daily' in Sentence ID: sent_9408
#   Word: 'daily.' in Sentence ID: sent_9827
#   Word: 'daily.' in Sentence ID: sent_9828
#   Word: 'TID' in Sentence ID: sent_10089
#   Word: 'nighttime' in Sentence ID: sent_10215
#   Word: 'qd' in Sentence ID: sent_10362
#   Word: 'Q4H' in Sentence ID: sent_10473
#   Word: 'Q6H' in Sentence ID: sent_10474
#   Word: 'twice' in Sentence ID: sent_10640
#   Word: 'qday' in Sentence ID: sent_10674
#   Word: 'daily.' in Sentence ID: sent_10744
#   Word: 'BID' in Sentence ID: sent_10750
#
#
# True label: I-Reason, Predicted label: B-Dosage
#   Word: 'of' in Sentence ID: sent_285
#   Word: 'BLEED' in Sentence ID: sent_751
#   Word: 'clots' in Sentence ID: sent_2113
#   Word: 'breath' in Sentence ID: sent_3668
#   Word: 'bacteremia' in Sentence ID: sent_6481
#   Word: 'flares' in Sentence ID: sent_7468
#   Word: 'of' in Sentence ID: sent_7503
#   Word: 'production' in Sentence ID: sent_7998
#   Word: 'breath' in Sentence ID: sent_8396
#   Word: 'fibrilation' in Sentence ID: sent_10341
#
#
# True label: B-Route, Predicted label: I-Strength
#   Word: 'face' in Sentence ID: sent_292
#   Word: 'Intravenous' in Sentence ID: sent_473
#   Word: 'PO' in Sentence ID: sent_716
#   Word: 'PO' in Sentence ID: sent_1235
#   Word: 'PO' in Sentence ID: sent_1355
#   Word: 'PO' in Sentence ID: sent_1939
#   Word: 'epidural' in Sentence ID: sent_2137
#   Word: 'PO' in Sentence ID: sent_2283
#   Word: 'PO' in Sentence ID: sent_2407
#   Word: 'by' in Sentence ID: sent_2831
#   Word: 'PO' in Sentence ID: sent_3046
#   Word: 'Ophthalmic' in Sentence ID: sent_3277
#   Word: 'Ophthalmic' in Sentence ID: sent_3277
#   Word: 'PO' in Sentence ID: sent_3331
#   Word: 'PO' in Sentence ID: sent_3473
#   Word: 'PO' in Sentence ID: sent_4261
#   Word: 'IV' in Sentence ID: sent_4842
#   Word: 'PO' in Sentence ID: sent_5104
#   Word: 'IV' in Sentence ID: sent_5536
#   Word: 'PO' in Sentence ID: sent_6194
#   Word: 'IV' in Sentence ID: sent_6337
#   Word: 'PO' in Sentence ID: sent_6805
#   Word: 'drip' in Sentence ID: sent_7587
#   Word: 'PO' in Sentence ID: sent_8443
#   Word: 'PO' in Sentence ID: sent_8594
#   Word: 'IV' in Sentence ID: sent_8810
#   Word: 'PO' in Sentence ID: sent_9205
#   Word: 'PO.' in Sentence ID: sent_9953
#   Word: 'PO' in Sentence ID: sent_10180
#   Word: 'PO' in Sentence ID: sent_10432
#
#
# True label: I-Route, Predicted label: B-Drug
#   Word: '-' in Sentence ID: sent_292
#   Word: 'vent' in Sentence ID: sent_3791
#   Word: 'mouth' in Sentence ID: sent_9124
#   Word: 'mouth' in Sentence ID: sent_9867
#   Word: 'Inhalation' in Sentence ID: sent_10276
#
#
# True label: I-Route, Predicted label: B-Form
#   Word: 'mask' in Sentence ID: sent_292
#   Word: 'mouth' in Sentence ID: sent_2831
#   Word: 'membrane' in Sentence ID: sent_5097
#
#
# True label: B-Reason, Predicted label: B-Route
#   Word: 'acute' in Sentence ID: sent_311
#   Word: 'C.diff' in Sentence ID: sent_4005
#   Word: 'opacity' in Sentence ID: sent_5399
#   Word: 'pruritis' in Sentence ID: sent_6040
#   Word: 'preseptal' in Sentence ID: sent_6968
#   Word: 'metastatic.' in Sentence ID: sent_8880
#   Word: 'Pain' in Sentence ID: sent_9202
#   Word: 'heart' in Sentence ID: sent_9593
#   Word: 'C' in Sentence ID: sent_10041
#   Word: 'constipation' in Sentence ID: sent_10222
#
#
# True label: I-Reason, Predicted label: B-Frequency
#   Word: 'on' in Sentence ID: sent_311
#   Word: 'setting' in Sentence ID: sent_1049
#   Word: 'pressure.' in Sentence ID: sent_2585
#   Word: 'hyponatremia' in Sentence ID: sent_3127
#   Word: 'deficiency' in Sentence ID: sent_6737
#   Word: 'cellulitis' in Sentence ID: sent_6968
#   Word: 'shrink' in Sentence ID: sent_7974
#   Word: 'a' in Sentence ID: sent_8487
#   Word: 'poorly' in Sentence ID: sent_8880
#   Word: '.' in Sentence ID: sent_10041
#
#
# True label: I-Reason, Predicted label: B-Drug
#   Word: 'chronic' in Sentence ID: sent_311
#   Word: 'withdrawal' in Sentence ID: sent_379
#   Word: 'oxygen' in Sentence ID: sent_953
#   Word: 'INR' in Sentence ID: sent_1001
#   Word: 'response' in Sentence ID: sent_1221
#   Word: 'pressure' in Sentence ID: sent_1349
#   Word: 'op' in Sentence ID: sent_1485
#   Word: 'RVR' in Sentence ID: sent_1724
#   Word: 'pain' in Sentence ID: sent_1813
#   Word: 'dose' in Sentence ID: sent_1894
#   Word: 'pneumonia' in Sentence ID: sent_1912
#   Word: 'arthritis' in Sentence ID: sent_1949
#   Word: 'control' in Sentence ID: sent_2056
#   Word: 'ppx' in Sentence ID: sent_2205
#   Word: 'clots' in Sentence ID: sent_2225
#   Word: 'possible' in Sentence ID: sent_2722
#   Word: 'symptoms' in Sentence ID: sent_3604
#   Word: 'blood.' in Sentence ID: sent_3686
#   Word: 'the' in Sentence ID: sent_3775
#   Word: 'attack' in Sentence ID: sent_3788
#   Word: 'tissue' in Sentence ID: sent_4340
#   Word: 'Fibrillation' in Sentence ID: sent_4630
#   Word: ',' in Sentence ID: sent_4718
#   Word: '-' in Sentence ID: sent_5372
#   Word: 'to' in Sentence ID: sent_5399
#   Word: 'of.' in Sentence ID: sent_5448
#   Word: 'Pain' in Sentence ID: sent_5495
#   Word: 'right' in Sentence ID: sent_5591
#   Word: 'edmema' in Sentence ID: sent_6617
#   Word: 'control' in Sentence ID: sent_6790
#   Word: 'of' in Sentence ID: sent_7154
#   Word: 'systemic' in Sentence ID: sent_7503
#   Word: 'of' in Sentence ID: sent_7586
#   Word: 'for' in Sentence ID: sent_7663
#   Word: 'Bleed' in Sentence ID: sent_7817
#   Word: 'prostate' in Sentence ID: sent_7974
#   Word: 'a' in Sentence ID: sent_7977
#   Word: 'with' in Sentence ID: sent_8096
#   Word: 'schizophrenia' in Sentence ID: sent_8129
#   Word: 'CA' in Sentence ID: sent_8211
#   Word: 'of' in Sentence ID: sent_8396
#   Word: 'thrombosis' in Sentence ID: sent_9189
#   Word: 'pain' in Sentence ID: sent_9296
#   Word: 'aortic' in Sentence ID: sent_9764
#   Word: 'difficile' in Sentence ID: sent_10041
#
#
# True label: I-Reason, Predicted label: B-Strength
#   Word: 'diastolic' in Sentence ID: sent_311
#   Word: 'in' in Sentence ID: sent_1049
#   Word: 'control' in Sentence ID: sent_1349
#   Word: 'radiotherapy' in Sentence ID: sent_1894
#   Word: 'of' in Sentence ID: sent_2143
#   Word: 'fever' in Sentence ID: sent_3016
#   Word: 'fibrillation.' in Sentence ID: sent_3125
#   Word: 'C' in Sentence ID: sent_3614
#   Word: 'site.' in Sentence ID: sent_3775
#   Word: 'Disease' in Sentence ID: sent_4719
#   Word: 'abuse' in Sentence ID: sent_6189
#   Word: 'c' in Sentence ID: sent_7663
#   Word: 'coverage' in Sentence ID: sent_7998
#   Word: 'PAIN.' in Sentence ID: sent_8245
#   Word: 'of' in Sentence ID: sent_8408
#   Word: 'DVT' in Sentence ID: sent_9604
#   Word: 'urinalysis' in Sentence ID: sent_9698
#   Word: 'control.' in Sentence ID: sent_10887
#
#
# True label: I-Reason, Predicted label: I-Strength
#   Word: 'CHF.' in Sentence ID: sent_311
#   Word: 'exacerbation' in Sentence ID: sent_311
#   Word: 'the' in Sentence ID: sent_1049
#   Word: 'prevention' in Sentence ID: sent_1145
#   Word: 'control' in Sentence ID: sent_1350
#   Word: 'breath' in Sentence ID: sent_2143
#   Word: 'chronic' in Sentence ID: sent_3097
#   Word: 'LE' in Sentence ID: sent_3097
#   Word: 'ulcerations' in Sentence ID: sent_3097
#   Word: 'cultures' in Sentence ID: sent_5737
#   Word: 'grew.' in Sentence ID: sent_5737
#   Word: 'GPC' in Sentence ID: sent_5737
#   Word: 'in' in Sentence ID: sent_5737
#   Word: 'clusters' in Sentence ID: sent_5737
#   Word: 'and' in Sentence ID: sent_5737
#   Word: 'clot' in Sentence ID: sent_7651
#   Word: '.' in Sentence ID: sent_7663
#   Word: 'breath' in Sentence ID: sent_8408
#   Word: 'of' in Sentence ID: sent_10408
#   Word: 'procedure' in Sentence ID: sent_10644
#   Word: 'with' in Sentence ID: sent_10977
#
#
# True label: B-Dosage, Predicted label: B-Reason
#   Word: 'One' in Sentence ID: sent_323
#   Word: '2' in Sentence ID: sent_2645
#   Word: 'One' in Sentence ID: sent_3212
#   Word: 'One' in Sentence ID: sent_3470
#   Word: 'Three' in Sentence ID: sent_3474
#   Word: 'One' in Sentence ID: sent_3476
#   Word: '1' in Sentence ID: sent_3546
#   Word: 'Two' in Sentence ID: sent_4129
#   Word: 'One' in Sentence ID: sent_4261
#   Word: 'One' in Sentence ID: sent_4429
#   Word: '1' in Sentence ID: sent_6768
#   Word: 'taper' in Sentence ID: sent_7003
#   Word: '1' in Sentence ID: sent_7507
#   Word: 'bolus.' in Sentence ID: sent_7663
#   Word: 'Four' in Sentence ID: sent_8101
#   Word: '6L' in Sentence ID: sent_8240
#   Word: '1' in Sentence ID: sent_9613
#   Word: '2' in Sentence ID: sent_10079
#   Word: 'One' in Sentence ID: sent_10328
#   Word: 'Sliding' in Sentence ID: sent_10479
#   Word: '1/2' in Sentence ID: sent_10896
#
#
# True label: I-Dosage, Predicted label: B-Drug
#   Word: ')' in Sentence ID: sent_323
#   Word: ')' in Sentence ID: sent_473
#   Word: 'Units' in Sentence ID: sent_644
#   Word: ')' in Sentence ID: sent_765
#   Word: ')' in Sentence ID: sent_968
#   Word: ')' in Sentence ID: sent_969
#   Word: '(' in Sentence ID: sent_1123
#   Word: ')' in Sentence ID: sent_1123
#   Word: ').' in Sentence ID: sent_1158
#   Word: '(' in Sentence ID: sent_1233
#   Word: '1' in Sentence ID: sent_1234
#   Word: ')' in Sentence ID: sent_1235
#   Word: ')' in Sentence ID: sent_1355
#   Word: ')' in Sentence ID: sent_1355
#   Word: '(' in Sentence ID: sent_1356
#   Word: 'liter' in Sentence ID: sent_1464
#   Word: ')' in Sentence ID: sent_1550
#   Word: ').' in Sentence ID: sent_1647
#   Word: '*' in Sentence ID: sent_1653
#   Word: 'Numeric' in Sentence ID: sent_1653
#   Word: '2' in Sentence ID: sent_1939
#   Word: '-' in Sentence ID: sent_1939
#   Word: '2' in Sentence ID: sent_2094
#   Word: '40' in Sentence ID: sent_2210
#   Word: ')' in Sentence ID: sent_2212
#   Word: '2' in Sentence ID: sent_2213
#   Word: '(' in Sentence ID: sent_2214
#   Word: ').' in Sentence ID: sent_2214
#   Word: ')' in Sentence ID: sent_2283
#   Word: ')' in Sentence ID: sent_2287
#   Word: ')' in Sentence ID: sent_2469
#   Word: '1' in Sentence ID: sent_2716
#   Word: '2' in Sentence ID: sent_2769
#   Word: ')' in Sentence ID: sent_2833
#   Word: '1' in Sentence ID: sent_2895
#   Word: '(' in Sentence ID: sent_2896
#   Word: '1' in Sentence ID: sent_2953
#   Word: ')' in Sentence ID: sent_3010
#   Word: '2' in Sentence ID: sent_3015
#   Word: '(' in Sentence ID: sent_3047
#   Word: '1' in Sentence ID: sent_3277
#   Word: '(' in Sentence ID: sent_3277
#   Word: '(' in Sentence ID: sent_3331
#   Word: '1' in Sentence ID: sent_3332
#   Word: '2' in Sentence ID: sent_3396
#   Word: '(' in Sentence ID: sent_3545
#   Word: '-' in Sentence ID: sent_3550
#   Word: '(' in Sentence ID: sent_3573
#   Word: '1' in Sentence ID: sent_3809
#   Word: '(' in Sentence ID: sent_3954
#   Word: ')' in Sentence ID: sent_4018
#   Word: '2' in Sentence ID: sent_4129
#   Word: '1' in Sentence ID: sent_4132
#   Word: ')' in Sentence ID: sent_4190
#   Word: '(' in Sentence ID: sent_4196
#   Word: '(' in Sentence ID: sent_4261
#   Word: '1' in Sentence ID: sent_4262
#   Word: '(' in Sentence ID: sent_4357
#   Word: '1' in Sentence ID: sent_4431
#   Word: '(' in Sentence ID: sent_4432
#   Word: '1' in Sentence ID: sent_4737
#   Word: '(' in Sentence ID: sent_4817
#   Word: 'ml' in Sentence ID: sent_5087
#   Word: 'ml' in Sentence ID: sent_5330
#   Word: '(' in Sentence ID: sent_5447
#   Word: ').' in Sentence ID: sent_5447
#   Word: '(' in Sentence ID: sent_5500
#   Word: ')' in Sentence ID: sent_5501
#   Word: '1' in Sentence ID: sent_5503
#   Word: '(' in Sentence ID: sent_5966
#   Word: ').' in Sentence ID: sent_5966
#   Word: '(' in Sentence ID: sent_6039
#   Word: '2' in Sentence ID: sent_6296
#   Word: ')' in Sentence ID: sent_6554
#   Word: '(' in Sentence ID: sent_6805
#   Word: ').' in Sentence ID: sent_6805
#   Word: '(' in Sentence ID: sent_6931
#   Word: '(' in Sentence ID: sent_6934
#   Word: '2' in Sentence ID: sent_7021
#   Word: '(' in Sentence ID: sent_7457
#   Word: ')' in Sentence ID: sent_7457
#   Word: ')' in Sentence ID: sent_7966
#   Word: 'ML' in Sentence ID: sent_8043
#   Word: '(' in Sentence ID: sent_8101
#   Word: ')' in Sentence ID: sent_8451
#   Word: '*' in Sentence ID: sent_8489
#   Word: ').' in Sentence ID: sent_8536
#   Word: '(' in Sentence ID: sent_8590
#   Word: '(' in Sentence ID: sent_8669
#   Word: '3' in Sentence ID: sent_8768
#   Word: ')' in Sentence ID: sent_8983
#   Word: '1' in Sentence ID: sent_9205
#   Word: '(' in Sentence ID: sent_9358
#   Word: '(' in Sentence ID: sent_9453
#   Word: '1' in Sentence ID: sent_9953
#   Word: '(' in Sentence ID: sent_10081
#   Word: ')' in Sentence ID: sent_10081
#   Word: '1' in Sentence ID: sent_10425
#   Word: 'Units' in Sentence ID: sent_10425
#   Word: ')' in Sentence ID: sent_10432
#   Word: '(' in Sentence ID: sent_10635
#   Word: '(' in Sentence ID: sent_10640
#   Word: '1' in Sentence ID: sent_10640
#   Word: '(' in Sentence ID: sent_10752
#   Word: ')' in Sentence ID: sent_10811
#   Word: '1' in Sentence ID: sent_10855
#   Word: '1' in Sentence ID: sent_10902
#
#
# True label: B-Frequency, Predicted label: B-Dosage
#   Word: '2' in Sentence ID: sent_323
#   Word: 'prn' in Sentence ID: sent_384
#   Word: 'Q4' in Sentence ID: sent_766
#   Word: 'BID' in Sentence ID: sent_972
#   Word: 'BID' in Sentence ID: sent_2211
#   Word: 'q6.' in Sentence ID: sent_3329
#   Word: 'DAILY.' in Sentence ID: sent_3398
#   Word: 'TID.' in Sentence ID: sent_4067
#   Word: 'as' in Sentence ID: sent_4124
#   Word: 'DAILY.' in Sentence ID: sent_4957
#   Word: 'HS' in Sentence ID: sent_6152
#   Word: 'QID' in Sentence ID: sent_6490
#   Word: 'PRN' in Sentence ID: sent_6551
#   Word: 'DAILY' in Sentence ID: sent_6806
#   Word: 'DAILY' in Sentence ID: sent_7458
#   Word: 'Q8H' in Sentence ID: sent_8329
#   Word: 'q' in Sentence ID: sent_9003
#   Word: 'four' in Sentence ID: sent_9201
#   Word: 'PRN' in Sentence ID: sent_9454
#   Word: 'qd' in Sentence ID: sent_10362
#   Word: 'BID' in Sentence ID: sent_10634
#   Word: 'daily.' in Sentence ID: sent_10745
#
#
# True label: I-Form, Predicted label: B-Strength
#   Word: 'Release' in Sentence ID: sent_323
#   Word: 's' in Sentence ID: sent_565
#   Word: 'E.C.' in Sentence ID: sent_649
#   Word: 'Chewable.' in Sentence ID: sent_716
#   Word: 's' in Sentence ID: sent_765
#   Word: ',' in Sentence ID: sent_1874
#   Word: 'E.C.' in Sentence ID: sent_2234
#   Word: 'Chewable.' in Sentence ID: sent_2407
#   Word: 'times' in Sentence ID: sent_2676
#   Word: ')' in Sentence ID: sent_2831
#   Word: '.' in Sentence ID: sent_2835
#   Word: ',' in Sentence ID: sent_3951
#   Word: 'Packet' in Sentence ID: sent_5097
#   Word: 'Release' in Sentence ID: sent_5104
#   Word: 'Chewable' in Sentence ID: sent_7245
#   Word: 'E.C.' in Sentence ID: sent_7310
#   Word: 'Release' in Sentence ID: sent_8329
#   Word: 'Sustained' in Sentence ID: sent_8329
#   Word: ',' in Sentence ID: sent_8536
#   Word: ',' in Sentence ID: sent_8671
#   Word: '(' in Sentence ID: sent_9453
#   Word: ',' in Sentence ID: sent_10755
#
#
# True label: B-Dosage, Predicted label: I-Dosage
#   Word: 'Two' in Sentence ID: sent_323
#   Word: 'One' in Sentence ID: sent_473
#   Word: 'gtt' in Sentence ID: sent_823
#   Word: 'Three.' in Sentence ID: sent_1232
#   Word: 'One.' in Sentence ID: sent_2352
#   Word: 'One' in Sentence ID: sent_2660
#   Word: 'Six' in Sentence ID: sent_2771
#   Word: '0.5' in Sentence ID: sent_3550
#   Word: 'Two' in Sentence ID: sent_4132
#   Word: 'One' in Sentence ID: sent_4608
#   Word: '2u' in Sentence ID: sent_4645
#   Word: 'SS' in Sentence ID: sent_4651
#   Word: 'One' in Sentence ID: sent_4957
#   Word: 'One' in Sentence ID: sent_7831
#   Word: 'One' in Sentence ID: sent_7831
#   Word: '0.5' in Sentence ID: sent_7888
#   Word: 'One' in Sentence ID: sent_8040
#   Word: '1' in Sentence ID: sent_9125
#   Word: 'One' in Sentence ID: sent_9129
#   Word: '0.5' in Sentence ID: sent_9500
#   Word: 'Two' in Sentence ID: sent_9619
#   Word: 'One' in Sentence ID: sent_9621
#   Word: 'One' in Sentence ID: sent_10184
#   Word: '2' in Sentence ID: sent_10255
#   Word: 'One' in Sentence ID: sent_10750
#
#
# True label: I-Dosage, Predicted label: B-Form
#   Word: ').' in Sentence ID: sent_323
#   Word: '1' in Sentence ID: sent_473
#   Word: '1' in Sentence ID: sent_473
#   Word: ')' in Sentence ID: sent_568
#   Word: ')' in Sentence ID: sent_766
#   Word: ')' in Sentence ID: sent_972
#   Word: '3' in Sentence ID: sent_1232
#   Word: ')' in Sentence ID: sent_1292
#   Word: ')' in Sentence ID: sent_2352
#   Word: '1' in Sentence ID: sent_2660
#   Word: '(' in Sentence ID: sent_2660
#   Word: '2' in Sentence ID: sent_2764
#   Word: '1' in Sentence ID: sent_3087
#   Word: ')' in Sentence ID: sent_3398
#   Word: 'dose' in Sentence ID: sent_3707
#   Word: '2' in Sentence ID: sent_4132
#   Word: ')' in Sentence ID: sent_4262
#   Word: '(' in Sentence ID: sent_4608
#   Word: '(' in Sentence ID: sent_4819
#   Word: '(' in Sentence ID: sent_4890
#   Word: '(' in Sentence ID: sent_4957
#   Word: ')' in Sentence ID: sent_6152
#   Word: '(' in Sentence ID: sent_6152
#   Word: ')' in Sentence ID: sent_6194
#   Word: '(' in Sentence ID: sent_6297
#   Word: '(' in Sentence ID: sent_6806
#   Word: ')' in Sentence ID: sent_7021
#   Word: '(' in Sentence ID: sent_7831
#   Word: '(' in Sentence ID: sent_7831
#   Word: '(' in Sentence ID: sent_7885
#   Word: ')' in Sentence ID: sent_8040
#   Word: '(' in Sentence ID: sent_8328
#   Word: '(' in Sentence ID: sent_9129
#   Word: ')' in Sentence ID: sent_9201
#   Word: ')' in Sentence ID: sent_9358
#   Word: '(' in Sentence ID: sent_9619
#   Word: 'units' in Sentence ID: sent_9697
#   Word: '1' in Sentence ID: sent_9833
#   Word: '(' in Sentence ID: sent_10088
#   Word: ')' in Sentence ID: sent_10184
#   Word: ')' in Sentence ID: sent_10368
#   Word: '(' in Sentence ID: sent_10474
#   Word: ')' in Sentence ID: sent_10634
#   Word: '(' in Sentence ID: sent_10750
#
#
# True label: B-Form, Predicted label: B-Route
#   Word: 'Tablet' in Sentence ID: sent_324
#   Word: 'Tablet' in Sentence ID: sent_569
#   Word: 'Tablet' in Sentence ID: sent_763
#   Word: 'Solution' in Sentence ID: sent_968
#   Word: 'Tablet' in Sentence ID: sent_1234
#   Word: 'Tablet' in Sentence ID: sent_2283
#   Word: 'Tablet' in Sentence ID: sent_3330
#   Word: 'Tablet' in Sentence ID: sent_3396
#   Word: 'Tablet' in Sentence ID: sent_3469
#   Word: 'Tablet' in Sentence ID: sent_3573
#   Word: 'puff.' in Sentence ID: sent_4196
#   Word: 'Tablets' in Sentence ID: sent_4608
#   Word: 'gtt' in Sentence ID: sent_4842
#   Word: 'Lotion' in Sentence ID: sent_5090
#   Word: 'Tablet' in Sentence ID: sent_5286
#   Word: 'Tablet' in Sentence ID: sent_5501
#   Word: 'Patch' in Sentence ID: sent_6154
#   Word: 'Solution' in Sentence ID: sent_6629
#   Word: 'patches' in Sentence ID: sent_6798
#   Word: 'Solution' in Sentence ID: sent_6805
#   Word: 'Adhesive' in Sentence ID: sent_6806
#   Word: 'Capsule' in Sentence ID: sent_7021
#   Word: 'Tablet' in Sentence ID: sent_7830
#   Word: 'Tablet' in Sentence ID: sent_7885
#   Word: 'Tablet' in Sentence ID: sent_7966
#   Word: 'Injection.' in Sentence ID: sent_8040
#   Word: 'Disk' in Sentence ID: sent_8099
#   Word: 'Puff' in Sentence ID: sent_8101
#   Word: 'Aerosol' in Sentence ID: sent_8101
#   Word: 'Tablet' in Sentence ID: sent_8591
#   Word: 'Disk.' in Sentence ID: sent_9121
#   Word: 'Tablet' in Sentence ID: sent_9122
#   Word: 'Capsule' in Sentence ID: sent_9358
#   Word: 'Tablet' in Sentence ID: sent_9500
#   Word: 'Tablet' in Sentence ID: sent_9616
#   Word: 'gtt' in Sentence ID: sent_9636
#   Word: 'Tablet' in Sentence ID: sent_10184
#   Word: 'Tablet' in Sentence ID: sent_10184
#   Word: 'Tablet' in Sentence ID: sent_10225
#   Word: 'Injection' in Sentence ID: sent_10368
#   Word: 'cap' in Sentence ID: sent_10745
#   Word: 'tablet' in Sentence ID: sent_10762
#   Word: 'Syrup' in Sentence ID: sent_10856
#
#
# True label: I-Form, Predicted label: B-Frequency
#   Word: ',' in Sentence ID: sent_324
#   Word: '(' in Sentence ID: sent_648
#   Word: ')' in Sentence ID: sent_649
#   Word: ')' in Sentence ID: sent_765
#   Word: ')' in Sentence ID: sent_1033
#   Word: 'Sustained' in Sentence ID: sent_1234
#   Word: 'E.C.' in Sentence ID: sent_2235
#   Word: 'Sustained' in Sentence ID: sent_2239
#   Word: 'Release' in Sentence ID: sent_2284
#   Word: '24' in Sentence ID: sent_2835
#   Word: 'Release' in Sentence ID: sent_3951
#   Word: ',' in Sentence ID: sent_4129
#   Word: ',' in Sentence ID: sent_5286
#   Word: '72' in Sentence ID: sent_6154
#   Word: 'DR' in Sentence ID: sent_6195
#   Word: 'Delayed' in Sentence ID: sent_8040
#   Word: 'with' in Sentence ID: sent_8099
#   Word: '24' in Sentence ID: sent_8451
#   Word: 'Rapid' in Sentence ID: sent_8536
#   Word: 'Release' in Sentence ID: sent_8819
#   Word: 'with' in Sentence ID: sent_9122
#   Word: ',' in Sentence ID: sent_9200
#   Word: ',' in Sentence ID: sent_9448
#   Word: 'Delayed' in Sentence ID: sent_9453
#   Word: 'E.C.' in Sentence ID: sent_10183
#
#
# True label: I-Drug, Predicted label: B-Dosage
#   Word: 'acid' in Sentence ID: sent_380
#   Word: 'Lock' in Sentence ID: sent_473
#   Word: 'sulfate' in Sentence ID: sent_1119
#   Word: 'Sodium' in Sentence ID: sent_2235
#   Word: 'Saline' in Sentence ID: sent_2539
#   Word: 'spectrum' in Sentence ID: sent_3191
#   Word: '1' in Sentence ID: sent_3573
#   Word: 'acetaminophen' in Sentence ID: sent_4066
#   Word: ')' in Sentence ID: sent_4889
#   Word: '-' in Sentence ID: sent_5078
#   Word: 'Oil' in Sentence ID: sent_5096
#   Word: 'bicarbonate' in Sentence ID: sent_6168
#   Word: 'e' in Sentence ID: sent_6490
#   Word: 'Sodium' in Sentence ID: sent_6629
#   Word: 'cells' in Sentence ID: sent_6961
#   Word: 'd' in Sentence ID: sent_7026
#   Word: '-' in Sentence ID: sent_8536
#   Word: ':' in Sentence ID: sent_8983
#   Word: '-' in Sentence ID: sent_9107
#   Word: 'inhibior' in Sentence ID: sent_9295
#   Word: 'mononitrate' in Sentence ID: sent_9754
#   Word: ')' in Sentence ID: sent_10434
#   Word: 'sustained.' in Sentence ID: sent_10534
#   Word: 'medication' in Sentence ID: sent_10918
#
#
# True label: B-Duration, Predicted label: I-Dosage
#   Word: 'for' in Sentence ID: sent_380
#   Word: 'for' in Sentence ID: sent_569
#   Word: '3' in Sentence ID: sent_654
#   Word: 'for' in Sentence ID: sent_10183
#
#
# True label: I-Duration, Predicted label: B-Form
#   Word: '10' in Sentence ID: sent_380
#   Word: 'days' in Sentence ID: sent_569
#   Word: 'days' in Sentence ID: sent_654
#
#
# True label: I-Duration, Predicted label: I-Form
#   Word: 'day' in Sentence ID: sent_380
#
#
# True label: B-Reason, Predicted label: B-Frequency
#   Word: 'anxiety' in Sentence ID: sent_381
#   Word: 'help' in Sentence ID: sent_726
#   Word: 'fever.' in Sentence ID: sent_1037
#   Word: 'anxiety' in Sentence ID: sent_1295
#   Word: 'high.' in Sentence ID: sent_1893
#   Word: 'PCP.' in Sentence ID: sent_1908
#   Word: 'a' in Sentence ID: sent_2722
#   Word: 'shortness' in Sentence ID: sent_4197
#   Word: 'pain' in Sentence ID: sent_4646
#   Word: 'vasogenic' in Sentence ID: sent_6617
#   Word: 'PPX' in Sentence ID: sent_7441
#   Word: 'shortness' in Sentence ID: sent_8396
#   Word: 'wheezing' in Sentence ID: sent_8396
#   Word: 'COPD' in Sentence ID: sent_9058
#   Word: 'PNA' in Sentence ID: sent_9224
#   Word: 'Atrial' in Sentence ID: sent_9407
#   Word: 'constipation.' in Sentence ID: sent_10762
#   Word: 'SOB' in Sentence ID: sent_10856
#
#
# True label: B-Frequency, Predicted label: I-Drug
#   Word: 'prn.' in Sentence ID: sent_384
#   Word: 'at' in Sentence ID: sent_902
#   Word: 'HS.' in Sentence ID: sent_1291
#   Word: 'daily' in Sentence ID: sent_1440
#   Word: 'Q24H' in Sentence ID: sent_1940
#   Word: 'BID' in Sentence ID: sent_1941
#   Word: 'DAILY' in Sentence ID: sent_3047
#   Word: 'twice' in Sentence ID: sent_4018
#   Word: 'BID' in Sentence ID: sent_4819
#   Word: 'Q2H' in Sentence ID: sent_5089
#   Word: 'DAILY.' in Sentence ID: sent_6686
#   Word: 'Q8H' in Sentence ID: sent_7021
#   Word: 'roughly.' in Sentence ID: sent_7494
#   Word: 'DAILY' in Sentence ID: sent_7966
#   Word: 'daily.' in Sentence ID: sent_8531
#   Word: 'DAILY' in Sentence ID: sent_9128
#   Word: 'DAILY' in Sentence ID: sent_9619
#   Word: 'twice' in Sentence ID: sent_10429
#   Word: 'q.8' in Sentence ID: sent_10535
#   Word: 'daily.' in Sentence ID: sent_10633
#
#
# True label: B-Strength, Predicted label: B-Route
#   Word: '100ml' in Sentence ID: sent_384
#   Word: '100' in Sentence ID: sent_473
#   Word: '10' in Sentence ID: sent_716
#   Word: '50' in Sentence ID: sent_758
#   Word: '500mg' in Sentence ID: sent_902
#   Word: '10' in Sentence ID: sent_968
# ...
#   Word: 'Prophylaxis' in Sentence ID: sent_6484
#   Word: 'seizures' in Sentence ID: sent_7937
#   Word: 'MOUTH' in Sentence ID: sent_8245
#   Word: 'thrush' in Sentence ID: sent_10063
#   Word: 'chronic.' in Sentence ID: sent_10770
#
#
# True label: B-Duration, Predicted label: I-Strength
#   Word: 'for' in Sentence ID: sent_2096
#   Word: 'for' in Sentence ID: sent_4177
#
#
# True label: I-Duration, Predicted label: I-Strength
#   Word: '4' in Sentence ID: sent_2096
#
#
# True label: B-ADE, Predicted label: I-Strength
#   Word: 'hypercarbic' in Sentence ID: sent_2137
#   Word: 'platelet' in Sentence ID: sent_4271
#   Word: 'pulmonary' in Sentence ID: sent_6826
#
#
# True label: B-ADE, Predicted label: I-Reason
#   Word: 'hypoxia.' in Sentence ID: sent_2189
#   Word: 'some' in Sentence ID: sent_8540
#
#
# True label: B-Frequency, Predicted label: B-ADE
#   Word: 'DAILY' in Sentence ID: sent_2282
#   Word: 'Q4' in Sentence ID: sent_3546
#   Word: 'DAILY.' in Sentence ID: sent_6357
#   Word: '4X/WEEK' in Sentence ID: sent_7828
#   Word: '2' in Sentence ID: sent_8100
#   Word: 'DAILY' in Sentence ID: sent_9449
#   Word: 'DAILY.' in Sentence ID: sent_10076
#   Word: 'DAILY.' in Sentence ID: sent_10076
#   Word: 'per' in Sentence ID: sent_10099
#
#
# True label: B-Reason, Predicted label: I-Duration
#   Word: 's/p' in Sentence ID: sent_2297
#   Word: 'pain' in Sentence ID: sent_3981
#   Word: 'Tongue' in Sentence ID: sent_7161
#
#
# True label: I-Duration, Predicted label: B-Reason
#   Word: 'day' in Sentence ID: sent_2335
#   Word: 'days' in Sentence ID: sent_5842
#   Word: 'days' in Sentence ID: sent_6043
#   Word: '-' in Sentence ID: sent_7887
#   Word: 'month' in Sentence ID: sent_8623
#   Word: '7' in Sentence ID: sent_10682
#
#
# True label: I-Dosage, Predicted label: I-Route
#   Word: ')' in Sentence ID: sent_2353
#
#
# True label: I-Dosage, Predicted label: I-Reason
#   Word: ')' in Sentence ID: sent_2467
#   Word: ').' in Sentence ID: sent_3011
#   Word: '1' in Sentence ID: sent_3088
#   Word: 'mg' in Sentence ID: sent_3088
#   Word: '(' in Sentence ID: sent_3212
#   Word: '(' in Sentence ID: sent_3470
#   Word: '(' in Sentence ID: sent_3476
#   Word: '1' in Sentence ID: sent_3476
#   Word: ')' in Sentence ID: sent_3476
#   Word: '-' in Sentence ID: sent_3546
#   Word: '1' in Sentence ID: sent_3572
#   Word: '1' in Sentence ID: sent_3951
#   Word: '(' in Sentence ID: sent_4819
#   Word: '1' in Sentence ID: sent_4819
#   Word: '1' in Sentence ID: sent_6043
#   Word: '(' in Sentence ID: sent_8157
#   Word: '2' in Sentence ID: sent_9267
#   Word: '(' in Sentence ID: sent_9499
#   Word: ')' in Sentence ID: sent_10474
#   Word: '(' in Sentence ID: sent_10811
#   Word: '-' in Sentence ID: sent_10896
#   Word: '1' in Sentence ID: sent_10896
#   Word: '(' in Sentence ID: sent_11036
#   Word: '1' in Sentence ID: sent_11036
#   Word: ')' in Sentence ID: sent_11036
#
#
# True label: B-Reason, Predicted label: I-Route
#   Word: 'blood' in Sentence ID: sent_2585
#
#
# True label: I-Dosage, Predicted label: B-Duration
#   Word: '(' in Sentence ID: sent_2716
#   Word: '1' in Sentence ID: sent_3330
#   Word: ').' in Sentence ID: sent_3396
#   Word: '1' in Sentence ID: sent_7027
#   Word: '(' in Sentence ID: sent_10326
#
#
# True label: I-Reason, Predicted label: I-Drug
#   Word: 'pneumonia' in Sentence ID: sent_2722
#   Word: 'DERMATITIS' in Sentence ID: sent_3136
#   Word: 'retention' in Sentence ID: sent_3323
#   Word: 'breath' in Sentence ID: sent_5448
#   Word: 'of' in Sentence ID: sent_8211
#   Word: 'Resistant.' in Sentence ID: sent_10591
#
#
# True label: I-ADE, Predicted label: I-Strength
#   Word: 'brain' in Sentence ID: sent_2763
#   Word: 'progressivly' in Sentence ID: sent_5851
#   Word: 'throat' in Sentence ID: sent_5871
#   Word: 'GI' in Sentence ID: sent_6672
#   Word: 'syndrome' in Sentence ID: sent_10994
#
#
# True label: I-ADE, Predicted label: B-Form
#   Word: 'mets' in Sentence ID: sent_2763
#   Word: 'count' in Sentence ID: sent_4271
#   Word: 'ulcers' in Sentence ID: sent_6672
#   Word: 'hemorrhage' in Sentence ID: sent_6826
#   Word: 'of' in Sentence ID: sent_7513
#
#
# True label: B-Dosage, Predicted label: I-Route
#   Word: 'sliding' in Sentence ID: sent_2838
#   Word: 'One' in Sentence ID: sent_9448
#
#
# True label: B-Dosage, Predicted label: I-Duration
#   Word: 'One' in Sentence ID: sent_2953
#   Word: 'One.' in Sentence ID: sent_5286
#   Word: '1' in Sentence ID: sent_5505
#   Word: '1.5' in Sentence ID: sent_8450
#
#
# True label: I-Strength, Predicted label: B-Duration
#   Word: 'mg' in Sentence ID: sent_3010
#
#
# True label: I-Duration, Predicted label: B-Duration
#   Word: '5' in Sentence ID: sent_3041
#
#
# True label: B-Duration, Predicted label: B-Dosage
#   Word: '4' in Sentence ID: sent_3046
#   Word: '5' in Sentence ID: sent_5403
#   Word: '8' in Sentence ID: sent_6380
#   Word: '3' in Sentence ID: sent_10411
#
#
# True label: B-Duration, Predicted label: I-Form
#   Word: 'for' in Sentence ID: sent_3047
#   Word: '2' in Sentence ID: sent_6538
#
#
# True label: I-ADE, Predicted label: B-Drug
#   Word: 'and' in Sentence ID: sent_3052
#   Word: 'and' in Sentence ID: sent_5851
#   Word: 'face' in Sentence ID: sent_5871
#   Word: 'EF' in Sentence ID: sent_6189
#   Word: 'gastric.' in Sentence ID: sent_6672
#   Word: 'insufficiency' in Sentence ID: sent_6955
#   Word: 'RENAL' in Sentence ID: sent_7810
#   Word: 'Compromise' in Sentence ID: sent_8822
#   Word: 'GI' in Sentence ID: sent_9803
#
#
# True label: B-ADE, Predicted label: I-Form
#   Word: 'Osteoporosis' in Sentence ID: sent_3208
#   Word: 'Drug' in Sentence ID: sent_6344
#
#
# True label: B-Dosage, Predicted label: I-Reason
#   Word: 'One' in Sentence ID: sent_3214
#   Word: 'One' in Sentence ID: sent_3951
#   Word: 'One' in Sentence ID: sent_4819
#   Word: 'One' in Sentence ID: sent_5102
#   Word: '1.5' in Sentence ID: sent_5180
#   Word: 'One' in Sentence ID: sent_7460
#   Word: 'One' in Sentence ID: sent_8157
#   Word: 'One' in Sentence ID: sent_8590
#   Word: '1' in Sentence ID: sent_10420
#   Word: 'One' in Sentence ID: sent_10432
#   Word: '1L' in Sentence ID: sent_10773
#   Word: 'One' in Sentence ID: sent_10811
#   Word: 'Two' in Sentence ID: sent_10854
#
#
# True label: B-Route, Predicted label: B-ADE
#   Word: 'po' in Sentence ID: sent_3328
#   Word: 'gtt' in Sentence ID: sent_7435
#
#
# True label: I-Form, Predicted label: I-Reason
#   Word: ')' in Sentence ID: sent_3396
#   Word: ')' in Sentence ID: sent_3951
#   Word: 'Delayed' in Sentence ID: sent_5447
#   Word: 'hr' in Sentence ID: sent_10424
#   Word: 'hr.' in Sentence ID: sent_11036
#
#
# True label: I-Form, Predicted label: I-Duration
#   Word: ',' in Sentence ID: sent_3396
#   Word: ')' in Sentence ID: sent_4818
#   Word: 'Extended' in Sentence ID: sent_8454
#   Word: '24' in Sentence ID: sent_8454
#   Word: 'hr' in Sentence ID: sent_8454
#
#
# True label: B-Frequency, Predicted label: I-Reason
#   Word: 'DAILY' in Sentence ID: sent_3466
#   Word: 'DAILY.' in Sentence ID: sent_3953
#   Word: 'QD.' in Sentence ID: sent_4185
#   Word: 'TID' in Sentence ID: sent_4190
#   Word: 'qday.' in Sentence ID: sent_5113
#   Word: 'twice' in Sentence ID: sent_5116
#   Word: 'DAILY.' in Sentence ID: sent_5503
#   Word: 'daily.' in Sentence ID: sent_5827
#   Word: 'QHS' in Sentence ID: sent_9500
#   Word: 'q' in Sentence ID: sent_9682
#   Word: 'HS.' in Sentence ID: sent_11059
#
#
# True label: B-Form, Predicted label: I-Route
#   Word: 'Tablet' in Sentence ID: sent_3474
#   Word: 'Solution' in Sentence ID: sent_4196
#   Word: 'Capsule' in Sentence ID: sent_9358
#   Word: 'Capsule' in Sentence ID: sent_9448
#
#
# True label: I-Reason, Predicted label: I-ADE
#   Word: 'hypotension' in Sentence ID: sent_3534
#
#
# True label: I-Duration, Predicted label: B-Strength
#   Word: 'day' in Sentence ID: sent_3590
#   Word: 'week' in Sentence ID: sent_9117
#
#
# True label: B-Strength, Predicted label: I-Route
#   Word: '0.02' in Sentence ID: sent_3668
#
#
# True label: I-Reason, Predicted label: I-Route
#   Word: 'breath.' in Sentence ID: sent_3669
#   Word: 'tissue' in Sentence ID: sent_4342
#   Word: 'infection' in Sentence ID: sent_4342
#   Word: 'mobilization' in Sentence ID: sent_10927
#
#
# True label: B-Duration, Predicted label: B-Frequency
#   Word: '7' in Sentence ID: sent_3901
#   Word: '5' in Sentence ID: sent_7998
#   Word: 'until' in Sentence ID: sent_10673
#
#
# True label: B-Route, Predicted label: I-Duration
#   Word: 'IV' in Sentence ID: sent_3981
#   Word: 'PO' in Sentence ID: sent_7027
#   Word: 'PO' in Sentence ID: sent_9613
#
#
# True label: I-Drug, Predicted label: I-ADE
#   Word: 'meds' in Sentence ID: sent_4006
#   Word: '(' in Sentence ID: sent_4124
#   Word: 'Saline' in Sentence ID: sent_5622
#   Word: 'medications' in Sentence ID: sent_8689
#
#
# True label: I-Strength, Predicted label: B-ADE
#   Word: 'mg' in Sentence ID: sent_4013
#   Word: 'mg' in Sentence ID: sent_5102
#   Word: 'mg' in Sentence ID: sent_6624
#   Word: 'mg' in Sentence ID: sent_10632
#
#
# True label: B-ADE, Predicted label: B-Duration
#   Word: 'intoxication.' in Sentence ID: sent_4119
#
#
# True label: B-Frequency, Predicted label: B-Duration
#   Word: 'Q8AM' in Sentence ID: sent_4257
#   Word: 'every' in Sentence ID: sent_6628
#   Word: 'DAILY' in Sentence ID: sent_7445
#   Word: 'daily' in Sentence ID: sent_7735
#   Word: 'HS' in Sentence ID: sent_8451
#   Word: 'twice' in Sentence ID: sent_9867
#
#
# True label: B-ADE, Predicted label: B-Dosage
#   Word: 'Altered' in Sentence ID: sent_4344
#   Word: 'petticheal/macular' in Sentence ID: sent_6344
#   Word: 'hypotensive' in Sentence ID: sent_10020
#
#
# True label: I-ADE, Predicted label: I-Dosage
#   Word: 'Mental' in Sentence ID: sent_4344
#   Word: 'Status' in Sentence ID: sent_4344
#   Word: 'eruption' in Sentence ID: sent_5958
#   Word: 'rash.' in Sentence ID: sent_6344
#   Word: 'are' in Sentence ID: sent_8463
#   Word: 'elevated' in Sentence ID: sent_8463
#   Word: 'episodes' in Sentence ID: sent_10020
#
#
# True label: B-Frequency, Predicted label: I-ADE
#   Word: 'TID' in Sentence ID: sent_4608
#   Word: 'every' in Sentence ID: sent_5306
#   Word: 'DAILY.' in Sentence ID: sent_10274
#
#
# True label: I-Route, Predicted label: I-Frequency
#   Word: 'eye' in Sentence ID: sent_4653
#   Word: 'Ophthalmic' in Sentence ID: sent_4890
#   Word: 'skin' in Sentence ID: sent_8983
#   Word: 'mouth' in Sentence ID: sent_9122
#   Word: 'cannula' in Sentence ID: sent_9122
#   Word: 'mouth' in Sentence ID: sent_9125
#
#
# True label: B-Duration, Predicted label: I-Reason
#   Word: 'for' in Sentence ID: sent_4708
#   Word: 'five' in Sentence ID: sent_5939
#
#
# True label: I-Duration, Predicted label: I-Reason
#   Word: '24hrs' in Sentence ID: sent_4708
#   Word: 'days' in Sentence ID: sent_5939
#   Word: 'days' in Sentence ID: sent_10682
#
#
# True label: I-Form, Predicted label: B-Duration
#   Word: 'E.C.' in Sentence ID: sent_4818
#   Word: 'Rel' in Sentence ID: sent_8454
#   Word: 'Release' in Sentence ID: sent_10755
#
#
# True label: B-ADE, Predicted label: I-ADE
#   Word: 'hypotension' in Sentence ID: sent_4872
#   Word: 'PR' in Sentence ID: sent_6010
#
#
# True label: I-ADE, Predicted label: B-ADE
#   Word: 'output' in Sentence ID: sent_4872
#
#
# True label: I-Reason, Predicted label: B-Duration
#   Word: 'cellulitis' in Sentence ID: sent_4908
#   Word: 'to' in Sentence ID: sent_7240
#
#
# True label: I-Route, Predicted label: B-Strength
#   Word: 'tube' in Sentence ID: sent_5213
#   Word: 'mouth.' in Sentence ID: sent_9754
#   Word: 'mouth' in Sentence ID: sent_10424
#
#
# True label: I-Route, Predicted label: I-Strength
#   Word: 'tube' in Sentence ID: sent_5213
#   Word: '.' in Sentence ID: sent_6816
#
#
# True label: I-Route, Predicted label: B-Frequency
#   Word: 'tube' in Sentence ID: sent_5213
#
#
# True label: I-Reason, Predicted label: B-Reason
#   Word: 'Cirrhosis' in Sentence ID: sent_5275
#   Word: 'atrial' in Sentence ID: sent_5299
#   Word: ',' in Sentence ID: sent_5826
#   Word: 'Serratia' in Sentence ID: sent_6209
#   Word: 'opacification' in Sentence ID: sent_6211
#   Word: 'syndrome' in Sentence ID: sent_6958
#   Word: 'right' in Sentence ID: sent_7323
#   Word: 'stabilization' in Sentence ID: sent_9113
#   Word: 'further.' in Sentence ID: sent_10147
#   Word: 'acquired' in Sentence ID: sent_10616
#   Word: 'would' in Sentence ID: sent_10770
#
#
# True label: B-Reason, Predicted label: B-ADE
#   Word: 'DM' in Sentence ID: sent_5277
#   Word: 'rash' in Sentence ID: sent_8497
#
#
# True label: B-Duration, Predicted label: I-Duration
#   Word: '7' in Sentence ID: sent_5323
#
#
# True label: B-Duration, Predicted label: I-Frequency
#   Word: 'for' in Sentence ID: sent_5439
#   Word: '12hours' in Sentence ID: sent_7887
#   Word: 'for' in Sentence ID: sent_9358
#   Word: '10days' in Sentence ID: sent_10801
#
#
# True label: B-Frequency, Predicted label: I-Route
#   Word: 'Q4H' in Sentence ID: sent_5500
#   Word: 'qhs.' in Sentence ID: sent_8326
#   Word: 'once' in Sentence ID: sent_8327
#   Word: 'Q6H.' in Sentence ID: sent_10368
#
#
# True label: I-ADE, Predicted label: B-Route
#   Word: 'rash' in Sentence ID: sent_5594
#   Word: 'worsened' in Sentence ID: sent_5851
#   Word: 'osteoporosis' in Sentence ID: sent_7513
#   Word: 'symptoms' in Sentence ID: sent_8622
#
#
# True label: I-ADE, Predicted label: B-Frequency
#   Word: 'to.' in Sentence ID: sent_5851
#   Word: 'bleed' in Sentence ID: sent_6672
#
#
# True label: B-Reason, Predicted label: B-Duration
#   Word: 'LLE' in Sentence ID: sent_5956
#
#
# True label: I-Reason, Predicted label: I-Duration
#   Word: 'DVT' in Sentence ID: sent_5956
#   Word: 'cancer' in Sentence ID: sent_7161
#   Word: 'control' in Sentence ID: sent_7240
#   Word: 'hypertension' in Sentence ID: sent_7240
#
#
# True label: I-Reason, Predicted label: B-ADE
#   Word: 'dermatitis' in Sentence ID: sent_5958
#
#
# True label: B-ADE, Predicted label: B-Frequency
#   Word: 'drug' in Sentence ID: sent_6336
#   Word: 'Tachycardia' in Sentence ID: sent_7499
#   Word: 'hypertension.' in Sentence ID: sent_8129
#
#
# True label: I-ADE, Predicted label: I-Form
#   Word: 'Rash' in Sentence ID: sent_6344
#
#
# True label: I-Duration, Predicted label: I-Drug
#   Word: 'days' in Sentence ID: sent_6355
#
#
# True label: I-Drug, Predicted label: B-Duration
#   Word: 'Tear' in Sentence ID: sent_6932
#
#
# True label: I-Drug, Predicted label: I-Duration
#   Word: 'with' in Sentence ID: sent_6932
#
#
# True label: I-ADE, Predicted label: B-Reason
#   Word: 'GI' in Sentence ID: sent_7108
#   Word: 'of' in Sentence ID: sent_9839
#
#
# True label: B-ADE, Predicted label: B-Form
#   Word: 'HIT' in Sentence ID: sent_8050
#   Word: 'orthostatic' in Sentence ID: sent_8622
#   Word: 'allergy' in Sentence ID: sent_8811
#
#
# True label: B-Route, Predicted label: B-Duration
#   Word: 'Inhalation' in Sentence ID: sent_8100
#   Word: 'by' in Sentence ID: sent_9867
#
#
# True label: B-Route, Predicted label: I-Route
#   Word: 'PO' in Sentence ID: sent_8327
#   Word: 'PO' in Sentence ID: sent_9358
#
#
# True label: B-Form, Predicted label: B-Duration
#   Word: 'Tablet' in Sentence ID: sent_8328
#   Word: 'Tablet' in Sentence ID: sent_8454
#   Word: 'tab' in Sentence ID: sent_9613
#
#
# True label: I-Drug, Predicted label: B-ADE
#   Word: 'MALEATE' in Sentence ID: sent_8391
#
#
# True label: B-ADE, Predicted label: B-Route
#   Word: 'Airway' in Sentence ID: sent_8822
#   Word: 'delirium' in Sentence ID: sent_9441
#
#
# True label: B-Duration, Predicted label: I-Drug
#   Word: '6' in Sentence ID: sent_9117
#   Word: 'for' in Sentence ID: sent_9618
#
#
# True label: I-Route, Predicted label: I-Form
#   Word: 'mouth' in Sentence ID: sent_9121
#
#
# True label: I-Drug, Predicted label: I-Route
#   Word: 'cells' in Sentence ID: sent_9697
#
#
# True label: B-Drug, Predicted label: I-Route
#   Word: 'Bactrim' in Sentence ID: sent_9698
#
#
# True label: I-Route, Predicted label: B-Duration
#   Word: 'mouth' in Sentence ID: sent_9752
#
#
# True label: I-Route, Predicted label: I-Reason
#   Word: 'mouth' in Sentence ID: sent_9753
#
#
# True label: I-Route, Predicted label: I-Duration
#   Word: 'mouth' in Sentence ID: sent_9867
#
#
# True label: B-Duration, Predicted label: B-Route
#   Word: 'for' in Sentence ID: sent_10040
#   Word: 'x7' in Sentence ID: sent_10631
#
#
# True label: I-Route, Predicted label: B-ADE
#   Word: 'going' in Sentence ID: sent_10096
#
#
# True label: I-Strength, Predicted label: I-Duration
#   Word: 'mg' in Sentence ID: sent_10534
#   Word: 'mg' in Sentence ID: sent_10811
#
#
# True label: B-Strength, Predicted label: B-Duration
#   Word: '5' in Sentence ID: sent_10811
#
#
# True label: I-Duration, Predicted label: I-ADE
#   Word: 'one' in Sentence ID: sent_11027

# %%
from collections import defaultdict

# Dictionary to hold tuples of (word, sentence_id) for correct classifications
correctly_classified_words_with_ids = defaultdict(list)

for _, row in data_test.iterrows():
    true_labels = row['word_labels'].split(',')
    pred_labels = row['predicted_labels'].split(',')
    words = row['sentence'].split()  # Assuming words are space-separated
    sentence_id = row['sentence_id']  # Capture the sentence ID

    # Ensure the lists are of the same length; this might need adjusting depending on your data's preprocessing
    assert len(true_labels) == len(pred_labels) == len(words), "Length mismatch between words and labels"

    for true_label, pred_label, word in zip(true_labels, pred_labels, words):
        if true_label == pred_label:  # Word is correctly classified
            key = true_label  # Use true label as the key
            # Append a tuple of (word, sentence_id) for correct classifications
            correctly_classified_words_with_ids[key].append((word, sentence_id))

# %%
correctly_classified_words_with_ids
# Out:
# defaultdict(list,
#             {'O': [('Admission', 'sent_0'),
#               ('Date', 'sent_0'),
#               (':', 'sent_0'),
#               ('[', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('2109', 'sent_0'),
#               ('-', 'sent_0'),
#               ('7', 'sent_0'),
#               ('-', 'sent_0'),
#               ('21', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               (']', 'sent_0'),
#               ('Discharge', 'sent_0'),
#               ('Date', 'sent_0'),
#               (':', 'sent_0'),
#               ('[', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('2109', 'sent_0'),
#               ('-', 'sent_0'),
#               ('8', 'sent_0'),
#               ('-', 'sent_0'),
#               ('13', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('].', 'sent_0'),
#               ('Date', 'sent_0'),
#               ('of', 'sent_0'),
#               ('Birth', 'sent_0'),
#               (':', 'sent_0'),
#               ('[', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('2053', 'sent_0'),
#               ('-', 'sent_0'),
#               ('6', 'sent_0'),
#               ('-', 'sent_0'),
#               ('5', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               (']', 'sent_0'),
#               ('Sex', 'sent_0'),
#               (':', 'sent_0'),
#               ('F.', 'sent_0'),
#               ('Service', 'sent_0'),
#               (':', 'sent_0'),
#               ('[', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('Doctor', 'sent_0'),
#               ('Last', 'sent_0'),
#               ('Name', 'sent_0'),
#               ('1181', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               (']', 'sent_0'),
#               ('MEDICINE.', 'sent_0'),
#               ('HISTORY', 'sent_0'),
#               ('OF', 'sent_0'),
#               ('PRESENT', 'sent_0'),
#               ('ILLNESS', 'sent_0'),
#               (':', 'sent_0'),
#               ('This', 'sent_0'),
#               ('is', 'sent_0'),
#               ('a', 'sent_0'),
#               ('56', 'sent_0'),
#               ('-', 'sent_0'),
#               ('year', 'sent_0'),
#               ('-', 'sent_0'),
#               ('old', 'sent_0'),
#               ('white.', 'sent_0'),
#               ('female', 'sent_0'),
#               ('with', 'sent_0'),
#               ('a', 'sent_0'),
#               ('history', 'sent_0'),
#               ('of', 'sent_0'),
#               ('right', 'sent_0'),
#               ('frontal', 'sent_0'),
#               ('craniotomy', 'sent_0'),
#               ('on', 'sent_0'),
#               ('[', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               ('2109', 'sent_0'),
#               ('-', 'sent_0'),
#               ('7', 'sent_0'),
#               ('-', 'sent_0'),
#               ('1', 'sent_0'),
#               ('*', 'sent_0'),
#               ('*', 'sent_0'),
#               (']', 'sent_0'),
#               (',', 'sent_0'),
#               ('for', 'sent_0'),
#               ('a', 'sent_0'),
#               ('dysembryoplastic', 'sent_0'),
#               ('angioneural', 'sent_0'),
#               ('epithelial', 'sent_0'),
#               ('lesion.', 'sent_0'),
#               ('with', 'sent_1'),
#               ('features', 'sent_1'),
#               ('of', 'sent_1'),
#               ('an', 'sent_1'),
#               ('oligodendroglioma', 'sent_1'),
#               ('who', 'sent_1'),
#               ('was', 'sent_1'),
#               ('started', 'sent_1'),
#               ('on.', 'sent_1'),
#               ('postoperatively', 'sent_1'),
#               ('for', 'sent_1'),
#               ('and', 'sent_1'),
#               ('was.', 'sent_1'),
#               ('subsequently', 'sent_1'),
#               ('developed', 'sent_1'),
#               ('and', 'sent_1'),
#               ('seen', 'sent_1'),
#               ('by', 'sent_1'),
#               ('an.', 'sent_1'),
#               ('optometrist', 'sent_1'),
#               ('treated', 'sent_1'),
#               ('it', 'sent_1'),
#               ('with', 'sent_1'),
#               ('..', 'sent_1'),
#               ('The', 'sent_1'),
#               ('patient', 'sent_1'),
#               ('then', 'sent_1'),
#               ('developed', 'sent_1'),
#               ('and', 'sent_1'),
#               ('in', 'sent_1'),
#               ('the', 'sent_1'),
#               ('chest.', 'sent_1'),
#               ('the', 'sent_2'),
#               ('night', 'sent_2'),
#               ('before', 'sent_2'),
#               ('admission', 'sent_2'),
#               ('which', 'sent_2'),
#               ('rapidly', 'sent_2'),
#               ('spread', 'sent_2'),
#               ('to', 'sent_2'),
#               ('the', 'sent_2'),
#               ('face', 'sent_2'),
#               (',.', 'sent_2'),
#               ('trunk', 'sent_2'),
#               (',', 'sent_2'),
#               ('and', 'sent_2'),
#               ('upper', 'sent_2'),
#               ('extremities', 'sent_2'),
#               ('within', 'sent_2'),
#               ('the', 'sent_2'),
#               ('last', 'sent_2'),
#               ('24', 'sent_2'),
#               ('hours', 'sent_2'),
#               ('.', 'sent_2'),
#               ('The.', 'sent_2'),
#               ('patient', 'sent_2'),
#               ('was', 'sent_2'),
#               ('unable', 'sent_2'),
#               ('to', 'sent_2'),
#               ('eat', 'sent_2'),
#               ('secondary', 'sent_2'),
#               ('to', 'sent_2'),
#               ('mouth', 'sent_2'),
#               ('pain', 'sent_2'),
#               ('.', 'sent_2'),
#               ('She', 'sent_2'),
#               ('had.', 'sent_2'),
#               (',', 'sent_2'),
#               ('and', 'sent_2'),
#               ('.', 'sent_2'),
#               ('There', 'sent_2'),
#               ('were', 'sent_2'),
#               ('no', 'sent_2'),
#               ('genital.', 'sent_2'),
#               ('the', 'sent_2'),
#               ('morning', 'sent_2'),
#               ('of', 'sent_2'),
#               ('[', 'sent_2'),
#               ('*', 'sent_2'),
#               ('*', 'sent_2'),
#               ('7', 'sent_2'),
#               ('-', 'sent_2'),
#               ('20', 'sent_2'),
#               ('*', 'sent_2'),
#               ('*', 'sent_2'),
#               (']', 'sent_2'),
#               ('..', 'sent_2'),
#               ('PAST', 'sent_3'),
#               ('MEDICAL', 'sent_3'),
#               ('HISTORY', 'sent_3'),
#               (':', 'sent_3'),
#               ('1', 'sent_3'),
#               ('.', 'sent_3'),
#               ('Hypercholesterolemia', 'sent_3'),
#               ('.', 'sent_3'),
#               ('2', 'sent_3'),
#               ('.', 'sent_3'),
#               ('Benign.', 'sent_3'),
#               ('right', 'sent_3'),
#               ('frontal', 'sent_3'),
#               ('cystic', 'sent_3'),
#               ('tumor', 'sent_3'),
#               ('status', 'sent_3'),
#               ('post', 'sent_3'),
#               ('right', 'sent_3'),
#               ('frontal.', 'sent_3'),
#               ('craniotomy', 'sent_3'),
#               ('on', 'sent_3'),
#               ('*', 'sent_3'),
#               ('*', 'sent_3'),
#               ('2109', 'sent_3'),
#               ('-', 'sent_3'),
#               ('*', 'sent_3'),
#               ('*', 'sent_3'),
#               (']', 'sent_3'),
#               ('..', 'sent_3'),
#               ('ALLERGIES', 'sent_3'),
#               (':', 'sent_3'),
#               ('NO', 'sent_3'),
#               ('..', 'sent_3'),
#               (':', 'sent_3'),
#               (',', 'sent_3'),
#               (',', 'sent_3'),
#               (',.', 'sent_3'),
#               ('previously', 'sent_4'),
#               ('on', 'sent_4'),
#               ('tapered', 'sent_4'),
#               ('over', 'sent_4'),
#               ('and.', 'sent_4'),
#               ('discontinued', 'sent_4'),
#               ('a', 'sent_4'),
#               ('week', 'sent_4'),
#               ('ago', 'sent_4'),
#               ('..', 'sent_4'),
#               ('SOCIAL', 'sent_4'),
#               ('HISTORY', 'sent_4'),
#               (':', 'sent_4'),
#               ('The', 'sent_4'),
#               ('patient', 'sent_4'),
#               ('lives', 'sent_4'),
#               ('with', 'sent_4'),
#               ('her', 'sent_4'),
#               ('husband', 'sent_4'),
#               (',.', 'sent_4'),
#               ('daughter', 'sent_4'),
#               (',', 'sent_4'),
#               ('and', 'sent_4'),
#               ('son', 'sent_4'),
#               ('.', 'sent_4'),
#               ('[', 'sent_4'),
#               ('*', 'sent_4'),
#               ('*', 'sent_4'),
#               ('Name', 'sent_4'),
#               ('(', 'sent_4'),
#               ('NI', 'sent_4'),
#               (')', 'sent_4'),
#               ('*', 'sent_4'),
#               ('*', 'sent_4'),
#               (']', 'sent_4'),
#               ('smoking', 'sent_4'),
#               ('or', 'sent_4'),
#               ('ethanol', 'sent_4'),
#               ('use', 'sent_4'),
#               ('history', 'sent_4'),
#               ('..', 'sent_4'),
#               ('PHYSICAL', 'sent_4'),
#               ('EXAMINATION', 'sent_4'),
#               (':', 'sent_4'),
#               ('Vital', 'sent_4'),
#               ('signs', 'sent_4'),
#               (':', 'sent_4'),
#               ('T', 'sent_4'),
#               ('-', 'sent_4'),
#               ('max', 'sent_4'),
#               ('104.3??????', 'sent_4'),
#               (',', 'sent_4'),
#               ('currently.', 'sent_4'),
#               ('100.8??????', 'sent_5'),
#               (',', 'sent_5'),
#               ('heart', 'sent_5'),
#               ('rate', 'sent_5'),
#               ('107', 'sent_5'),
#               ('-', 'sent_5'),
#               ('110', 'sent_5'),
#               (',', 'sent_5'),
#               ('blood', 'sent_5'),
#               ('pressure', 'sent_5'),
#               ('110/27', 'sent_5'),
#               (',.', 'sent_5'),
#               ('respirations', 'sent_5'),
#               ('15', 'sent_5'),
#               ('-', 'sent_5'),
#               ('20', 'sent_5'),
#               (',', 'sent_5'),
#               ('oxygen', 'sent_5'),
#               ('saturation', 'sent_5'),
#               ('98', 'sent_5'),
#               ('%', 'sent_5'),
#               ('on', 'sent_5'),
#               ('room', 'sent_5'),
#               ('air', 'sent_5'),
#               ('..', 'sent_5'),
#               ('General', 'sent_5'),
#               (':', 'sent_5'),
#               ('The', 'sent_5'),
#               ('was', 'sent_5'),
#               ('an', 'sent_5'),
#               ('alert', 'sent_5'),
#               ('-', 'sent_5'),
#               ('woman', 'sent_5'),
#               ('with.', 'sent_5'),
#               ('postsurgical', 'sent_5'),
#               ('.', 'sent_5'),
#               ('Head', 'sent_5'),
#               ('and', 'sent_5'),
#               ('neck', 'sent_5'),
#               (':', 'sent_5'),
#               ('Injected', 'sent_5'),
#               ('conjunctivae', 'sent_5'),
#               (',.', 'sent_5'),
#               ('greenish', 'sent_5'),
#               ('ocular', 'sent_5'),
#               ('discharge', 'sent_5'),
#               (',', 'sent_5'),
#               ('ulcerative', 'sent_5'),
#               ('oral', 'sent_5'),
#               ('lesions', 'sent_5'),
#               ('..', 'sent_5'),
#               ('Cardiovascular', 'sent_6'),
#               (':', 'sent_6'),
#               ('Regular', 'sent_6'),
#               ('rhythm', 'sent_6'),
#               ('.', 'sent_6'),
#               ('Rapid', 'sent_6'),
#               ('rate', 'sent_6'),
#               ('.', 'sent_6'),
#               ('No', 'sent_6'),
#               ('murmurs', 'sent_6'),
#               ('..', 'sent_6'),
#               ('Pulmonary', 'sent_6'),
#               (':', 'sent_6'),
#               ('Clear', 'sent_6'),
#               ('to', 'sent_6'),
#               ('auscultation', 'sent_6'),
#               ('bilaterally', 'sent_6'),
#               ('.', 'sent_6'),
#               ('Abdomen', 'sent_6'),
#               (':.', 'sent_6'),
#               ('Normoactive', 'sent_6'),
#               ('bowel', 'sent_6'),
#               ('sounds', 'sent_6'),
#               ('.', 'sent_6'),
#               ('Soft', 'sent_6'),
#               (',', 'sent_6'),
#               ('nontender', 'sent_6'),
#               (',', 'sent_6'),
#               ('nondistended', 'sent_6'),
#               ('..', 'sent_6'),
#               ('Extremities', 'sent_6'),
#               (':', 'sent_6'),
#               ('No', 'sent_6'),
#               ('edema', 'sent_6'),
#               ('.', 'sent_6'),
#               ('Skin', 'sent_6'),
#               (':', 'sent_6'),
#               ('Diffuse', 'sent_6'),
#               ('erythema', 'sent_6'),
#               ('and', 'sent_6'),
#               ('pustules.', 'sent_6'),
#               ('on', 'sent_6'),
#               ('the', 'sent_6'),
#               ('face', 'sent_6'),
#               ('.', 'sent_6'),
#               ('Patulous', 'sent_6'),
#               ('pustules', 'sent_6'),
#               ('on', 'sent_6'),
#               ('the', 'sent_6'),
#               ('chest', 'sent_6'),
#               (',', 'sent_6'),
#               ('back', 'sent_6'),
#               (',', 'sent_6'),
#               ('and.', 'sent_6'),
#               ('proximal', 'sent_7'),
#               ('upper', 'sent_7'),
#               ('extremities', 'sent_7'),
#               ('.', 'sent_7'),
#               ('GU', 'sent_7'),
#               (':', 'sent_7'),
#               ('No', 'sent_7'),
#               ('genital', 'sent_7'),
#               ('lesions', 'sent_7'),
#               ('..', 'sent_7'),
#               ('LABORATORY', 'sent_7'),
#               ('DATA', 'sent_7'),
#               (':', 'sent_7'),
#               ('Hematocrit', 'sent_7'),
#               ('34.1', 'sent_7'),
#               (',', 'sent_7'),
#               ('WBC', 'sent_7'),
#               ('10.3', 'sent_7'),
#               (',', 'sent_7'),
#               ('platelet', 'sent_7'),
#               ('count.', 'sent_7'),
#               ('291', 'sent_7'),
#               (',', 'sent_7'),
#               ('000', 'sent_7'),
#               (',', 'sent_7'),
#               ('differential', 'sent_7'),
#               ('of', 'sent_7'),
#               ('87', 'sent_7'),
#               ('neutrophils', 'sent_7'),
#               (',', 'sent_7'),
#               ('0', 'sent_7'),
#               ('bands', 'sent_7'),
#               (';', 'sent_7'),
#               ('sodium', 'sent_7'),
#               ('133', 'sent_7'),
#               (',.', 'sent_7'),
#               ('potassium', 'sent_7'),
#               ('3.8', 'sent_7'),
#               (',', 'sent_7'),
#               ('chloride', 'sent_7'),
#               ('93', 'sent_7'),
#               (',', 'sent_7'),
#               ('CO2', 'sent_7'),
#               ('21', 'sent_7'),
#               (',', 'sent_7'),
#               ('BUN', 'sent_7'),
#               ('17', 'sent_7'),
#               (',', 'sent_7'),
#               ('creatinine', 'sent_7'),
#               ('0.9', 'sent_7'),
#               (',.', 'sent_7'),
#               ('glucose', 'sent_7'),
#               ('121', 'sent_7'),
#               (';', 'sent_7'),
#               ('ALT', 'sent_7'),
#               ('39', 'sent_7'),
#               (',', 'sent_7'),
#               ('AST', 'sent_7'),
#               ('42', 'sent_7'),
#               (',', 'sent_7'),
#               ('LDH', 'sent_7'),
#               ('434', 'sent_7'),
#               ('amylase', 'sent_7'),
#               ('63', 'sent_7'),
#               (',', 'sent_7'),
#               ('albumin.', 'sent_7'),
#               ('total', 'sent_8'),
#               ('bilirubin', 'sent_8'),
#               ('0.3', 'sent_8'),
#               (';', 'sent_8'),
#               ('urinalysis', 'sent_8'),
#               ('with', 'sent_8'),
#               ('positive', 'sent_8'),
#               ('ketones', 'sent_8'),
#               (',.', 'sent_8'),
#               ('negative', 'sent_8'),
#               ('nitrites', 'sent_8'),
#               (';', 'sent_8'),
#               ('urine', 'sent_8'),
#               ('culture', 'sent_8'),
#               ('pending', 'sent_8'),
#               (';', 'sent_8'),
#               ('times', 'sent_8'),
#               ('two', 'sent_8'),
#               ('pending', 'sent_8'),
#               (';', 'sent_8'),
#               ('conjunctival', 'sent_8'),
#               ('culture', 'sent_8'),
#               ('pending', 'sent_8'),
#               ('..', 'sent_8'),
#               ('HOSPITAL', 'sent_8'),
#               ('COURSE', 'sent_8'),
#               (':', 'sent_8'),
#               ('Given', 'sent_8'),
#               ('the', 'sent_8'),
#               ('Medical', 'sent_9'),
#               ('Intensive', 'sent_9'),
#               ('monitoring', 'sent_9'),
#               ('.', 'sent_9'),
#               ('skin', 'sent_9'),
#               ('flora', 'sent_9'),
#               (',', 'sent_9'),
#               ('and', 'sent_9'),
#               ('Ophthalmology', 'sent_9'),
#               ('Care', 'sent_10'),
#               ('Unit', 'sent_10'),
#               ('was.', 'sent_10'),
#               ('was', 'sent_10'),
#               ('discharged', 'sent_10'),
#               ('included', 'sent_10'),
#               ('consultation', 'sent_10'),
#               ('with.', 'sent_10'),
#               ('to', 'sent_10'),
#               ('her', 'sent_10'),
#               ('skin', 'sent_10'),
#               ('lesions', 'sent_10'),
#               (',', 'sent_10'),
#               ('they.', 'sent_10'),
#               ('continued', 'sent_11'),
#               ('exfoliate', 'sent_11'),
#               ('over', 'sent_11'),
#               ('the', 'sent_11'),
#               ('next', 'sent_11'),
#               ('couple', 'sent_11'),
#               ('of', 'sent_11'),
#               ('days', 'sent_11'),
#               (',', 'sent_11'),
#               ('and', 'sent_11'),
#               ('her.', 'sent_11'),
#               ('skin', 'sent_11'),
#               ('care', 'sent_11'),
#               ('included', 'sent_11'),
#               ('frequent', 'sent_11'),
#               ('application', 'sent_11'),
#               ('to', 'sent_11'),
#               ('.', 'sent_11'),
#               ('The', 'sent_11'),
#               ("patient's.", 'sent_11'),
#               ('intake', 'sent_11'),
#               ('and', 'sent_11'),
#               ('output', 'sent_11'),
#               ('were', 'sent_11'),
#               ('closely', 'sent_11'),
#               ('monitored', 'sent_11'),
#               ('and', 'sent_11'),
#               ('replaced.', 'sent_11'),
#               ('appropriately', 'sent_11'),
#               (';', 'sent_11'),
#               ('however', 'sent_11'),
#               (',', 'sent_11'),
#               ('the', 'sent_11'),
#               ('intensive', 'sent_11'),
#               ('nursing', 'sent_11'),
#               ('care.', 'sent_11'),
#               ('requirement', 'sent_12'),
#               ('made', 'sent_12'),
#               ('it', 'sent_12'),
#               ('difficult', 'sent_12'),
#               ('for', 'sent_12'),
#               ('the', 'sent_12'),
#               ('patient', 'sent_12'),
#               ('to', 'sent_12'),
#               ('receive.', 'sent_12'),
#               ('adequate', 'sent_12'),
#               ('on', 'sent_12'),
#               ('the', 'sent_12'),
#               ('floor', 'sent_12'),
#               (',', 'sent_12'),
#               ('and', 'sent_12'),
#               ('therefore', 'sent_12'),
#               (',', 'sent_12'),
#               ('she', 'sent_12'),
#               ('was', 'sent_12'),
#               ('transferred', 'sent_12'),
#               ('to.', 'sent_12'),
#               ('the', 'sent_12'),
#               ('Medical', 'sent_12'),
#               ('Intensive', 'sent_12'),
#               ('Care', 'sent_12'),
#               ('Unit', 'sent_12'),
#               ('again', 'sent_12'),
#               ('for', 'sent_12'),
#               ('frequent', 'sent_12'),
#               ('ophthalmic.', 'sent_12'),
#               ('applications', 'sent_12'),
#               ('and', 'sent_12'),
#               ('skin', 'sent_12'),
#               ('care', 'sent_12'),
#               ('..', 'sent_12'),
#               ('While', 'sent_12'),
#               ('in', 'sent_12'),
#               ('the', 'sent_12'),
#               ('MICU', 'sent_12'),
#               (',', 'sent_12'),
#               ('the', 'sent_12'),
#               ('patient', 'sent_12'),
#               ('continued', 'sent_12'),
#               ('to', 'sent_12'),
#               ('have', 'sent_12'),
#               ('meticulous.', 'sent_12'),
#               ('skin', 'sent_13'),
#               ('care', 'sent_13'),
#               ('and', 'sent_13'),
#               ('eye', 'sent_13'),
#               ('care', 'sent_13'),
#               ('.', 'sent_13'),
#               ('The', 'sent_13'),
#               ('skin', 'sent_13'),
#               ('lesions', 'sent_13'),
#               ('continued', 'sent_13'),
#               ('to.', 'sent_13'),
#               ('desquamate', 'sent_13'),
#               ('and', 'sent_13'),
#               ('exfoliate', 'sent_13'),
#               ('which', 'sent_13'),
#               ('is', 'sent_13'),
#               ('the', 'sent_13'),
#               ('natural.', 'sent_13'),
#               ('progression', 'sent_13'),
#               ('of', 'sent_13'),
#               ('this', 'sent_13'),
#               ('disease', 'sent_13'),
#               ('.', 'sent_13'),
#               ('She', 'sent_13'),
#               ('began', 'sent_13'),
#               ('to', 'sent_13'),
#               ('have', 'sent_13'),
#               ('involvement.', 'sent_13'),
#               ('of', 'sent_13'),
#               ('the', 'sent_13'),
#               ('genital', 'sent_13'),
#               ('area', 'sent_13'),
#               ('with', 'sent_13'),
#               ('continued', 'sent_13'),
#               ('desquamation', 'sent_13'),
#               ('of', 'sent_13'),
#               ('the.', 'sent_13'),
#               ('exfoliative', 'sent_13'),
#               ('lesions', 'sent_13'),
#               ('.', 'sent_13'),
#               ('Her', 'sent_13'),
#               ('course', 'sent_13'),
#               ('in', 'sent_13'),
#               ('the', 'sent_13'),
#               ('Intensive', 'sent_13'),
#               ('Care', 'sent_13'),
#               ('Unit.', 'sent_13'),
#               ('within', 'sent_14'),
#               ('the', 'sent_14'),
#               ('next', 'sent_14'),
#               ('8', 'sent_14'),
#               ('-', 'sent_14'),
#               ('10', 'sent_14'),
#               ('days', 'sent_14'),
#               ('was', 'sent_14'),
#               ('a', 'sent_14'),
#               ('slow', 'sent_14'),
#               ('but', 'sent_14'),
#               ('gradual', 'sent_14'),
#               ('improvement.', 'sent_14'),
#               ('from', 'sent_14'),
#               ('a', 'sent_14'),
#               ('dermatologic', 'sent_14'),
#               ('and', 'sent_14'),
#               ('ophthalmologic', 'sent_14'),
#               ('standpoint', 'sent_14'),
#               ('..', 'sent_14'),
#               ('From', 'sent_14'),
#               ('a', 'sent_14'),
#               ('cardiovascular', 'sent_14'),
#               ('standpoint', 'sent_14'),
#               (',', 'sent_14'),
#               ('she', 'sent_14'),
#               ('was', 'sent_14'),
#               ('in', 'sent_14'),
#               ('sinus.', 'sent_14'),
#               ('tachycardia', 'sent_14'),
#               ('which', 'sent_14'),
#               ('was', 'sent_14'),
#               ('felt', 'sent_14'),
#               ('to', 'sent_14'),
#               ('be', 'sent_14'),
#               ('secondary', 'sent_14'),
#               ('to', 'sent_14'),
#               ('her.', 'sent_14'),
#               ('[', 'sent_14'),
#               ('*', 'sent_14'),
#               ('*', 'sent_14'),
#               ('Doctor', 'sent_14'),
#               ('Last', 'sent_14'),
#               ('Name', 'sent_14'),
#               ('*', 'sent_14'),
#               ('*', 'sent_14'),
#               (']', 'sent_14'),
#               ('-', 'sent_14'),
#               ('[', 'sent_14'),
#               ('*', 'sent_14'),
#               ('*', 'sent_14'),
#               ('Location', 'sent_14'),
#               ('(', 'sent_14'),
#               ('un', 'sent_14'),
#               (')', 'sent_14'),
#               ('*', 'sent_14'),
#               ('*', 'sent_14'),
#               (']', 'sent_14'),
#               ('syndrome', 'sent_14'),
#               ('leading', 'sent_14'),
#               ('to', 'sent_14'),
#               ('dehydration', 'sent_14'),
#               ('and.', 'sent_14'),
#               ('insensible', 'sent_15'),
#               ('fluid', 'sent_15'),
#               ('losses', 'sent_15'),
#               ('..', 'sent_15'),
#               ('While', 'sent_15'),
#               ('in', 'sent_15'),
#               ('the', 'sent_15'),
#               ('Intensive', 'sent_15'),
#               ('Care', 'sent_15'),
#               ('Unit', 'sent_15'),
#               (',', 'sent_15'),
#               ('she', 'sent_15'),
#               ('was', 'sent_15'),
#               ('also', 'sent_15'),
#               ('found', 'sent_15'),
#               ('to', 'sent_15'),
#               ('be.', 'sent_15'),
#               ('mildly', 'sent_15'),
#               ('hypoxic', 'sent_15'),
#               ('which', 'sent_15'),
#               ('is', 'sent_15'),
#               ('likely', 'sent_15'),
#               ('secondary', 'sent_15'),
#               ('to', 'sent_15'),
#               ('atelectasis.', 'sent_15'),
#               ('because', 'sent_15'),
#               ('of', 'sent_15'),
#               ('the', 'sent_15'),
#               ("patient's", 'sent_15'),
#               ('immobility', 'sent_15'),
#               ('.', 'sent_15'),
#               ('Lower', 'sent_15'),
#               ('extremity.', 'sent_15'),
#               ('Dopplers', 'sent_15'),
#               ('were', 'sent_15'),
#               ('also', 'sent_15'),
#               ('done', 'sent_15'),
#               (',', 'sent_15'),
#               ('and', 'sent_15'),
#               ('no', 'sent_15'),
#               ('deep', 'sent_15'),
#               ('venous', 'sent_15'),
#               ('thromboses', 'sent_15'),
#               ('were.', 'sent_15'),
#               ('found', 'sent_16'),
#               ('..', 'sent_16'),
#               ('From', 'sent_16'),
#               ('and', 'sent_16'),
#               ('Infectious', 'sent_16'),
#               ('Disease', 'sent_16'),
#               ('standpoint', 'sent_16'),
#               (',', 'sent_16'),
#               ('the', 'sent_16'),
#               ('patient', 'sent_16'),
#               ('was.', 'sent_16'),
#               ('started', 'sent_16'),
#               ('on', 'sent_16'),
#               ('empirically', 'sent_16'),
#               ('.', 'sent_16'),
#               ('Blood', 'sent_16'),
#               ('cultures.', 'sent_16'),
#               ('on', 'sent_16'),
#               ('the', 'sent_16'),
#               ('5th', 'sent_16'),
#               ('was', 'sent_16'),
#               ('with', 'sent_16'),
#               ('no', 'sent_16'),
#               ('growth', 'sent_16'),
#               ('times', 'sent_16'),
#               ('two', 'sent_16'),
#               (';', 'sent_16'),
#               ('however', 'sent_16'),
#               (',', 'sent_16'),
#               ('one', 'sent_16'),
#               ('bottle.', 'sent_16'),
#               ('from', 'sent_16'),
#               ('grew', 'sent_16'),
#               ('out', 'sent_16'),
#               ('gram', 'sent_16'),
#               ('positive', 'sent_16'),
#               ('cocci', 'sent_16'),
#               ('on', 'sent_16'),
#               ('[', 'sent_16'),
#               ('*', 'sent_16'),
#               ('*', 'sent_16'),
#               ('7', 'sent_16'),
#               ('*', 'sent_16'),
#               ('*', 'sent_16'),
#               (']', 'sent_16'),
#               ('..', 'sent_16'),
#               ('She', 'sent_17'),
#               ('was', 'sent_17'),
#               ('started', 'sent_17'),
#               ('on', 'sent_17'),
#               ('a', 'sent_17'),
#               ('course', 'sent_17'),
#               ('of', 'sent_17'),
#               ('.', 'sent_17'),
#               ('Subsequently', 'sent_17'),
#               ('the.', 'sent_17'),
#               ('organism', 'sent_17'),
#               ('was', 'sent_17'),
#               ('found', 'sent_17'),
#               ('to', 'sent_17'),
#               ('be', 'sent_17'),
#               ('CNS', 'sent_17'),
#               ('with', 'sent_17'),
#               ('Corynebacterium', 'sent_17'),
#               (',', 'sent_17'),
#               ('and.', 'sent_17'),
#               ('was', 'sent_17'),
#               ('discontinued', 'sent_17'),
#               ('prior', 'sent_17'),
#               ('to', 'sent_17'),
#               ('transfer', 'sent_17'),
#               ('to', 'sent_17'),
#               ('the', 'sent_17'),
#               ('floor', 'sent_17'),
#               ('on.', 'sent_17'),
#               ('[', 'sent_17'),
#               ('*', 'sent_17'),
#               ('*', 'sent_17'),
#               ('8', 'sent_17'),
#               ('-', 'sent_17'),
#               ('5', 'sent_17'),
#               ('*', 'sent_17'),
#               ('*', 'sent_17'),
#               (']', 'sent_17'),
#               ('..', 'sent_17'),
#               ('The', 'sent_17'),
#               ("patient's", 'sent_17'),
#               ('course', 'sent_17'),
#               ('on', 'sent_17'),
#               ('the', 'sent_17'),
#               ('floor', 'sent_17'),
#               ('was', 'sent_17'),
#               ('uncomplicated', 'sent_17'),
#               ('with.', 'sent_17'),
#               ('continued', 'sent_18'),
#               ('improvement', 'sent_18'),
#               ('..', 'sent_18'),
#               ('Dermatology', 'sent_18'),
#               (':', 'sent_18'),
#               ('The', 'sent_18'),
#               ('patient', 'sent_18'),
#               (',', 'sent_18'),
#               ('as', 'sent_18'),
#               ('indicated', 'sent_18'),
#               (',', 'sent_18'),
#               ('improved.', 'sent_18'),
#               ('dramatically', 'sent_18'),
#               ('from', 'sent_18'),
#               ('her', 'sent_18'),
#               ('presentation', 'sent_18'),
#               ('to', 'sent_18'),
#               ('the', 'sent_18'),
#               ('time', 'sent_18'),
#               ('of', 'sent_18'),
#               ('discharge', 'sent_18'),
#               ('..', 'sent_18'),
#               ('Her', 'sent_18'),
#               ('exfoliative', 'sent_18'),
#               ('lesions', 'sent_18'),
#               ('healed', 'sent_18'),
#               ('over', 'sent_18'),
#               ('the', 'sent_18'),
#               ('course', 'sent_18'),
#               ('of', 'sent_18'),
#               ('this.', 'sent_18'),
#               ('admission', 'sent_18'),
#               ('.', 'sent_18'),
#               ('Her', 'sent_18'),
#               ('skin', 'sent_18'),
#               ('care', 'sent_18'),
#               ('requirements', 'sent_18'),
#               ('decreased', 'sent_18'),
#               ('to', 'sent_18'),
#               ('at', 'sent_19'),
#               ('the', 'sent_19'),
#               ('time', 'sent_19'),
#               ('of', 'sent_19'),
#               ('discharge', 'sent_19'),
#               ('.', 'sent_19'),
#               ('She', 'sent_19'),
#               ('was', 'sent_19'),
#               ('able', 'sent_19'),
#               ('to.', 'sent_19'),
#               ('take', 'sent_19'),
#               ('in', 'sent_19'),
#               ('oral', 'sent_19'),
#               ('foot', 'sent_19'),
#               ('without', 'sent_19'),
#               ('problems', 'sent_19'),
#               ('..', 'sent_19'),
#               ('Ophthalmology', 'sent_19'),
#               (':', 'sent_19'),
#               ('The', 'sent_19'),
#               ("patient's", 'sent_19'),
#               ('eye', 'sent_19'),
#               ('care', 'sent_19'),
#               ('requirement', 'sent_19'),
#               ('improved.', 'sent_19'),
#               ('markedly', 'sent_19'),
#               ('.', 'sent_19'),
#               ('She', 'sent_19'),
#               ('was', 'sent_19'),
#               ('able', 'sent_19'),
#               ('to', 'sent_19'),
#               ('open', 'sent_19'),
#               ('her', 'sent_19'),
#               ('eyes', 'sent_19'),
#               ('and', 'sent_19'),
#               ('use', 'sent_19'),
#               ('vision.', 'sent_19'),
#               ('without', 'sent_19'),
#               ('significant', 'sent_19'),
#               ('problems', 'sent_19'),
#               ('the', 'sent_19'),
#               ('time', 'sent_19'),
#               ('of', 'sent_19'),
#               ('discharge', 'sent_19'),
#               ('Her.', 'sent_19'),
#               ('was', 'sent_20'),
#               ('discontinued', 'sent_20'),
#               ('on', 'sent_20'),
#               ('day', 'sent_20'),
#               ('discharge', 'sent_20'),
#               (',', 'sent_20'),
#               ('and', 'sent_20'),
#               ('she.', 'sent_20'),
#               ('is', 'sent_20'),
#               ('to', 'sent_20'),
#               ('have', 'sent_20'),
#               ('follow', 'sent_20'),
#               ('-', 'sent_20'),
#               ('up', 'sent_20'),
#               ('with', 'sent_20'),
#               ('Ophthalmology', 'sent_20'),
#               ('a', 'sent_20'),
#               ('couple', 'sent_20'),
#               ('days.', 'sent_20'),
#               ('after', 'sent_20'),
#               ('discharge', 'sent_20'),
#               ('..', 'sent_20'),
#               ('Fluid', 'sent_20'),
#               (',', 'sent_20'),
#               ('electrolytes', 'sent_20'),
#               (',', 'sent_20'),
#               ('and', 'sent_20'),
#               ('nutrition', 'sent_20'),
#               (':', 'sent_20'),
#               ('On', 'sent_20'),
#               ('admission', 'sent_20'),
#               ('the', 'sent_20'),
#               ('patient.', 'sent_20'),
#               ('was', 'sent_20'),
#               ('begun', 'sent_20'),
#               ('on', 'sent_20'),
#               ('nutritional', 'sent_20'),
#               ('support', 'sent_20'),
#               ('.', 'sent_20'),
#               ('As', 'sent_20'),
#               ('the', 'sent_20'),
#               ('patient.', 'sent_20'),
#               ('a', 'sent_21'),
#               ('perspective', 'sent_21'),
#               (',', 'sent_21'),
#               ('her', 'sent_21'),
#               ('TPN', 'sent_21'),
#               ('was', 'sent_21'),
#               ('weaned', 'sent_21'),
#               (',', 'sent_21'),
#               ('and.', 'sent_21'),
#               ('at', 'sent_21'),
#               ('the', 'sent_21'),
#               ('time', 'sent_21'),
#               ('of', 'sent_21'),
#               ('discharge', 'sent_21'),
#               (',', 'sent_21'),
#               ('the', 'sent_21'),
#               ('patient', 'sent_21'),
#               ('was', 'sent_21'),
#               ('taking', 'sent_21'),
#               ('adequate.', 'sent_21'),
#               ('p.o', 'sent_21'),
#               ('.', 'sent_21'),
#               ('with', 'sent_21'),
#               ('supplementation', 'sent_21'),
#               ('of', 'sent_21'),
#               ('..', 'sent_21'),
#               (':', 'sent_21'),
#               ('At', 'sent_21'),
#               ('the', 'sent_21'),
#               ('time', 'sent_21'),
#               ('of', 'sent_21'),
#               ('admission', 'sent_21'),
#               (',', 'sent_21'),
#               ('she', 'sent_21'),
#               ('was.', 'sent_21'),
#               ('started', 'sent_21'),
#               ('on', 'sent_21'),
#               ('empiric', 'sent_21'),
#               ('and', 'sent_21'),
#               ('placed', 'sent_21'),
#               ('on', 'sent_21'),
#               ('contact.', 'sent_21'),
#               ('precautions', 'sent_22'),
#               ('secondary', 'sent_22'),
#               ...],
#              'B-Drug': [('Lipitor', 'sent_3'),
#               ('Decadron', 'sent_4'),
#               ('Pred', 'sent_10'),
#               ('Neurontin', 'sent_133'),
#               ('Dacogen', 'sent_222'),
#               ('insulin', 'sent_280'),
#               ('lorazepam.', 'sent_347'),
#               ('oxycodone', 'sent_459'),
#               ('Furosemide', 'sent_467'),
#               ('antibiotic', 'sent_529'),
#               ('o2.', 'sent_605'),
#               ('methadone', 'sent_615'),
#               ('Cyanocobalamin', 'sent_620'),
#               ('steroids', 'sent_953'),
#               ('meropenem', 'sent_956'),
#               ('voriconazole', 'sent_956'),
#               ('FFP', 'sent_1001'),
#               ('Erythropoietin', 'sent_1118'),
#               ('Senna', 'sent_1124'),
#               ('anticoagulation', 'sent_1145'),
#               ('ativan', 'sent_1169'),
#               ('aspirin', 'sent_1235'),
#               ('Seroquel', 'sent_1285'),
#               ('hydralazine', 'sent_1349'),
#               ('hydralazine', 'sent_1351'),
#               ('NS', 'sent_1468'),
#               ('metronidazole.', 'sent_1468'),
#               ('GENTAMICIN', 'sent_1601'),
#               ('LEVOFLOXACIN', 'sent_1602'),
#               ('OXACILLIN', 'sent_1602'),
#               ('RIFAMPIN', 'sent_1602'),
#               ('insulin.', 'sent_1625'),
#               ('metoprolol', 'sent_1646'),
#               ('heparin', 'sent_1654'),
#               ('coumadin.', 'sent_1676'),
#               ('IPRATROPIUM', 'sent_1773'),
#               ('Detrol', 'sent_1800'),
#               ('vanco', 'sent_1908'),
#               ('penicillins', 'sent_2018'),
#               ('cephalosporins', 'sent_2018'),
#               ('Fentanyl', 'sent_2055'),
#               ('FFPs', 'sent_2071'),
#               ('metoprolol', 'sent_2226'),
#               ('Aspirin', 'sent_2282'),
#               ('Imuran.', 'sent_2297'),
#               ('Norepi.', 'sent_2301'),
#               ('BP', 'sent_2393'),
#               ('diuretics', 'sent_2453'),
#               ('Atrovent.', 'sent_2580'),
#               ('cefazolin', 'sent_2648'),
#               ('Heparin', 'sent_2665'),
#               ('lorazepam', 'sent_2708'),
#               ('Dexamethasone', 'sent_2760'),
#               ('antibiotics', 'sent_2821'),
#               ('azithromycin', 'sent_2843'),
#               ('prednisone', 'sent_2843'),
#               ('beta', 'sent_2884'),
#               ('statin', 'sent_2884'),
#               ('anti', 'sent_3006'),
#               ('enoxaparin', 'sent_3016'),
#               ('famotidine', 'sent_3041'),
#               ('diltiazem', 'sent_3100'),
#               ('Torsemide', 'sent_3133'),
#               ('cefepime', 'sent_3164'),
#               ('broad', 'sent_3191'),
#               ('Bactrim', 'sent_3196'),
#               ('tacrolimus', 'sent_3214'),
#               ('Methylphenidate', 'sent_3284'),
#               ('Heparin', 'sent_3329'),
#               ('cefepime', 'sent_3526'),
#               ('vancomycin', 'sent_3590'),
#               ('Serax', 'sent_3593'),
#               ('Zoloft', 'sent_3603'),
#               ('Carvedilol', 'sent_3652'),
#               ('Meropenem', 'sent_3656'),
#               ('Ativan', 'sent_3670'),
#               ('Coumadin', 'sent_3690'),
#               ('vitamin', 'sent_3691'),
#               ("RBC's", 'sent_3895'),
#               ('Clonazepam', 'sent_4013'),
#               ('Potassium', 'sent_4067'),
#               ('Albuterol', 'sent_4070'),
#               ('benzodiazepine', 'sent_4119'),
#               ('Docusate', 'sent_4129'),
#               ('Flagyl', 'sent_4152'),
#               ('unasyn', 'sent_4340'),
#               ('Levaquin', 'sent_4372'),
#               ('Quetiapin', 'sent_4609'),
#               ('coumadin.', 'sent_4630'),
#               ('coumadin', 'sent_4658'),
#               ('zosyn', 'sent_4677'),
#               ('meropenem', 'sent_4706'),
#               ('statin', 'sent_4812'),
#               ('levetiracetam', 'sent_4890'),
#               ('Gelclair', 'sent_5091'),
#               ('Lorazepa', 'sent_5096'),
#               ('Senna', 'sent_5102'),
#               ('megace.', 'sent_5299'),
#               ('vancomycin', 'sent_5323'),
#               ('lipase', 'sent_5448'),
#               ('Warfarin', 'sent_5501'),
#               ('Meropenem', 'sent_5536'),
#               ('lovenox.', 'sent_5825'),
#               ('Citalopram', 'sent_5827'),
#               ('steroids', 'sent_5863'),
#               ('benadryl', 'sent_5863'),
#               ('heparin', 'sent_5956'),
#               ('heparin.', 'sent_5956'),
#               ('Simvastati', 'sent_5968'),
#               ('beta', 'sent_6023'),
#               ('Warfarin', 'sent_6038'),
#               ('Metoprolol', 'sent_6039'),
#               ('Cefepime', 'sent_6042'),
#               ('fluid', 'sent_6099'),
#               ('Dilaudid', 'sent_6148'),
#               ('Fioricet', 'sent_6149'),
#               ('Valium', 'sent_6149'),
#               ('acetaminophen', 'sent_6154'),
#               ('Warfarin', 'sent_6194'),
#               ('Ativan', 'sent_6254'),
#               ('benadryl', 'sent_6290'),
#               ('DMS', 'sent_6617'),
#               ('thiamine', 'sent_6731'),
#               ('abx.', 'sent_6733'),
#               ('HCTZ', 'sent_6803'),
#               ('metoprolol', 'sent_6854'),
#               ('Amiodarone', 'sent_6859'),
#               ('Ca++/Vit', 'sent_6860'),
#               ('Aldactone', 'sent_6955'),
#               ('diltiazem', 'sent_7115'),
#               ('flonase', 'sent_7170'),
#               ('lasix', 'sent_7241'),
#               ('Prednisone', 'sent_7244'),
#               ('Calcium', 'sent_7245'),
#               ('levofloxacin', 'sent_7298'),
#               ('Ativan', 'sent_7493'),
#               ('ipratroprium', 'sent_7494'),
#               ('vitamin', 'sent_7503'),
#               ('Carboplatin', 'sent_7545'),
#               ('broad', 'sent_7695'),
#               ('barium', 'sent_7730'),
#               ('amlodipine', 'sent_7757'),
#               ('Diuril', 'sent_7759'),
#               ('ffp', 'sent_7815'),
#               ('normal', 'sent_7815'),
#               ('blood', 'sent_7824'),
#               ('benzo', 'sent_7848'),
#               ('benedryl', 'sent_7890'),
#               ('hydralazine', 'sent_7941'),
#               ('Flomax', 'sent_7974'),
#               ('Coumadin', 'sent_7977'),
#               ('Atorvastatin', 'sent_8101'),
#               ('aspiri', 'sent_8154'),
#               ('Nifedipine', 'sent_8326'),
#               ('Fentanyl.', 'sent_8345'),
#               ('flumazenil', 'sent_8346'),
#               ('anticoagulation', 'sent_8375'),
#               ('colace', 'sent_8407'),
#               ('Metformin', 'sent_8440'),
#               ('Glipizide', 'sent_8454'),
#               ('statin.', 'sent_8463'),
#               ('propofol', 'sent_8482'),
#               ('Fluconazole', 'sent_8531'),
#               ('Cefpodoxime', 'sent_8591'),
#               ('nitro', 'sent_8623'),
#               ('Paroxetine', 'sent_8670'),
#               ('Flagyl', 'sent_8715'),
#               ('Labetalol', 'sent_8768'),
#               ('heparin.', 'sent_8809'),
#               ('Benadryl', 'sent_8810'),
#               ('abx', 'sent_8862'),
#               ('NG', 'sent_8864'),
#               ('morphine', 'sent_9055'),
#               ('Isoniazid', 'sent_9142'),
#               ('Omeprazole.', 'sent_9217'),
#               ('heparin', 'sent_9252'),
#               ('coumadin', 'sent_9346'),
#               ('Multivitamin', 'sent_9356'),
#               ('Zosyn', 'sent_9404'),
#               ('Protonix', 'sent_9453'),
#               ('Cepacol', 'sent_9454'),
#               ('ibuprofen', 'sent_9633'),
#               ('PRBCs', 'sent_9657'),
#               ('Isosorbide', 'sent_9754'),
#               ('plavix', 'sent_9805'),
#               ('anticoagulation', 'sent_9806'),
#               ('vincristine', 'sent_9908'),
#               ('Clofarabine', 'sent_9909'),
#               ('cytoxan', 'sent_9917'),
#               ('blood', 'sent_10019'),
#               ('synthroid', 'sent_10034'),
#               ('levothyroxine', 'sent_10034'),
#               ('Atenolol', 'sent_10180'),
#               ('levofloxacin', 'sent_10217'),
#               ('ciprofloxacin', 'sent_10217'),
#               ('OXYCODONE', 'sent_10420'),
#               ('Ranitidine', 'sent_10429'),
#               ('HEPATITIS', 'sent_10631'),
#               ('Aspirin', 'sent_10745'),
#               ('Colace', 'sent_10762'),
#               ('Bactrim', 'sent_10886'),
#               ('HCTZ', 'sent_10889'),
#               ('metoclopramide', 'sent_10901'),
#               ('stool', 'sent_10918'),
#               ('Meropenem', 'sent_10977'),
#               ('Pramipexole', 'sent_11036')],
#              'I-Drug': [('Forte.', 'sent_10'),
#               ('porcine', 'sent_1292'),
#               (')', 'sent_1292'),
#               ('Bromide', 'sent_2660'),
#               ('s', 'sent_3573'),
#               ('Chloride', 'sent_4067'),
#               ('Sodium', 'sent_4129'),
#               ('m', 'sent_5096'),
#               ('-', 'sent_5448'),
#               (')', 'sent_7653'),
#               ('pressure', 'sent_10019'),
#               ('HCl', 'sent_10429'),
#               ('CARBONATE', 'sent_10633'),
#               ('-', 'sent_10633')],
#              'B-Strength': [('40', 'sent_228'),
#               ('20mg', 'sent_347'),
#               ('500', 'sent_620'),
#               ('500mg', 'sent_1568'),
#               ('1000', 'sent_1655'),
#               ('81', 'sent_2282'),
#               ('0.5', 'sent_3085'),
#               ('60', 'sent_3468'),
#               ('1', 'sent_3573'),
#               ('8mEQ', 'sent_4067'),
#               ('100', 'sent_4129'),
#               ('1.5mg.', 'sent_4344'),
#               ('40', 'sent_4842'),
#               ('250', 'sent_4890'),
#               ('0.5', 'sent_5096'),
#               ('1000mg', 'sent_5536'),
#               ('2mg', 'sent_6149'),
#               ('10mg', 'sent_6149'),
#               ('0.5', 'sent_6254'),
#               ('2mg', 'sent_7493'),
#               ('200', 'sent_7967'),
#               ('10', 'sent_8101'),
#               ('90', 'sent_8101'),
#               ('60', 'sent_8326'),
#               ('0.5mg', 'sent_8346'),
#               ('145mg', 'sent_8443'),
#               ('100', 'sent_8591'),
#               ('40', 'sent_8671'),
#               ('200', 'sent_8768'),
#               ('600', 'sent_9003'),
#               ('300', 'sent_9198'),
#               ('0.9', 'sent_9364'),
#               ('81', 'sent_9660'),
#               ('40mg', 'sent_9829'),
#               ('25', 'sent_10180'),
#               ('100', 'sent_10185'),
#               ('250', 'sent_10631'),
#               ('75', 'sent_10744'),
#               ('325', 'sent_10745')],
#              'I-Strength': [('mg', 'sent_228'),
#               ('mg', 'sent_568'),
#               ('Units/mL', 'sent_1655'),
#               ('mg', 'sent_2771'),
#               ('mg', 'sent_3085'),
#               ('mg', 'sent_3330'),
#               ('mg', 'sent_3573'),
#               ('mg', 'sent_3668'),
#               ('/3', 'sent_3668'),
#               ('mg', 'sent_4129'),
#               ('mg', 'sent_4652'),
#               ('mg', 'sent_4842'),
#               ('mg', 'sent_4890'),
#               ('mg', 'sent_5096'),
#               ('mg', 'sent_5213'),
#               ('mL', 'sent_5836'),
#               ('mg', 'sent_6254'),
#               ('%', 'sent_6806'),
#               ('mg', 'sent_7967'),
#               ('unit', 'sent_8040'),
#               ('/100', 'sent_8043'),
#               ('mcg/Dose', 'sent_8099'),
#               ('mg', 'sent_8101'),
#               ('mcg/Actuation', 'sent_8101'),
#               ('mg', 'sent_8326'),
#               ('mg', 'sent_8591'),
#               ('mg', 'sent_8671'),
#               (')', 'sent_9366'),
#               ('mg', 'sent_10180'),
#               ('mg', 'sent_10185'),
#               ('mg', 'sent_10631'),
#               ('mg', 'sent_10744'),
#               ('mg', 'sent_10745')],
#              'B-Form': [('Capsule', 'sent_228'),
#               ('Tablet', 'sent_763'),
#               ('Tablet', 'sent_1940'),
#               ('Tablet', 'sent_1941'),
#               ('Tablet', 'sent_2283'),
#               ('Tablet', 'sent_2537'),
#               ('Tablet', 'sent_2537'),
#               ('Capsule', 'sent_2659'),
#               ('Capsule', 'sent_2659'),
#               ('Tablet', 'sent_3047'),
#               ('Tablet', 'sent_3085'),
#               ('Tablet', 'sent_3085'),
#               ('Capsule', 'sent_3331'),
#               ('Solution', 'sent_3668'),
#               ('Tablet', 'sent_4432'),
#               ('Tablet', 'sent_4890'),
#               ('Syrup', 'sent_4890'),
#               ('Tablet', 'sent_5096'),
#               ('Syringe', 'sent_5836'),
#               ('injection.', 'sent_5836'),
#               ('Tablet', 'sent_6296'),
#               ('Tablets', 'sent_6297'),
#               ('Tablet', 'sent_7588'),
#               ('Tablet', 'sent_8536'),
#               ('Cap', 'sent_9125'),
#               ('Tablet', 'sent_9453'),
#               ('ML', 'sent_9453'),
#               ('Tablet', 'sent_9619'),
#               ('Tablet', 'sent_9832'),
#               ('Tablet', 'sent_9834'),
#               ('Capsule', 'sent_10185'),
#               ('Capsule', 'sent_10185')],
#              'B-Reason': [('coughing', 'sent_270'),
#               ('headache', 'sent_458'),
#               ('PEs', 'sent_4183'),
#               ('Metastatic', 'sent_5106'),
#               ('acute', 'sent_5711'),
#               ('abdominal', 'sent_6296'),
#               ('hepatorenal', 'sent_6958'),
#               ('acute', 'sent_7890'),
#               ('constipation', 'sent_8536'),
#               ('cough.', 'sent_10419'),
#               ('aspiration', 'sent_10845')],
#              'I-Reason': [('up', 'sent_270'),
#               ('overload', 'sent_1434'),
#               ('IMPOSED', 'sent_3136'),
#               ('CELLULITIS', 'sent_3136'),
#               ('fibrillation.', 'sent_5299'),
#               ('benign', 'sent_5826'),
#               ('hip', 'sent_7323'),
#               ('cultures', 'sent_7534'),
#               ('which.', 'sent_7534'),
#               ('had', 'sent_7534'),
#               ('gram', 'sent_7534'),
#               ('-', 'sent_7534'),
#               ('clotting', 'sent_10147'),
#               ('drain', 'sent_10666'),
#               ('pneumonia', 'sent_10845')],
#              'I-Dosage': [('(', 'sent_323'),
#               ('2', 'sent_323'),
#               ('(', 'sent_473'),
#               ('(', 'sent_1232'),
#               ('1', 'sent_1551'),
#               (')', 'sent_1551'),
#               ('(', 'sent_2353'),
#               ('(', 'sent_2659'),
#               ('1', 'sent_2659'),
#               (')', 'sent_2659'),
#               ('(', 'sent_2660'),
#               ('(', 'sent_2771'),
#               ('6', 'sent_2771'),
#               (')', 'sent_3085'),
#               ('(', 'sent_3085'),
#               ('1', 'sent_3085'),
#               (')', 'sent_3085'),
#               (')', 'sent_3331'),
#               ('ML', 'sent_3331'),
#               (')', 'sent_3335'),
#               (')', 'sent_3573'),
#               ('ml', 'sent_3905'),
#               (')', 'sent_3907'),
#               (')', 'sent_3907'),
#               ('1', 'sent_3908'),
#               (')', 'sent_3908'),
#               ('(', 'sent_4132'),
#               (')', 'sent_4361'),
#               ('-', 'sent_5096'),
#               ('2', 'sent_5096'),
#               (').', 'sent_5097'),
#               ('ML', 'sent_5097'),
#               ('(', 'sent_5836'),
#               ('1', 'sent_5836'),
#               (')', 'sent_5836'),
#               ('2', 'sent_6154'),
#               (')', 'sent_6154'),
#               ('(', 'sent_6296'),
#               ('1', 'sent_6296'),
#               (')', 'sent_6296'),
#               (')', 'sent_6490'),
#               (')', 'sent_6806'),
#               ('1', 'sent_6811'),
#               (')', 'sent_6811'),
#               ('(', 'sent_8040'),
#               ('1', 'sent_8040'),
#               ('(', 'sent_9453'),
#               ('1', 'sent_9453'),
#               (').', 'sent_9453'),
#               ('(', 'sent_10184'),
#               ('1', 'sent_10184'),
#               ('(', 'sent_10185'),
#               ('1', 'sent_10185'),
#               (')', 'sent_10185'),
#               ('units', 'sent_10255'),
#               ('3', 'sent_10853'),
#               (')', 'sent_10853')],
#              'B-Route': [('IV', 'sent_347'),
#               ('PO', 'sent_716'),
#               ('PO', 'sent_1033'),
#               ('INH', 'sent_1773'),
#               ('PO', 'sent_2659'),
#               ('PO', 'sent_2764'),
#               ('PO', 'sent_2765'),
#               ('PO', 'sent_2765'),
#               ('PO', 'sent_3085'),
#               ('IV', 'sent_3540'),
#               ('IV', 'sent_4022'),
#               ('gtt', 'sent_4183'),
#               ('PO.', 'sent_5500'),
#               ('Subcutaneous', 'sent_5836'),
#               ('drip', 'sent_8050'),
#               ('PO', 'sent_8153'),
#               ('PO', 'sent_8326'),
#               ('PO', 'sent_8329'),
#               ('nasogastric', 'sent_9621'),
#               ('intravenous', 'sent_9728'),
#               ('PO', 'sent_10180'),
#               ('PO', 'sent_10185'),
#               ('PO', 'sent_10640')],
#              'I-Frequency': [(':', 'sent_385'),
#               ('PRN', 'sent_385'),
#               ('(', 'sent_716'),
#               ('Daily', 'sent_716'),
#               (')', 'sent_716'),
#               ('6', 'sent_766'),
#               ('a', 'sent_837'),
#               ('(', 'sent_967'),
#               ('every', 'sent_967'),
#               ('as', 'sent_972'),
#               ('needed', 'sent_972'),
#               ('needed', 'sent_1291'),
#               ('at', 'sent_1551'),
#               ('4.', 'sent_1551'),
#               ('2.', 'sent_1937'),
#               ('times', 'sent_1938'),
#               ('a', 'sent_1938'),
#               ('(', 'sent_2541'),
#               ('4', 'sent_2541'),
#               ('times', 'sent_2541'),
#               ('a', 'sent_2541'),
#               ('day', 'sent_2541'),
#               (')', 'sent_2541'),
#               ('as', 'sent_2541'),
#               ('four.', 'sent_2659'),
#               ('(', 'sent_2660'),
#               ('4', 'sent_2660'),
#               ('(', 'sent_2660'),
#               ('3', 'sent_2660'),
#               ('times', 'sent_2660'),
#               ('a', 'sent_2660'),
#               ('day', 'sent_2660'),
#               ('a', 'sent_2771'),
#               ('eight', 'sent_2771'),
#               ('a', 'sent_3277'),
#               ('day', 'sent_3277'),
#               ('needed', 'sent_3330'),
#               ('day', 'sent_3331'),
#               (')', 'sent_3331'),
#               ('8', 'sent_3332'),
#               ('hours', 'sent_3332'),
#               (')', 'sent_3332'),
#               ('as', 'sent_3332'),
#               (')', 'sent_3336'),
#               (')', 'sent_3396'),
#               ('as', 'sent_3396'),
#               ('needed', 'sent_3396'),
#               ('(', 'sent_3473'),
#               ('(', 'sent_3474'),
#               ('Daily', 'sent_3474'),
#               ('needed', 'sent_3550'),
#               ('(', 'sent_3573'),
#               ('day', 'sent_3573'),
#               ('day', 'sent_3908'),
#               ('month', 'sent_3908'),
#               ('(', 'sent_4193'),
#               ('at.', 'sent_4193'),
#               ('bedtime', 'sent_4193'),
#               (')', 'sent_4193'),
#               ('(', 'sent_4608'),
#               ('Daily', 'sent_4608'),
#               (')', 'sent_4608'),
#               ('as', 'sent_4608'),
#               ('needed', 'sent_4608'),
#               ('(', 'sent_4819'),
#               ('Daily', 'sent_4819'),
#               (')', 'sent_4819'),
#               ('a', 'sent_4957'),
#               ('day', 'sent_4957'),
#               ('(', 'sent_4958'),
#               ('2.', 'sent_4958'),
#               ('times', 'sent_4958'),
#               ('a', 'sent_4958'),
#               ('day', 'sent_4958'),
#               ('every', 'sent_5096'),
#               ('4.', 'sent_5096'),
#               ('hours', 'sent_5096'),
#               (')', 'sent_5096'),
#               ('as', 'sent_5096'),
#               ('needed', 'sent_5096'),
#               ('(', 'sent_5097'),
#               ('4', 'sent_5097'),
#               ('times', 'sent_5097'),
#               ('a', 'sent_5097'),
#               ('day', 'sent_5097'),
#               ('3', 'sent_5097'),
#               ('times', 'sent_5097'),
#               ('a', 'sent_5097'),
#               ('day', 'sent_5097'),
#               (')', 'sent_5097'),
#               ('in', 'sent_5333'),
#               ('every', 'sent_5500'),
#               ('4', 'sent_5500'),
#               ('3', 'sent_5622'),
#               ('times', 'sent_5622'),
#               ('HR', 'sent_5836'),
#               ('day', 'sent_6152'),
#               (')', 'sent_6152'),
#               ('(', 'sent_6153'),
#               ('every.', 'sent_6154'),
#               ('6', 'sent_6154'),
#               ('hours', 'sent_6154'),
#               ('bedtime', 'sent_6296'),
#               (').', 'sent_6296'),
#               ('as', 'sent_6297'),
#               ('needed', 'sent_6297'),
#               ('day', 'sent_6297'),
#               (')', 'sent_6297'),
#               ('as', 'sent_6297'),
#               ('needed', 'sent_6297'),
#               ('hours', 'sent_6629'),
#               (')', 'sent_6629'),
#               ('day', 'sent_6811'),
#               ('4.', 'sent_7880'),
#               ('hours', 'sent_7880'),
#               ('prn', 'sent_7890'),
#               ('as', 'sent_7890'),
#               ('needed', 'sent_7890'),
#               ('(', 'sent_8040'),
#               ('Monday', 'sent_8040'),
#               ('prn.', 'sent_9827'),
#               ('prn.', 'sent_9827'),
#               ('days', 'sent_9829'),
#               ('day', 'sent_9831'),
#               (')', 'sent_9831'),
#               ('day', 'sent_9833'),
#               (')', 'sent_10089'),
#               ('(', 'sent_10184'),
#               ('every.', 'sent_10184'),
#               ('(', 'sent_10185'),
#               ('2.', 'sent_10185'),
#               ('every', 'sent_10368'),
#               ('6', 'sent_10368'),
#               ('hours', 'sent_10368'),
#               ('three', 'sent_10411'),
#               ('days.', 'sent_10411'),
#               ('thereafter', 'sent_10411'),
#               ('..', 'sent_10411'),
#               ('3', 'sent_10495'),
#               (')', 'sent_10495'),
#               (')', 'sent_10750'),
#               ('as', 'sent_10750'),
#               ('needed', 'sent_10750'),
#               ('Daily', 'sent_10811')],
#              'I-Form': [('(', 'sent_569'),
#               ('s', 'sent_569'),
#               (')', 'sent_569'),
#               ('Delayed', 'sent_649'),
#               ('Release', 'sent_649'),
#               ('(', 'sent_649'),
#               ('E.C.', 'sent_649'),
#               (')', 'sent_649'),
#               ('(', 'sent_649'),
#               ('for.', 'sent_3668'),
#               ('Nebulization', 'sent_3668'),
#               ('(', 'sent_5103'),
#               ('E.C.', 'sent_5103'),
#               (')', 'sent_5103'),
#               (',', 'sent_6194'),
#               ('Rapid', 'sent_6194'),
#               ('Dissolve', 'sent_6194'),
#               (',', 'sent_6194'),
#               ('DR', 'sent_6194'),
#               ('DR', 'sent_8591'),
#               ('(', 'sent_9200')],
#              'B-Frequency': [('DAILY', 'sent_716'),
#               ('qd', 'sent_758'),
#               ('once', 'sent_837'),
#               ('tid', 'sent_902'),
#               ('every', 'sent_2659'),
#               ('PRN', 'sent_2664'),
#               ('q8.', 'sent_2764'),
#               ('BID', 'sent_2765'),
#               ('Q8H', 'sent_2833'),
#               ('QHS', 'sent_3085'),
#               ('daily.', 'sent_3394'),
#               ('Q6H', 'sent_3473'),
#               ('daily.', 'sent_3502'),
#               ('DAILY', 'sent_4819'),
#               ('Q12', 'sent_5836'),
#               ('daily', 'sent_6201'),
#               ('TID', 'sent_6854'),
#               ('q6H', 'sent_7890'),
#               ('QMOWEFR', 'sent_8040'),
#               ('HS.', 'sent_8153'),
#               ('QAM.', 'sent_8247'),
#               ('tid.', 'sent_8327'),
#               ('DAILY', 'sent_8329'),
#               ('DAILY.', 'sent_10180'),
#               ('BID', 'sent_10185'),
#               ('once', 'sent_10640'),
#               ('twice', 'sent_10762'),
#               ('30min', 'sent_10894')],
#              'B-Dosage': [('One', 'sent_2659'),
#               ('One', 'sent_3085'),
#               ('6', 'sent_3905'),
#               ('One', 'sent_4204'),
#               ('Three', 'sent_4890'),
#               ('1', 'sent_5096'),
#               ('One', 'sent_5836'),
#               ('One', 'sent_6039'),
#               ('One', 'sent_6296'),
#               ('0.5', 'sent_7834'),
#               ('1.5', 'sent_7884'),
#               ('One', 'sent_9453'),
#               ('three', 'sent_9697'),
#               ('One', 'sent_9867'),
#               ('One', 'sent_10185'),
#               ('x1', 'sent_10385')],
#              'I-Duration': [('days', 'sent_3041')]})

# %%
# # Example: Print correctly classified words for each label
# for label, word_id_pairs in correctly_classified_words_with_ids.items():
#     print(f"Label: {label}")
#     word_counts = defaultdict(int)
#     for word, sentence_id in word_id_pairs:
#         word_counts[word] += 1  # Count occurrences of each word

#     # Sort words by their frequency
#     sorted_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

#     for word, count in sorted_words[:5]:  # Adjust number as needed
#         print(f"  Word: '{word}' appeared {count} times correctly")
#     print("\n")

# %%
# Assuming correctly_classified_words_with_ids is already populated from the previous step

# Example: Print correctly classified words for each label, including sentence IDs
for label, word_id_pairs in correctly_classified_words_with_ids.items():
    print(f"Label: {label}")

    # Instead of just counting words, store sentence IDs where they appear
    word_sentence_ids = defaultdict(list)
    for word, sentence_id in word_id_pairs:
        word_sentence_ids[word].append(sentence_id)  # Append sentence ID for each word

    # Sort words by their frequency (number of sentence IDs)
    sorted_words = sorted(word_sentence_ids.items(), key=lambda x: len(x[1]), reverse=True)

    for word, sentence_ids in sorted_words[:5]:  # Adjust number as needed
        unique_sentence_ids = set(sentence_ids)  # Remove potential duplicates
        print(f"  Word: '{word}' appeared in sentences: {', '.join(unique_sentence_ids)}")
    print("\n")
# Out:
# Label: O
#   Word: '*' appeared in sentences: sent_8068, sent_1136, sent_1767, sent_10433, sent_2741, sent_4879, sent_260, sent_8211, sent_2587, sent_5733, sent_8141, sent_3483, sent_440, sent_5325, sent_9961, sent_546, sent_8708, sent_9304, sent_8278, sent_8031, sent_9486, sent_10202, sent_4622, sent_1964, sent_7914, sent_3627, sent_6159, sent_8689, sent_3017, sent_2169, sent_2934, sent_7919, sent_10341, sent_5584, sent_5785, sent_8590, sent_5408, sent_10645, sent_7393, sent_4236, sent_3228, sent_2335, sent_10446, sent_7656, sent_3797, sent_795, sent_733, sent_7638, sent_2600, sent_2766, sent_787, sent_5747, sent_8858, sent_10535, sent_2964, sent_2507, sent_2295, sent_7516, sent_4922, sent_9218, sent_1955, sent_7538, sent_5378, sent_4577, sent_6883, sent_8403, sent_2051, sent_2034, sent_8526, sent_3783, sent_8282, sent_1433, sent_4663, sent_10164, sent_5075, sent_2364, sent_5958, sent_6300, sent_9463, sent_2445, sent_1574, sent_11018, sent_5315, sent_10455, sent_1583, sent_9434, sent_5765, sent_6161, sent_4704, sent_1895, sent_3286, sent_5830, sent_6451, sent_4882, sent_668, sent_5679, sent_2033, sent_10016, sent_2131, sent_5624, sent_2202, sent_4305, sent_3687, sent_1592, sent_4940, sent_8961, sent_10465, sent_7576, sent_7990, sent_7460, sent_4636, sent_9799, sent_8221, sent_2618, sent_735, sent_5997, sent_6453, sent_5844, sent_8365, sent_8964, sent_10822, sent_4417, sent_3828, sent_4441, sent_5501, sent_7019, sent_4624, sent_7657, sent_7724, sent_8364, sent_5604, sent_3353, sent_1704, sent_6082, sent_8692, sent_523, sent_2346, sent_5379, sent_10163, sent_9312, sent_8200, sent_6465, sent_9401, sent_5531, sent_639, sent_5883, sent_495, sent_4367, sent_5318, sent_10931, sent_4151, sent_7587, sent_9540, sent_868, sent_7208, sent_2951, sent_8646, sent_1356, sent_5819, sent_9042, sent_9029, sent_7955, sent_2491, sent_3661, sent_7820, sent_5417, sent_4785, sent_2365, sent_4081, sent_2893, sent_3983, sent_8687, sent_7179, sent_6450, sent_6303, sent_9314, sent_4234, sent_5929, sent_10144, sent_6873, sent_4233, sent_6836, sent_8574, sent_3670, sent_249, sent_1557, sent_9513, sent_3944, sent_1144, sent_1103, sent_1455, sent_8080, sent_8593, sent_8779, sent_4486, sent_10865, sent_1159, sent_1989, sent_8296, sent_4557, sent_9598, sent_5896, sent_3154, sent_1928, sent_2794, sent_8569, sent_4290, sent_10272, sent_1057, sent_1253, sent_8649, sent_9230, sent_2504, sent_7420, sent_4767, sent_4222, sent_5738, sent_5849, sent_10203, sent_10747, sent_7873, sent_1954, sent_10226, sent_2342, sent_4228, sent_3833, sent_2795, sent_5242, sent_286, sent_7481, sent_7627, sent_6229, sent_8417, sent_4477, sent_8937, sent_1827, sent_1578, sent_4998, sent_6998, sent_1169, sent_4128, sent_5700, sent_7234, sent_5017, sent_4098, sent_1560, sent_4169, sent_10228, sent_5165, sent_2684, sent_60, sent_3429, sent_5770, sent_7936, sent_2811, sent_299, sent_4041, sent_10275, sent_9705, sent_461, sent_1293, sent_2961, sent_9227, sent_3613, sent_9643, sent_2729, sent_4171, sent_1182, sent_376, sent_6178, sent_1963, sent_1871, sent_6356, sent_6278, sent_400, sent_1584, sent_6381, sent_10555, sent_1192, sent_8075, sent_95, sent_3556, sent_7850, sent_8004, sent_7358, sent_9974, sent_6068, sent_3146, sent_1422, sent_6131, sent_10754, sent_7299, sent_3290, sent_6939, sent_9006, sent_7151, sent_974, sent_6213, sent_2076, sent_8086, sent_7004, sent_9826, sent_2039, sent_3799, sent_9937, sent_8255, sent_6520, sent_9331, sent_5661, sent_8773, sent_794, sent_5673, sent_90, sent_3882, sent_625, sent_4583, sent_5774, sent_1919, sent_9887, sent_1488, sent_6759, sent_3543, sent_69, sent_1579, sent_8560, sent_2038, sent_3229, sent_4860, sent_9293, sent_1134, sent_10222, sent_7593, sent_4383, sent_1975, sent_4799, sent_5645, sent_932, sent_7588, sent_9846, sent_10996, sent_3636, sent_9175, sent_4847, sent_1958, sent_7699, sent_7920, sent_5105, sent_2615, sent_7646, sent_7134, sent_587, sent_7331, sent_5560, sent_9260, sent_566, sent_577, sent_9801, sent_702, sent_6497, sent_3906, sent_6631, se ...
#   Word: '-' appeared in sentences: sent_8068, sent_5656, sent_10433, sent_9329, sent_4879, sent_260, sent_2587, sent_2958, sent_3904, sent_5733, sent_1985, sent_8141, sent_440, sent_5325, sent_9961, sent_4124, sent_546, sent_8278, sent_9486, sent_1114, sent_3627, sent_6159, sent_8689, sent_2169, sent_2934, sent_1280, sent_7919, sent_4777, sent_10341, sent_5584, sent_5785, sent_4107, sent_5408, sent_6570, sent_10645, sent_3825, sent_4236, sent_3228, sent_2335, sent_1464, sent_10446, sent_7656, sent_3797, sent_795, sent_7638, sent_2600, sent_4397, sent_787, sent_5747, sent_8858, sent_585, sent_9897, sent_2507, sent_7516, sent_4922, sent_9218, sent_1955, sent_7538, sent_4577, sent_6883, sent_3030, sent_2051, sent_2034, sent_8731, sent_8526, sent_3783, sent_8282, sent_1433, sent_4663, sent_10164, sent_5075, sent_5958, sent_2445, sent_9597, sent_1574, sent_1770, sent_11018, sent_5315, sent_10455, sent_10952, sent_1583, sent_9434, sent_10821, sent_3739, sent_5765, sent_6161, sent_4704, sent_1895, sent_9547, sent_3286, sent_7233, sent_5830, sent_6451, sent_4882, sent_668, sent_5679, sent_2033, sent_10016, sent_10213, sent_3687, sent_1592, sent_4940, sent_8961, sent_10465, sent_7576, sent_7990, sent_10031, sent_7460, sent_4636, sent_2992, sent_9799, sent_3417, sent_8221, sent_2618, sent_5997, sent_6453, sent_10625, sent_8365, sent_8964, sent_4417, sent_7943, sent_8188, sent_3828, sent_4441, sent_5501, sent_7019, sent_4624, sent_4954, sent_7657, sent_7724, sent_6606, sent_8364, sent_5604, sent_1704, sent_6082, sent_2346, sent_10163, sent_2596, sent_8200, sent_6465, sent_9401, sent_8393, sent_639, sent_495, sent_4367, sent_5318, sent_10931, sent_10559, sent_4151, sent_7681, sent_868, sent_8008, sent_7208, sent_2951, sent_8646, sent_5819, sent_9042, sent_8642, sent_7955, sent_2491, sent_20, sent_7820, sent_5417, sent_4785, sent_4081, sent_4436, sent_3983, sent_8687, sent_7179, sent_3461, sent_6450, sent_9314, sent_4234, sent_5929, sent_6873, sent_4233, sent_6836, sent_8574, sent_3670, sent_249, sent_9513, sent_3944, sent_1144, sent_1455, sent_8080, sent_8593, sent_3481, sent_4486, sent_7042, sent_10865, sent_1159, sent_1989, sent_4557, sent_9598, sent_5896, sent_3154, sent_1928, sent_8569, sent_4290, sent_8048, sent_1018, sent_10272, sent_1253, sent_8649, sent_9230, sent_9063, sent_2504, sent_7420, sent_4767, sent_4222, sent_5527, sent_5738, sent_5849, sent_10437, sent_10203, sent_6817, sent_7873, sent_1954, sent_2342, sent_605, sent_4228, sent_286, sent_7481, sent_8781, sent_7627, sent_6229, sent_4477, sent_1827, sent_3489, sent_4998, sent_6998, sent_1169, sent_6518, sent_4128, sent_5700, sent_4098, sent_1803, sent_1560, sent_4402, sent_4169, sent_5165, sent_1393, sent_60, sent_10005, sent_3429, sent_5770, sent_271, sent_2811, sent_7936, sent_299, sent_4041, sent_10275, sent_8388, sent_8477, sent_9705, sent_461, sent_2961, sent_9227, sent_3613, sent_4161, sent_8090, sent_6669, sent_4171, sent_1182, sent_3877, sent_6178, sent_1963, sent_1871, sent_400, sent_11005, sent_7927, sent_10555, sent_1192, sent_8075, sent_7850, sent_8004, sent_10403, sent_9974, sent_3146, sent_1422, sent_6131, sent_7299, sent_3290, sent_6939, sent_9006, sent_10743, sent_7151, sent_2076, sent_8086, sent_7004, sent_2039, sent_3799, sent_4275, sent_9937, sent_8255, sent_9616, sent_6520, sent_9331, sent_5661, sent_5673, sent_3882, sent_7826, sent_4583, sent_5774, sent_1919, sent_9887, sent_1488, sent_69, sent_8560, sent_2038, sent_3761, sent_4860, sent_5463, sent_9293, sent_1134, sent_7593, sent_4383, sent_1975, sent_4799, sent_449, sent_5645, sent_8301, sent_7588, sent_9846, sent_6982, sent_1467, sent_10996, sent_3636, sent_9175, sent_4847, sent_1958, sent_2401, sent_7126, sent_7699, sent_7920, sent_2615, sent_7134, sent_7331, sent_8217, sent_5560, sent_9260, sent_577, sent_9801, sent_6236, sent_3906, sent_5876, sent_1111, sent_6318, sent_4473, sent_1367, sent_7370, sent_3431, sent_7956, sent_3633, sent_10381, sent_7779, sent_1797, sent_1196, sent_9281, sent_10232,  ...
#   Word: '.' appeared in sentences: sent_1767, sent_8346, sent_10433, sent_5297, sent_5791, sent_2741, sent_4879, sent_1996, sent_10848, sent_8211, sent_2587, sent_2143, sent_1985, sent_8141, sent_2222, sent_3483, sent_5325, sent_6893, sent_2836, sent_9491, sent_9961, sent_10675, sent_8729, sent_10961, sent_8884, sent_10283, sent_8031, sent_5959, sent_9486, sent_4622, sent_1114, sent_1964, sent_11024, sent_8982, sent_7688, sent_10298, sent_6159, sent_8689, sent_3017, sent_7221, sent_2994, sent_724, sent_5029, sent_1280, sent_8810, sent_4777, sent_8517, sent_10341, sent_6678, sent_5584, sent_5785, sent_8590, sent_9914, sent_4107, sent_2704, sent_6570, sent_10645, sent_3330, sent_9032, sent_7393, sent_3825, sent_6245, sent_673, sent_1464, sent_2335, sent_7604, sent_3004, sent_795, sent_733, sent_11035, sent_7638, sent_2600, sent_2766, sent_4397, sent_787, sent_4062, sent_8858, sent_585, sent_5571, sent_5925, sent_9897, sent_7874, sent_10524, sent_2601, sent_7538, sent_5378, sent_10256, sent_10400, sent_10216, sent_610, sent_5760, sent_6883, sent_8403, sent_2051, sent_8723, sent_1912, sent_8526, sent_5359, sent_314, sent_386, sent_1433, sent_1698, sent_4663, sent_5075, sent_8740, sent_2141, sent_5958, sent_6300, sent_8324, sent_9597, sent_1770, sent_7976, sent_5315, sent_139, sent_3757, sent_10952, sent_4455, sent_8666, sent_9434, sent_3488, sent_1115, sent_6934, sent_10821, sent_7639, sent_6894, sent_3739, sent_1650, sent_5765, sent_1895, sent_6728, sent_9, sent_4736, sent_5040, sent_9547, sent_383, sent_3619, sent_7233, sent_3005, sent_5224, sent_2200, sent_5830, sent_668, sent_5679, sent_2131, sent_7969, sent_1113, sent_5624, sent_465, sent_10213, sent_8096, sent_2202, sent_4305, sent_510, sent_3953, sent_6689, sent_9832, sent_3687, sent_879, sent_5336, sent_1195, sent_10465, sent_7576, sent_10031, sent_10122, sent_6675, sent_1213, sent_2933, sent_2992, sent_9799, sent_7815, sent_4039, sent_735, sent_10625, sent_10822, sent_4417, sent_8579, sent_1443, sent_7943, sent_8188, sent_3828, sent_7159, sent_5501, sent_4017, sent_8519, sent_837, sent_385, sent_7724, sent_3164, sent_6239, sent_6606, sent_6792, sent_5604, sent_3353, sent_1704, sent_2237, sent_9739, sent_2346, sent_528, sent_5316, sent_3529, sent_5379, sent_2596, sent_10163, sent_9312, sent_1696, sent_8200, sent_6465, sent_9401, sent_4620, sent_5883, sent_4367, sent_10931, sent_10559, sent_4151, sent_7587, sent_9540, sent_8008, sent_7208, sent_2951, sent_5049, sent_1356, sent_5819, sent_3084, sent_4558, sent_9042, sent_9029, sent_8642, sent_8784, sent_7955, sent_4874, sent_8179, sent_5565, sent_20, sent_1637, sent_8802, sent_7820, sent_10514, sent_2365, sent_7022, sent_2893, sent_3983, sent_9716, sent_7179, sent_3461, sent_1636, sent_1816, sent_6593, sent_897, sent_5929, sent_3040, sent_6873, sent_6836, sent_3670, sent_1557, sent_3944, sent_1144, sent_7525, sent_1103, sent_1455, sent_7601, sent_8593, sent_8779, sent_3481, sent_6880, sent_7042, sent_1989, sent_5946, sent_2682, sent_4557, sent_9999, sent_42, sent_9598, sent_7782, sent_1928, sent_2794, sent_8569, sent_3190, sent_8186, sent_4290, sent_716, sent_8048, sent_1018, sent_10272, sent_3900, sent_1253, sent_4261, sent_10812, sent_9246, sent_6, sent_835, sent_4315, sent_10526, sent_6723, sent_2663, sent_1648, sent_1649, sent_10071, sent_2130, sent_5738, sent_5849, sent_10801, sent_6817, sent_10747, sent_7873, sent_1954, sent_10477, sent_2342, sent_3833, sent_2795, sent_10314, sent_8781, sent_8417, sent_4073, sent_8937, sent_6240, sent_3489, sent_2807, sent_1578, sent_4998, sent_1169, sent_6287, sent_4128, sent_5700, sent_5450, sent_7234, sent_1803, sent_4402, sent_5128, sent_4169, sent_9350, sent_4908, sent_7700, sent_9012, sent_5165, sent_3350, sent_2684, sent_7005, sent_1393, sent_60, sent_10005, sent_1756, sent_5770, sent_8040, sent_271, sent_7936, sent_10738, sent_299, sent_1000, sent_10275, sent_8477, sent_461, sent_9705, sent_1293, sent_2961, sent_9227, sent_2075, sent_9643, sent_7452, sent_8090, sent_2083, sent_ ...
#   Word: ',' appeared in sentences: sent_1767, sent_5656, sent_8346, sent_9329, sent_4879, sent_260, sent_10848, sent_8211, sent_2587, sent_10888, sent_1985, sent_5325, sent_6893, sent_9491, sent_2609, sent_10675, sent_546, sent_8884, sent_8031, sent_4438, sent_9486, sent_10202, sent_4622, sent_1114, sent_1964, sent_7914, sent_11024, sent_10298, sent_6159, sent_7221, sent_2169, sent_2994, sent_724, sent_8810, sent_6678, sent_5584, sent_5785, sent_4107, sent_6570, sent_9032, sent_3825, sent_6245, sent_673, sent_1464, sent_2335, sent_4548, sent_7604, sent_7656, sent_3797, sent_733, sent_2600, sent_4397, sent_5747, sent_4062, sent_8858, sent_585, sent_10535, sent_5571, sent_2295, sent_7874, sent_10524, sent_2601, sent_7257, sent_6076, sent_10256, sent_10400, sent_4577, sent_10216, sent_610, sent_5760, sent_4110, sent_6883, sent_3030, sent_2051, sent_8723, sent_8731, sent_8526, sent_3783, sent_1433, sent_1698, sent_4663, sent_10164, sent_5075, sent_8740, sent_2364, sent_9463, sent_1574, sent_1770, sent_7976, sent_10952, sent_1583, sent_4455, sent_9434, sent_10821, sent_1115, sent_7639, sent_3359, sent_5765, sent_6161, sent_4704, sent_6728, sent_9, sent_5040, sent_9547, sent_3286, sent_3619, sent_7233, sent_2200, sent_5830, sent_668, sent_2033, sent_10016, sent_2131, sent_1113, sent_465, sent_10213, sent_2202, sent_4305, sent_510, sent_1475, sent_3687, sent_9067, sent_5336, sent_7576, sent_10031, sent_10122, sent_6675, sent_1213, sent_4636, sent_2933, sent_2992, sent_8221, sent_7815, sent_4039, sent_735, sent_5844, sent_8964, sent_10822, sent_8188, sent_3828, sent_4441, sent_7159, sent_7657, sent_7724, sent_3164, sent_6239, sent_5604, sent_3353, sent_9739, sent_523, sent_2346, sent_528, sent_5316, sent_10163, sent_2596, sent_7375, sent_9426, sent_2566, sent_9401, sent_8393, sent_639, sent_4367, sent_5318, sent_10931, sent_4151, sent_7681, sent_7208, sent_5049, sent_4558, sent_9042, sent_9029, sent_8784, sent_5565, sent_20, sent_1637, sent_8802, sent_7820, sent_10514, sent_2365, sent_2893, sent_3983, sent_8687, sent_7179, sent_3461, sent_1636, sent_9314, sent_1816, sent_897, sent_5929, sent_3040, sent_6873, sent_6836, sent_8574, sent_249, sent_1557, sent_9513, sent_3944, sent_10388, sent_1144, sent_1706, sent_1103, sent_7525, sent_7601, sent_8779, sent_4486, sent_6880, sent_252, sent_1989, sent_4557, sent_2160, sent_42, sent_3154, sent_7782, sent_8569, sent_2794, sent_3190, sent_8186, sent_8048, sent_3900, sent_1253, sent_9246, sent_8649, sent_6, sent_9230, sent_9063, sent_4315, sent_6723, sent_4047, sent_8720, sent_2663, sent_5527, sent_2130, sent_5738, sent_5849, sent_6817, sent_7873, sent_1954, sent_2342, sent_605, sent_4228, sent_3833, sent_5242, sent_301, sent_286, sent_8781, sent_6229, sent_10581, sent_8937, sent_6240, sent_1827, sent_2807, sent_1578, sent_4998, sent_6518, sent_5700, sent_7234, sent_1803, sent_4402, sent_5128, sent_4169, sent_4908, sent_9012, sent_5165, sent_7005, sent_1393, sent_60, sent_10005, sent_1756, sent_5770, sent_10738, sent_4041, sent_461, sent_5210, sent_9227, sent_2075, sent_3613, sent_9643, sent_7769, sent_4161, sent_2729, sent_4171, sent_8345, sent_3877, sent_7562, sent_10498, sent_6178, sent_1871, sent_6278, sent_400, sent_11005, sent_1584, sent_6945, sent_2759, sent_10231, sent_5657, sent_95, sent_2360, sent_9441, sent_3556, sent_7850, sent_7358, sent_9974, sent_6068, sent_1422, sent_2557, sent_7299, sent_9626, sent_3290, sent_9064, sent_7536, sent_899, sent_10743, sent_4269, sent_7995, sent_5428, sent_7151, sent_433, sent_512, sent_6213, sent_2076, sent_4275, sent_9937, sent_8255, sent_794, sent_90, sent_10319, sent_7826, sent_625, sent_1919, sent_8304, sent_9619, sent_6759, sent_8465, sent_4173, sent_10731, sent_69, sent_4860, sent_5463, sent_9293, sent_1975, sent_10914, sent_1715, sent_449, sent_1053, sent_736, sent_932, sent_5824, sent_6672, sent_1467, sent_10996, sent_3636, sent_1286, sent_9175, sent_7697, sent_6926, sent_2401, sent_7126, sent_3714, sent_7699, sent_5105, sent_7134, sent_587 ...
#   Word: ':' appeared in sentences: sent_108, sent_8068, sent_9906, sent_11034, sent_1973, sent_568, sent_1737, sent_5656, sent_307, sent_10433, sent_3205, sent_8136, sent_5791, sent_8818, sent_5137, sent_7734, sent_9329, sent_2873, sent_2713, sent_4879, sent_9559, sent_1550, sent_4521, sent_9376, sent_9356, sent_598, sent_9390, sent_6693, sent_6168, sent_2958, sent_2372, sent_1878, sent_3603, sent_10115, sent_10888, sent_4511, sent_8054, sent_5733, sent_8141, sent_408, sent_6902, sent_1269, sent_3483, sent_9392, sent_3490, sent_440, sent_7916, sent_2836, sent_6554, sent_7060, sent_8769, sent_2609, sent_2747, sent_10404, sent_5099, sent_3862, sent_8180, sent_3277, sent_266, sent_5216, sent_2214, sent_7200, sent_8708, sent_1297, sent_8729, sent_5309, sent_6753, sent_8278, sent_9304, sent_9360, sent_9740, sent_9993, sent_10961, sent_6183, sent_5293, sent_6732, sent_152, sent_9289, sent_6343, sent_7297, sent_5959, sent_10724, sent_3865, sent_10933, sent_9020, sent_505, sent_1324, sent_2983, sent_4075, sent_6553, sent_1298, sent_7161, sent_7914, sent_8982, sent_3627, sent_4200, sent_10577, sent_8847, sent_1416, sent_3017, sent_4928, sent_10809, sent_4329, sent_7418, sent_2169, sent_2649, sent_8379, sent_10329, sent_1907, sent_2934, sent_5157, sent_971, sent_3519, sent_7919, sent_210, sent_2479, sent_4471, sent_5276, sent_8067, sent_8588, sent_4935, sent_4885, sent_6219, sent_8688, sent_6187, sent_6685, sent_2539, sent_539, sent_7740, sent_1555, sent_5987, sent_5083, sent_2745, sent_4384, sent_2151, sent_6029, sent_6491, sent_5584, sent_8732, sent_6302, sent_7332, sent_349, sent_3506, sent_7503, sent_2718, sent_5408, sent_8063, sent_2388, sent_11054, sent_3330, sent_2423, sent_5832, sent_7393, sent_7825, sent_3950, sent_570, sent_6954, sent_4236, sent_7801, sent_8508, sent_4806, sent_3228, sent_673, sent_2210, sent_6257, sent_10446, sent_5330, sent_3089, sent_7656, sent_569, sent_6677, sent_2088, sent_3797, sent_2091, sent_7330, sent_7446, sent_9924, sent_9160, sent_795, sent_3741, sent_4192, sent_11035, sent_2134, sent_9673, sent_4949, sent_7638, sent_6625, sent_7987, sent_2600, sent_2766, sent_9722, sent_5747, sent_4062, sent_5957, sent_2665, sent_8101, sent_5102, sent_7683, sent_5571, sent_9383, sent_1966, sent_3378, sent_10535, sent_2507, sent_3960, sent_1232, sent_4430, sent_1370, sent_9718, sent_5612, sent_7516, sent_2870, sent_10661, sent_1632, sent_388, sent_6235, sent_7586, sent_6691, sent_10858, sent_3628, sent_9645, sent_5641, sent_4028, sent_1165, sent_7257, sent_9218, sent_1955, sent_10777, sent_6076, sent_116, sent_5378, sent_7538, sent_9953, sent_8384, sent_8360, sent_9542, sent_3725, sent_4577, sent_3365, sent_6422, sent_7239, sent_8580, sent_3175, sent_4972, sent_6883, sent_5152, sent_2034, sent_5499, sent_3435, sent_4020, sent_8526, sent_8731, sent_3626, sent_3783, sent_1728, sent_5359, sent_6747, sent_8282, sent_10007, sent_8671, sent_6369, sent_4420, sent_10937, sent_10164, sent_2895, sent_5075, sent_8466, sent_8740, sent_2710, sent_7457, sent_5585, sent_6930, sent_34, sent_4116, sent_2364, sent_7698, sent_7802, sent_9203, sent_9409, sent_8324, sent_637, sent_3185, sent_415, sent_9463, sent_2445, sent_3811, sent_8632, sent_7615, sent_9557, sent_9576, sent_8100, sent_10065, sent_5328, sent_7917, sent_1654, sent_9459, sent_1770, sent_2194, sent_766, sent_11018, sent_2260, sent_3757, sent_10455, sent_6588, sent_8728, sent_11064, sent_1748, sent_1050, sent_8600, sent_7915, sent_4455, sent_8666, sent_3111, sent_9434, sent_6934, sent_1115, sent_8819, sent_10821, sent_451, sent_3557, sent_6179, sent_6296, sent_3359, sent_6894, sent_862, sent_1535, sent_6734, sent_9190, sent_7790, sent_4716, sent_3731, sent_8284, sent_640, sent_1650, sent_8433, sent_372, sent_2525, sent_4396, sent_5765, sent_8306, sent_6161, sent_10340, sent_2824, sent_522, sent_1257, sent_2477, sent_4736, sent_8511, sent_1652, sent_9610, sent_3332, sent_2724, sent_3286, sent_763, sent_3619, sent_3883, sent_8910, sent_10859, sent_3331, sent_5830, sent_15 ...
#
#
# Label: B-Drug
#   Word: 'anticoagulation' appeared in sentences: sent_8375, sent_9806, sent_1145
#   Word: 'hydralazine' appeared in sentences: sent_7941, sent_1349, sent_1351
#   Word: 'metoprolol' appeared in sentences: sent_1646, sent_2226, sent_6854
#   Word: 'heparin' appeared in sentences: sent_1654, sent_5956, sent_9252
#   Word: 'Meropenem' appeared in sentences: sent_3656, sent_5536, sent_10977
#
#
# Label: I-Drug
#   Word: ')' appeared in sentences: sent_1292, sent_7653
#   Word: '-' appeared in sentences: sent_10633, sent_5448
#   Word: 'Forte.' appeared in sentences: sent_10
#   Word: 'porcine' appeared in sentences: sent_1292
#   Word: 'Bromide' appeared in sentences: sent_2660
#
#
# Label: B-Strength
#   Word: '40' appeared in sentences: sent_4842, sent_8671, sent_228
#   Word: '0.5' appeared in sentences: sent_5096, sent_6254, sent_3085
#   Word: '100' appeared in sentences: sent_10185, sent_4129, sent_8591
#   Word: '81' appeared in sentences: sent_2282, sent_9660
#   Word: '60' appeared in sentences: sent_3468, sent_8326
#
#
# Label: I-Strength
#   Word: 'mg' appeared in sentences: sent_6254, sent_568, sent_3573, sent_4129, sent_8591, sent_8671, sent_4890, sent_10745, sent_5213, sent_8326, sent_2771, sent_10631, sent_5096, sent_3668, sent_8101, sent_10180, sent_4652, sent_10744, sent_3085, sent_228, sent_10185, sent_7967, sent_4842, sent_3330
#   Word: 'Units/mL' appeared in sentences: sent_1655
#   Word: '/3' appeared in sentences: sent_3668
#   Word: 'mL' appeared in sentences: sent_5836
#   Word: '%' appeared in sentences: sent_6806
#
#
# Label: B-Form
#   Word: 'Tablet' appeared in sentences: sent_8536, sent_4432, sent_9453, sent_6296, sent_5096, sent_2537, sent_4890, sent_7588, sent_1940, sent_9619, sent_9832, sent_2283, sent_3047, sent_1941, sent_763, sent_9834, sent_3085
#   Word: 'Capsule' appeared in sentences: sent_10185, sent_3331, sent_228, sent_2659
#   Word: 'Solution' appeared in sentences: sent_3668
#   Word: 'Syrup' appeared in sentences: sent_4890
#   Word: 'Syringe' appeared in sentences: sent_5836
#
#
# Label: B-Reason
#   Word: 'acute' appeared in sentences: sent_5711, sent_7890
#   Word: 'coughing' appeared in sentences: sent_270
#   Word: 'headache' appeared in sentences: sent_458
#   Word: 'PEs' appeared in sentences: sent_4183
#   Word: 'Metastatic' appeared in sentences: sent_5106
#
#
# Label: I-Reason
#   Word: 'up' appeared in sentences: sent_270
#   Word: 'overload' appeared in sentences: sent_1434
#   Word: 'IMPOSED' appeared in sentences: sent_3136
#   Word: 'CELLULITIS' appeared in sentences: sent_3136
#   Word: 'fibrillation.' appeared in sentences: sent_5299
#
#
# Label: I-Dosage
#   Word: ')' appeared in sentences: sent_5836, sent_3331, sent_10853, sent_6296, sent_10185, sent_3573, sent_6806, sent_1551, sent_6811, sent_2659, sent_6154, sent_4361, sent_3907, sent_6490, sent_3335, sent_3908, sent_3085
#   Word: '(' appeared in sentences: sent_1232, sent_2771, sent_5836, sent_9453, sent_10184, sent_6296, sent_2353, sent_8040, sent_10185, sent_2659, sent_323, sent_473, sent_4132, sent_2660, sent_3085
#   Word: '1' appeared in sentences: sent_5836, sent_9453, sent_10184, sent_6296, sent_10185, sent_8040, sent_6811, sent_1551, sent_2659, sent_3908, sent_3085
#   Word: '2' appeared in sentences: sent_6154, sent_5096, sent_323
#   Word: 'ML' appeared in sentences: sent_5097, sent_3331
#
#
# Label: B-Route
#   Word: 'PO' appeared in sentences: sent_2765, sent_8329, sent_10185, sent_10640, sent_8153, sent_2764, sent_2659, sent_8326, sent_1033, sent_716, sent_10180, sent_3085
#   Word: 'IV' appeared in sentences: sent_3540, sent_347, sent_4022
#   Word: 'INH' appeared in sentences: sent_1773
#   Word: 'gtt' appeared in sentences: sent_4183
#   Word: 'PO.' appeared in sentences: sent_5500
#
#
# Label: I-Frequency
#   Word: ')' appeared in sentences: sent_6629, sent_10750, sent_3331, sent_9831, sent_3336, sent_10089, sent_5096, sent_6152, sent_6297, sent_4608, sent_10495, sent_4819, sent_716, sent_2541, sent_3332, sent_4193, sent_5097, sent_3396
#   Word: '(' appeared in sentences: sent_4958, sent_6153, sent_967, sent_3474, sent_10184, sent_10185, sent_3573, sent_8040, sent_4608, sent_3473, sent_4819, sent_716, sent_2541, sent_4193, sent_5097, sent_2660
#   Word: 'day' appeared in sentences: sent_3331, sent_4958, sent_9831, sent_3573, sent_6152, sent_5097, sent_6297, sent_3277, sent_6811, sent_9833, sent_4957, sent_2541, sent_3908, sent_2660
#   Word: 'needed' appeared in sentences: sent_10750, sent_5096, sent_6297, sent_1291, sent_3550, sent_4608, sent_7890, sent_972, sent_3396, sent_3330
#   Word: 'a' appeared in sentences: sent_2771, sent_4958, sent_3277, sent_1938, sent_837, sent_4957, sent_2541, sent_5097, sent_2660
#
#
# Label: I-Form
#   Word: '(' appeared in sentences: sent_569, sent_649, sent_9200, sent_5103
#   Word: ')' appeared in sentences: sent_569, sent_649, sent_5103
#   Word: 'E.C.' appeared in sentences: sent_649, sent_5103
#   Word: ',' appeared in sentences: sent_6194
#   Word: 'DR' appeared in sentences: sent_8591, sent_6194
#
#
# Label: B-Frequency
#   Word: 'DAILY' appeared in sentences: sent_4819, sent_8329, sent_716
#   Word: 'once' appeared in sentences: sent_10640, sent_837
#   Word: 'BID' appeared in sentences: sent_10185, sent_2765
#   Word: 'daily.' appeared in sentences: sent_3502, sent_3394
#   Word: 'qd' appeared in sentences: sent_758
#
#
# Label: B-Dosage
#   Word: 'One' appeared in sentences: sent_5836, sent_9867, sent_9453, sent_6296, sent_10185, sent_6039, sent_2659, sent_4204, sent_3085
#   Word: '6' appeared in sentences: sent_3905
#   Word: 'Three' appeared in sentences: sent_4890
#   Word: '1' appeared in sentences: sent_5096
#   Word: '0.5' appeared in sentences: sent_7834
#
#
# Label: I-Duration
#   Word: 'days' appeared in sentences: sent_3041

# %%
list(data_test[data_test['sentence_id'] == 'sent_1349'].sentence)
# Out:
# ['During initiation of her brain radiation treatments , patient had. intractable nausea , vomiting , headache , and hypertension , but. repeat CT head did not show increased edema . She continued on. IV dexamethasone 6 mg q6 hours , IV keppra 1000mg q12 hours , and. IV hydralazine for blood pressure control ( see below ) ..']

# %%
data_test[data_test['sentence_id'] == 'sent_1349'].predicted_labels.str.strip('')
# Out:
# 1349    O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# Name: predicted_labels, dtype: object

# %%
list(data_test[data_test['sentence_id'] == 'sent_1349'].word_labels)
# Out:
# ['O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,B-Route,B-Drug,B-Strength,I-Strength,B-Frequency,I-Frequency,O,B-Route,B-Drug,B-Strength,B-Frequency,I-Frequency,O,O,B-Route,B-Drug,O,B-Reason,I-Reason,I-Reason,O,O,O,O,O']

# %% [markdown]
# ### Save

# %%
import os

directory = "/content/drive/MyDrive/266_final/clinical_bert_concat7.pt"

if not os.path.exists(directory):
    os.makedirs(directory)

tokenizer.save_vocabulary(directory)
model.save_pretrained(directory)

# %% [markdown]
# ### Load

# %%
model.to(device)
# Out:
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=19, bias=True)
# )

# %% [markdown]
# Resources
#
# ### https://github.com/lcampillos/Medical-NER/blob/master/bert_ner.ipynb
# ### https://medium.com/analytics-vidhya/bio-tagged-text-to-original-text-99b05da6664

# %%
# Initialize lists to hold the restructured predictions and labels
# sentence_labels = []
# sentence_predictions = []

# # Initialize counters
# start_idx = 0

# # Loop through each row in the DataFrame
# for _, row in val_dataset.iterrows():
#     # Find out how many tokens are in the current sentence
#     num_tokens = len(row['word_labels'].split(','))

#     # Slice the flat list of labels and predictions to get the current sentence's portion
#     sentence_labels.append(labels[start_idx:start_idx + num_tokens])
#     sentence_predictions.append(predictions[start_idx:start_idx + num_tokens])

#     # Update the start index for the next sentence
#     start_idx += num_tokens

# # Now `sentence_labels` and `sentence_predictions` contain labels and predictions grouped by sentence

# %%
# sentence_labels

# %% [markdown]
# ### Error Analysis

# %%
val_dataset.head()
# Out:
#   sentence_id                     text_file_name  \
# 0      sent_2  data/training_20180910/100035.txt
# 1      sent_3  data/training_20180910/100035.txt
# 2      sent_5  data/training_20180910/100035.txt
# 3     sent_17  data/training_20180910/100035.txt
# 4     sent_18  data/training_20180910/100035.txt
#
#                                             sentence  \
# 0  Removal of chest tubes placed at an outside ho...
# 1  to an OSH with dyspnea now admitted to the MIC...
# 2  started on an epi gtt for asthma and a cooling...
# 3  [ * * 2115 - 3 - 19 * * ] 04 : 45AM BLOOD Gluc...
# 4  Baso - 0 Atyps - 0 Metas - 0 Myelos - 0. .. CX...
#
#                                          word_labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 2  O,O,O,B-Drug,B-Route,O,B-Reason,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...

# %%
# test['predictions'] = test_predictions
test['labels'] = test_labels

# %%
test[['label', 'labels']].head(60)
# Out:
#      label labels
# 0        O      O
# 1        O      O
# 2        O      O
# 3        O      O
# 4        O      O
# 5        O      O
# 6        O      O
# 7        O      O
# 8        O      O
# 9        O      O
# 10       O      O
# 11       O      O
# 12       O      O
# 13       O      O
# 14       O      O
# 15       O      O
# 16       O      O
# 17       O      O
# 18       O      O
# 19       O      O
# 20       O      O
# 21       O      O
# 22       O      O
# 23       O      O
# 24       O      O
# 25       O      O
# 26       O      O
# 27       O      O
# 28       O      O
# 29       O      O
# 30       O      O
# 31       O      O
# 32       O      O
# 33       O      O
# 34       O      O
# 35       O      O
# 36       O      O
# 37       O      O
# 38       O      O
# 39       O      O
# 40       O      O
# 41       O      O
# 42       O      O
# 43       O      O
# 44       O      O
# 45       O      O
# 46       O      O
# 47       O      O
# 48       O      O
# 49       O      O
# 50       O      O
# 51  B-Drug      O
# 52       O      O
# 53  B-Drug      O
# 54       O      O
# 55  B-Drug      O
# 56       O      O
# 57  B-Drug      O
# 58       O      O
# 59       O      O

# %%
test['predictions'].value_counts()
# Out:
# predictions
# O              523212
# B-Drug          10888
# I-Frequency     10093
# I-Dosage         5849
# B-Form           4312
# B-Strength       4220
# I-Strength       4144
# B-Frequency      4059
# B-Route          3642
# I-Form           3182
# B-Dosage         2772
# I-Drug           2647
# B-Reason         2599
# I-Reason         1700
# B-ADE             689
# I-Duration        681
# B-Duration        393
# I-ADE             367
# I-Route           312
# Name: count, dtype: int64

# %%
data_test.head()
# Out:
#                     text_file_name  \
# 0  data/test_data_Task2/100130.txt
# 1  data/test_data_Task2/100130.txt
# 2  data/test_data_Task2/100130.txt
# 3  data/test_data_Task2/100130.txt
# 4  data/test_data_Task2/100130.txt
#
#                                            sentences  \
# 0  Admission Date : [ * * 2109 - 7 - 21 * * ] Dis...
# 1  with features of an oligodendroglioma who was ...
# 2  the night before admission which rapidly sprea...
# 3  PAST MEDICAL HISTORY : 1 . Hypercholesterolemi...
# 4  previously on Decadron q.i.d . tapered over on...
#
#                                               labels
# 0  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 1  O,O,O,O,O,O,O,O,O,B-Drug,O,O,B-Reason,I-Reason...
# 2  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 3  O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,...
# 4  O,O,B-Drug,B-Frequency,O,O,O,B-Duration,I-Dura...

# %%
test.to_csv('/content/drive/MyDrive/266_final/data/concat7_preds.csv', index=False)
